# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3])

# %%
# %matplotlib notebook

# %%
plt.plot([1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# inline 옵션, notebook 옵션 두가지
# inline : interactive 안한다
# notebook : interactive 한다
