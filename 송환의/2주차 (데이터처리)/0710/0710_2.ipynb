# %%
import json

# %%
import urllib

# %%
url="http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty"
params ={
    "serviceKey":"e7QogJHmHSoZDNyOKmrSkz%2BfllX%2FnTsGt4BqhMRzx%2FsUivHY7UWg5HAxoYAOx%2F3xWpq%2Fo4p6cHGQumworGDfHA%3D%3D",
    "numOfRows":10,
    "pageNo":1,
    "stationName":"성북구",
    "dataTerm":"DAILY",
    "ver":"1.3",
    "_returnType":"JSON"
}

params["serviceKey"]= urllib.parse.unquote(params["serviceKey"])##(url에 ?. servicekey 붙임 get방식)
print(params)
params=urllib.parse.urlencode(params) #바이트타입 직렬화
print("===================")
print(params)
# Out:
# {'serviceKey': 'e7QogJHmHSoZDNyOKmrSkz+fllX/nTsGt4BqhMRzx/sUivHY7UWg5HAxoYAOx/3xWpq/o4p6cHGQumworGDfHA==', 'numOfRows': 10, 'pageNo': 1, 'stationName': '성북구', 'dataTerm': 'DAILY', 'ver': '1.3', '_returnType': 'JSON'}
# ===================
# serviceKey=e7QogJHmHSoZDNyOKmrSkz%2BfllX%2FnTsGt4BqhMRzx%2FsUivHY7UWg5HAxoYAOx%2F3xWpq%2Fo4p6cHGQumworGDfHA%3D%3D&numOfRows=10&pageNo=1&stationName=%EC%84%B1%EB%B6%81%EA%B5%AC&dataTerm=DAILY&ver=1.3&_returnType=JSON

# %%
params=params.encode("utf-8")# 바이트 코드를 담고있다.

req=urllib.request.Request(url,data=params)
res=urllib.request.urlopen(req)
resStr = res.read()

resStr = resStr.decode("utf-8")
resObj = json.loads(resStr)

resObj["list"][0]["pm25Value"]
list((item["stationName"],item["pm25Value"]) for item in resObj["list"])
    
#
#resJSON= json.dumps(resObj , indent = "    ",ensure_ascii=False)

#print(type(resJSON),resJSON)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2292f98aff49> in <module>()
# ----> 1 params=params.encode("utf-8")# 바이트 코드를 담고있다.
#       2
#       3 req=urllib.request.Request(url,data=params)
#       4 res=urllib.request.urlopen(req)
#       5 resStr = res.read()
#
# NameError: name 'params' is not defined

# %%
resObj["list"]

# %%
for row in resObj["list"] : print([{row["stationName"]:row["pm25Value"]}]
                                )  ## re!! 이거어캐?

# %%
####################

# %%
import xml.etree.ElementTree as etree

# %%
from lxml import etree ## et 북스토어가 루트노드

# %%
bookStore = etree.Element("bookstore")

# %%
book1 = etree.Element("book", category = "coking")
bookStore.insert(0, book1)
title1 = etree.Element("title")
title1.attrib["lange"] = "en"
title1.text = "Everyday Italian"
book1.append(title1)

# %%
etree.SubElement(book1, "author").text = "Giada De Laurentiis"
etree.SubElement(book1, "year").text = "2005"
etree.SubElement(book1, "price").text = "30.00"

# %%
etree.dump(bookStore)
# Out:
# <bookstore>
#   <book category="coking">
#     <title lange="en">Everyday Italian</title>
#     <author>Giada De Laurentiis</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
# </bookstore>

# %%
import xml.etree.ElementTree as etree

# %%
#xml = et.fromstring(et.tostring(bookStore))

# %%
#xmlTree =et.ElementTree(xml)
#xmlRoot = xmlTree.getroot()
#childNodes =xmlRoot.getchilderen()

# %%
xml = etree.fromstring(etree.tostring(bookStore)) 
xmlTree = etree.ElementTree(xml)
xmlRoot = xmlTree.getroot()
childNodes = xmlRoot.getchildren()
print(len(childNodes))
for childNode in childNodes:
    print(childNode.tag, childNode.items())
for childNode in childNodes[0]:
    print(childNode.tag, childNode.keys())
    if childNode.keys() != []:
        print([childNode.get(k) for k in childNode.keys()])
    
    ##############################
book = Root.find("book") 
print( book.get("category"))
bookList = xmlRoot.findall("book")
for book in bookList:
    print(book.get("category"))
title = xmlRoot.find(".//title")
print(type(title), title.text)
titleList = xmlRoot.findall(".//title") 
print([title.text for title in titleList])
title = xmlRoot.findtext(".//title") 
print(type(title), title)
book = xmlRoot.find(".//book[@category='children']") 
print(book, book.tag)
for childNode in xmlRoot.iter():
    print(childNode.tag, childNode.text)
for childNode in xmlRoot.iter("book"):
    print(childNode.tag, childNode.text)
# Out:
# 1
# book [('category', 'coking')]
# title ['lange']
# author []
# year []
# price []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-d131cc0261ad> in <module>()
#      12
#      13
# ---> 14 book = Root.find("book")
#      15 print( book.get("category"))
#      16 bookList = xmlRoot.findall("book")
#
# NameError: name 'Root' is not defined

# %%
from xml.etree.ElementTree import ElementTree

tree = ElementTree(root)
tree.write("book_xml.xml", encoding="utf-8", xml_declaration="utf-8")

# %%
from xml.etree.ElementTree import parse

tree =parse("book_xml.xml")
root = tree.getroot()

for node in root.iter():
    print(node.tag, node.text)
# Out:
# bookstore None
# book None
# title Everyday Italian
# author Giada De Laurentiis
# year 2005
# price 30.00

# %%
root.findall(".//title")
# Out:
# [<Element 'title' at 0x000001B3F95FB318>]

# %%
tree = ElementTree(file = "book_xml.xml")
root = tree.getroot()

for node in root.iter():
    print(node.tag, node.text)
# Out:
# bookstore None
# book None
# title Everyday Italian
# author Giada De Laurentiis
# year 2005
# price 30.00

# %%
################################# 
## lxml 이거를 쓴다 다 이거쓴다 이거쓰면됨

# %%
bookStore = etree.Element("bookstore")  ## root

bookl = etree.SubElement(bookStore, "book")
book2 = etree.SubElement(bookStore, "book", attrib={"category":"children"})

bookl.attrib["category"] = "cooking"

titlel = etree.Element("title", lang="en") 
titlel.text = "Everyday Italian"
bookl.append(titlel)

etree.SubElement(bookl, "author").text = "Giada De Laurentiis" 
etree.SubElement(bookl, "year").text = "2005"
etree.SubElement(bookl, "price").text = "30.00"

title2 = etree.Element("title")
title2.set("lang", titlel.get("lang")) 
title2.text = "Harry Potter"
book2.append(title2)

etree.SubElement(book2, "author").text = "Giada De Laurentiis" 
etree.SubElement(book2, "year").text = "2005"
book2.insert(3, etree.Element("price"))

print(len(book2)) 
book2[-1].text = "30.00"

##xmlBytes = etree.tostring(bookStore, encoding="utf-8", pretty_print=False, xml_declaration=True) 
##xmlStr = etree.tounicode(bookStore, pretty_print=True)

##print(type(xmlStr))
etree.dump(bookStore)
# Out:
# 4
# <bookstore><book category="cooking"><title lang="en">Everyday Italian</title><author>Giada De Laurentiis</author><year>2005</year><price>30.00</price></book><book category="children"><title lang="en">Harry Potter</title><author>Giada De Laurentiis</author><year>2005</year><price>30.00</price></book></bookstore>

# %%
b

# %%
xml = etree.XML(etree.tostring(bookStore)) 
xmlTree = etree.ElementTree(xml)
xmlRoot = xmlTree.getroot()

print(xmlTree.docinfo.xml_version)
print(xmlTree.docinfo.encoding)
print(xmlTree.docinfo.doctype)
print(xmlTree.docinfo.root_name)

print(len(xmlRoot))
for childNode in xmlRoot:
    print(childNode.tag, childNode.attrib)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-867d79c413d3> in <module>()
#       3 xmlRoot = xmlTree.getroot()
#       4
# ----> 5 print(xmlTree.docinfo.xml_version)
#       6 print(xmlTree.docinfo.encoding)
#       7 print(xmlTree.docinfo.doctype)
#
# AttributeError: 'ElementTree' object has no attribute 'docinfo'

# %%
xml = etree.fromstring(etree.tostring(bookStore)) 
xmlTree = etree.ElementTree(xml)
xmlRoot = xmlTree.getroot()

childNodes = xmlRoot.getchildren()

print(len(childNodes))
for childNode in childNodes:
     print(childNode.tag, childNode.items())

for childNode in childNodes[0]:
     print(childNode.tag, childNode.keys())
if childNode.keys() 1= []:
       printUchildNode.get(k) for k in childNode.keys()])

book = xmlRoot.find("book") 
print(book.tag, book.get("category"))

bookList = xmlRoot.findall("book")
for book in bookList:
 print(book.tag, book.get("category"))

title = xmlRoot.find(".//title") 
print(type(title), title.text)

titleList = xmlRoot.findall(".//title") 
print([title.text for title in titleList])

title = xmlRoot.findtext(".//title") 
print(type(title), title)

book = xmlRoot.find(".//book[@category='children']") 
print(book, book.tag)

for childNode in xmlRoot.iter(): 
 print(childNode.tag, childNode.text)

for childNode in xmlRoot.iter("book"): 
 print(childNode.tag, childNode.text)

# %%
url="http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty"
params ={
    "serviceKey":"e7QogJHmHSoZDNyOKmrSkz%2BfllX%2FnTsGt4BqhMRzx%2FsUivHY7UWg5HAxoYAOx%2F3xWpq%2Fo4p6cHGQumworGDfHA%3D%3D",
    "numOfRows":10,
    "pageNo":1,
    "stationName":"성북구",
    "dataTerm":"DAILY",
    "ver":"1.3",
    
}

params["serviceKey"]= urllib.parse.unquote(params["serviceKey"]) 
print(params)
params=urllib.parse.urlencode(params) #바이트타입으로 시리얼라이즈
params=params.encode("utf-8")# 바이트 코드를 담고있다.

req=urllib.request.Request(url,data=params)
res=urllib.request.urlopen(req)
resStr = res.read()

resStr = resStr.decode("utf-8")
# Out:
# {'serviceKey': 'e7QogJHmHSoZDNyOKmrSkz+fllX/nTsGt4BqhMRzx/sUivHY7UWg5HAxoYAOx/3xWpq/o4p6cHGQumworGDfHA==', 'numOfRows': 10, 'pageNo': 1, 'stationName': '성북구', 'dataTerm': 'DAILY', 'ver': '1.3'}

# %%
#resStr = resStr.decode("utf-8")
xmlObj = etree.fromstring(resStr)
xmlRoot = etree.ElementTree(xmlObj).getroot()
print("adsasd")
etree.dump(xmlRoot)

print("adsasd")
for node in xmlRoot.iter(): 
    print(node.tag, node.text)

itemList = xmlRoot.findall(".//item")
print("빼")
print(len(itemList))
# for item in itemList:
  #   for i in range(len(item)):
    #    print(item[i].tag, item[i].text)
print("빼에에에에에에엑")
pm25List = xmlRoot.findall(".//item/pm25Value") 
for item in pm25List:
    print(item.tag, item.text)
 #   print(item.get(i).tag)
 #   etree.dump(item.get(i))
# Out:
# adsasd
# <response>
# 	<header>
# 		<resultCode>00</resultCode>
# 		<resultMsg>NORMAL SERVICE.</resultMsg>
# 	</header>
# 	<body>
# 		<items>
#
# 				<item>
# 					<dataTime>2019-07-10 16:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.4</coValue>
# 					<o3Value>0.023</o3Value>
# 					<no2Value>0.019</no2Value>
# 					<pm10Value>7</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>7</pm25Value>
#
#
#                         <pm25Value24>6</pm25Value24>
#
# 					<khaiValue>38</khaiValue>
# 					<khaiGrade>1</khaiGrade>
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade>1</pm25Grade>
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 15:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.4</coValue>
# 					<o3Value>0.026</o3Value>
# 					<no2Value>0.018</no2Value>
# 					<pm10Value>7</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>6</pm25Value>
#
#
#                         <pm25Value24>6</pm25Value24>
#
# 					<khaiValue>43</khaiValue>
# 					<khaiGrade>1</khaiGrade>
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade>1</pm25Grade>
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 14:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.025</o3Value>
# 					<no2Value>0.020</no2Value>
# 					<pm10Value>8</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>7</pm25Value>
#
#
#                         <pm25Value24>6</pm25Value24>
#
# 					<khaiValue>42</khaiValue>
# 					<khaiGrade>1</khaiGrade>
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade>1</pm25Grade>
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 13:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.029</o3Value>
# 					<no2Value>0.017</no2Value>
# 					<pm10Value>6</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>6</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 12:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.029</o3Value>
# 					<no2Value>0.018</no2Value>
# 					<pm10Value>6</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>6</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 11:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.028</o3Value>
# 					<no2Value>0.017</no2Value>
# 					<pm10Value>8</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>7</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 10:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.027</o3Value>
# 					<no2Value>0.019</no2Value>
# 					<pm10Value>8</pm10Value>
#
#                         <pm10Value24>7</pm10Value24>
#
#
#                         <pm25Value>5</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 09:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.026</o3Value>
# 					<no2Value>0.018</no2Value>
# 					<pm10Value>11</pm10Value>
#
#                         <pm10Value24>6</pm10Value24>
#
#
#                         <pm25Value>4</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 08:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.021</o3Value>
# 					<no2Value>0.022</no2Value>
# 					<pm10Value>7</pm10Value>
#
#                         <pm10Value24>5</pm10Value24>
#
#
#                         <pm25Value>4</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h>1</pm25Grade1h>
#
# 				</item>
#
# 				<item>
# 					<dataTime>2019-07-10 07:00</dataTime>
#
#                         <mangName>도시대기</mangName>
#
# 					<so2Value>-</so2Value>
# 					<coValue>0.5</coValue>
# 					<o3Value>0.018</o3Value>
# 					<no2Value>0.022</no2Value>
# 					<pm10Value>4</pm10Value>
#
#                         <pm10Value24>5</pm10Value24>
#
#
#                         <pm25Value>-</pm25Value>
#
#
#                         <pm25Value24>-</pm25Value24>
#
# 					<khaiValue>-</khaiValue>
# 					<khaiGrade />
# 					<so2Grade />
# 					<coGrade>1</coGrade>
# 					<o3Grade>1</o3Grade>
# 					<no2Grade>1</no2Grade>
# 					<pm10Grade>1</pm10Grade>
#
#                         <pm25Grade />
#
#
#                         <pm10Grade1h>1</pm10Grade1h>
#                         <pm25Grade1h />
#
# 				</item>
#
# 		</items>
# 			<numOfRows>10</numOfRows>
# 			<pageNo>1</pageNo>
# 			<totalCount>23</totalCount>
# 	</body>
# </response>
# adsasd
# response
#
# header
#
# resultCode 00
# resultMsg NORMAL SERVICE.
# body
#
# items
#
#
# item
#
# dataTime 2019-07-10 16:00
# mangName 도시대기
# so2Value -
# coValue 0.4
# o3Value 0.023
# no2Value 0.019
# pm10Value 7
# pm10Value24 7
# pm25Value 7
# pm25Value24 6
# khaiValue 38
# khaiGrade 1
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade 1
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 15:00
# mangName 도시대기
# so2Value -
# coValue 0.4
# o3Value 0.026
# no2Value 0.018
# pm10Value 7
# pm10Value24 7
# pm25Value 6
# pm25Value24 6
# khaiValue 43
# khaiGrade 1
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade 1
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 14:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.025
# no2Value 0.020
# pm10Value 8
# pm10Value24 7
# pm25Value 7
# pm25Value24 6
# khaiValue 42
# khaiGrade 1
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade 1
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 13:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.029
# no2Value 0.017
# pm10Value 6
# pm10Value24 7
# pm25Value 6
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 12:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.029
# no2Value 0.018
# pm10Value 6
# pm10Value24 7
# pm25Value 6
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 11:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.028
# no2Value 0.017
# pm10Value 8
# pm10Value24 7
# pm25Value 7
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 10:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.027
# no2Value 0.019
# pm10Value 8
# pm10Value24 7
# pm25Value 5
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 09:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.026
# no2Value 0.018
# pm10Value 11
# pm10Value24 6
# pm25Value 4
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 08:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.021
# no2Value 0.022
# pm10Value 7
# pm10Value24 5
# pm25Value 4
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h 1
# item
#
# dataTime 2019-07-10 07:00
# mangName 도시대기
# so2Value -
# coValue 0.5
# o3Value 0.018
# no2Value 0.022
# pm10Value 4
# pm10Value24 5
# pm25Value -
# pm25Value24 -
# khaiValue -
# khaiGrade None
# so2Grade None
# coGrade 1
# o3Grade 1
# no2Grade 1
# pm10Grade 1
# pm25Grade None
# pm10Grade1h 1
# pm25Grade1h None
# numOfRows 10
# pageNo 1
# totalCount 23
# 빼
# 10
# 빼에에에에에에엑
# pm25Value 7
# pm25Value 6
# pm25Value 7
# pm25Value 6
# pm25Value 6
# pm25Value 7
# pm25Value 5
# pm25Value 4
# pm25Value 4
# pm25Value -

# %%
##string 다떄려박아서 xml개체로 생성해도 문제없는데 그럴자신없으면 트리 re!!
