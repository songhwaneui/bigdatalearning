# %% [markdown]
# __*scraping*__
# page rank <- link들 간의 관계를 이용하여 가중치를 매겨 계산
# 실제 크롤링을 해서 가중치를 매길 일은 아마 없을 것.... 아마도!
# 오늘부터 하는 게 더 도움될 것
# 앞에 했던 건 빅데이터 수집의 관점, 어떻게 바라봐야 하는지
# __*data scraping / data crawling*__
# scraping은 안 한 건 아니고 하긴 했음 검색결과 해서 우리가 원하는 거 뜯어오는 거
# 둘의 차이를 보면 후자는 스케일이 굉장히 크다. 웹사이트를 돌고 돌아서 왔다갔다 할 거니까. 큰 규모
# 당연히 우리가 빅데이터라고 부르면 후자에 해당 (volumn이라고 하는 관점에서)
# 구글 첫 페이지 긁어오거나 네이버, 다음 검색 첫페이지 긁어오기...딱 내가 원하는 것만큼만 <- 전자
# 웹페이지를 통으로 긁어와서 저장하는 부분이 반드시 있어야 함 <- 후자
# 전자는 그 부분이 필요없음. 내가 원하는 부분만 들고와서 쓴 다음에 나머지는 버려버리면 됨
# 후자는 crawler agent가 필요 (어제 만들었던 걔)
# 전자는 parser가 필요 <- 내가 원하는 데이터가 어디 있는지 찾은 다음에 걔만 가져와야 되니까
# 둘다 파서가 필요하긴 한데 굳이 구분하자면?
# 우리가 크롤러를 만들어서 seed 주소를 만들면 해당 링크 방문 list를 build하고 중간에 부산물로
# 전체 페이지를 다운로드 다운로드 해서 자연어 처리나 이런 걸 거쳐서 indexing이라고 하는 데이터베이스를 만들 것
# web scraping
# 특정 사이트 하나 들어가서 우리가 만든 scraper가 scraping할 건데 어떤 걸? xml, sql, excel
# web crawler가 indexing하는 거랑 어떻게 보면 똑같음
# 크롤러의 일부분이라고 볼 수도 있음
# 크롤링, 스크래핑이랑 조금씩 다름 - 목적이 다름
# 크롤링은 앵커라고 하는 텍스트를 찾아서 네트워크를 끊임없이 돌아다님
# 스크래핑은 특정 페이지의 내용을 내 목적에 맞게 가져옴
#
# Architecture
# 멀티 스레드로 돌면서 인터넷으로부터 웹페이지를 다운받음 <- URL주소를 가지고
# 큐라는 구조로 어제는 스케쥴러를 대신함
# 스케쥴러에 의해서 시드 주소를 주면 웹페이지를 하나 긁어오고 거기서 우리가 원하는 데이터를 따로 저장해놓고
# 다시 다음페이지로 감
# 어제 그림보다 훨씬 간단
# 어제 했던 DB를 안 버린 상태에서 오늘 table을 새로 만들 것

# %%
import requests
import time

headers = {"user-agent" : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"}

# request package를 사용하여 error handling
def download(method, url, param=None, data=None, timeout=1, maxretries=3):
    try:
        resp = requests.request(method, url, params=param, data=data, headers=headers)
        # 한글처럼 아스키가 아닌 문자들을 변환시킬 때 서비스키도 같이 바꿔버림
        resp.raise_for_status()
        #if(resp.headers['Content-Type'].split("/")[0] == "image"):
            #resp.headers['Content-Type'].split("/")[1] #확장자
    except requests.exceptions.HTTPError as e:
        if 500 <= e.response.status_code < 600 and maxretries > 0:
            print(e.response.status_code)
            print(e.response.reason)
            time.sleep(timeout) # 1초 정도 기다림
            print(maxretries)
            print("재시도") #maxretries
            download(method, url, param, data, timeout, maxretries-1)
        else:
            print(e.response.status_code)
            print(e.response.reason)
    return resp

# %%
from bs4 import BeautifulSoup
import re
import sqlite3

# %%
url = "http://www.ppomppu.co.kr/zboard/zboard.php"
param = {
    "id":"ppomppu",
    "page":1
}
resp = download("get", url, param = param)
dom = BeautifulSoup(resp.text, 'lxml')

# %%
requests.compat.urlparse(resp.request.url)
# Out:
# ParseResult(scheme='http', netloc='www.ppomppu.co.kr', path='/zboard/zboard.php', params='', query='id=freeboard', fragment='')

# %%
requests.compat.urlparse(resp.request.url)[4]
# Out:
# 'id=freeboard'

# %%
for tr in dom.select("tr[class^=list]")[1:]:
    # tr인데 class가 list로 시작하는
    td = tr.find_all("td", recursive=False)
    print(requests.compat.urljoin(url, td[3].a.img["src"]))
    print(td[3].select("td[valign=middle] > a")[0].text)
    temp = td[5].text.split("-")
    print((0, 0) if len(temp) < 2 else ",".join(temp))
    print(td[6].text.strip())
    print()
# Out:
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []

# %%
[requests.compat.urljoin(resp.request.url, _["href"]) for _ in dom.select("td#page_list a")]
# Out:
# ['http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=2&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=3&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=4&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=5&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=6&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=7&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=8&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=9&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=10&divpage=1221',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=11&divpage=1221']

# %%
# 아래아래 코드(선생님)와 뜻은 같음
def addlink(seed):
    ppomppulink = []
    html = download("get", seed)
    dom = BeautifulSoup(html.text, "lxml")
    for tr in dom.select("tr[class^=list]")[1:]:
        a = tr.find_all("a")
        if len(a) > 1:
            ppomppulink.append(a[1]["href"])
    return(ppomppulink)

# %%
[requests.compat.urljoin(resp.request.url, _) for _ in ppomppulink]
# Out:
# ['http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543168',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543167',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543166',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543165',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543164',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543163',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543162',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543161',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543160',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543159',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543158',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543157',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543156',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543155',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543154',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543153',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543152',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543151',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543150',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543149',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543147',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543146',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543145',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543144',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543143',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543142',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543141',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543140',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543139',
#  'http://www.ppomppu.co.kr/zboard/zboard.php?id=freeboard&page=1&divpage=1221&no=6543138']

# %%
def parseURL(seed):
    html = download("get", seed)
    dom = BeautifulSoup(html.text, "lxml")
    
    return [requests.compat.urljoin(seed, _.find_parent()["href"]) for _ in dom.select("font.list_title") if _.find_parent() and _.find_parent().has_attr("href")]

# %%
def parseContent(url):
    html = download("get", url)
    dom = BeautifulSoup(html.text, "lxml")
    
    return {"title":dom.select_one("font.view_title2").text.strip(),
           "body":dom.select_one("td.board-contents").text.strip(),
           "comments":[_.text.strip() for _ in dom.select("div[id^=commentContent_]")]}

# %%
url = "http://www.ppomppu.co.kr/zboard/zboard.php"
param = {
    "id":"freeboard",
}
resp = download("get", url, param = param)
dom = BeautifulSoup(resp.text, 'lxml')

# %%
seed = list()
seed.extend([requests.compat.urljoin(resp.request.url, _["href"]) 
             for _ in dom.select("td#page_list a")])
seen=list()
queue=list()
linkList = list()
# print(seed)

while seed:
    baseURL = seed.pop(0)
    seen.append(baseURL)
    linkList = parseURL(baseURL)
    
    for link in linkList:
        if link not in queue and link not in seen:
            queue.append(link)
    print("Queue: {0}, Seen: {1}".format(len(queue), len(seen)))
    
#     html = download("get", baseURL)
#     dom = BeautifulSoup(html.text, "lxml")
#     for tr in dom.select("tr[class^=list]")[1:]:
#         a = tr.find_all("a")
#         if len(a) > 1:
#             linkList.append(a[1]["href"])
    
#     print(len(seed), len(seen), len(linkList))
# Out:
# Queue: 30, Seen: 1
# Queue: 60, Seen: 2
# Queue: 90, Seen: 3
# Queue: 120, Seen: 4
# Queue: 150, Seen: 5
# Queue: 180, Seen: 6
# Queue: 210, Seen: 7
# Queue: 240, Seen: 8
# Queue: 270, Seen: 9
# Queue: 300, Seen: 10
# Queue: 330, Seen: 11

# %%
con = sqlite3.connect("bot.db")
cur = con.cursor()

# %%
cur.executescript("""
    DROP TABLE IF EXISTS table3;
    CREATE TABLE table3(
        id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
        title TEXT NOT NULL,
        content TEXT NOT NULL,
        data TIMESTAMP DEFAULT CURRENT_TIMESTAMP NOT NULL
    );
    
    DROP TABLE IF EXISTS table4;
    CREATE TABLE table4(
        id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
        table3_id INTEGER NOT NULL,
        comment TEXT NOT NULL
    );
""")
con.commit()

# %%
# contents=list()
while(queue):
    baseURL = queue.pop()
    seen.append(baseURL)
    content = parseContent(baseURL)
    cur.execute("""
        INSERT INTO table3 (title, content)
        VALUES(?,?)
    """, [content["title"], content["body"]])
    con.commit()
    
    # 원래는 이렇게 비교하는 거 안좋음. 키를 가져와서 비교하는 게 좋음
    cur.execute("""
        SELECT id
        FROM table3
        WHERE title=? AND content=?;
    """, [content["title"], content["body"]])
    con.commit()
    table3_id = cur.fetchone()[0]
    
    for comment in content["comments"]:
        cur.execute("""
            INSERT INTO table4 (table3_id, comment)
            VALUES(?,?)
        """, [table3_id, comment])
    con.commit()
#     contents.append(parseContent(currentURL))
    print("Queue: {0}, Seen: {1}".format(len(queue), len(seen)))
# Out:
# Queue: 329, Seen: 12
# Queue: 328, Seen: 13
# Queue: 327, Seen: 14
# Queue: 326, Seen: 15
# Queue: 325, Seen: 16
# Queue: 324, Seen: 17
# Queue: 323, Seen: 18
# Queue: 322, Seen: 19
# Queue: 321, Seen: 20
# Queue: 320, Seen: 21
# Queue: 319, Seen: 22
# Queue: 318, Seen: 23
# Queue: 317, Seen: 24
# Queue: 316, Seen: 25
# Queue: 315, Seen: 26
# Queue: 314, Seen: 27
# Queue: 313, Seen: 28
# Queue: 312, Seen: 29
# Queue: 311, Seen: 30
# Queue: 310, Seen: 31
# Queue: 309, Seen: 32
# Queue: 308, Seen: 33
# Queue: 307, Seen: 34
# Queue: 306, Seen: 35
# Queue: 305, Seen: 36
# Queue: 304, Seen: 37
# Queue: 303, Seen: 38
# Queue: 302, Seen: 39
# Queue: 301, Seen: 40
# Queue: 300, Seen: 41
# Queue: 299, Seen: 42
# Queue: 298, Seen: 43
# Queue: 297, Seen: 44
# Queue: 296, Seen: 45
# Queue: 295, Seen: 46
# Queue: 294, Seen: 47
# Queue: 293, Seen: 48
# Queue: 292, Seen: 49
# Queue: 291, Seen: 50
# Queue: 290, Seen: 51
# Queue: 289, Seen: 52
# Queue: 288, Seen: 53
# Queue: 287, Seen: 54
# Queue: 286, Seen: 55
# Queue: 285, Seen: 56
# Queue: 284, Seen: 57
# Queue: 283, Seen: 58
# Queue: 282, Seen: 59
# Queue: 281, Seen: 60
# Queue: 280, Seen: 61
# Queue: 279, Seen: 62
# Queue: 278, Seen: 63
# Queue: 277, Seen: 64
# Queue: 276, Seen: 65
# Queue: 275, Seen: 66
# Queue: 274, Seen: 67
# Queue: 273, Seen: 68
# Queue: 272, Seen: 69
# Queue: 271, Seen: 70
# Queue: 270, Seen: 71
# Queue: 269, Seen: 72
# Queue: 268, Seen: 73
# Queue: 267, Seen: 74
# Queue: 266, Seen: 75
# Queue: 265, Seen: 76
# Queue: 264, Seen: 77
# Queue: 263, Seen: 78
# Queue: 262, Seen: 79
# Queue: 261, Seen: 80
# Queue: 260, Seen: 81
# Queue: 259, Seen: 82
# Queue: 258, Seen: 83
# Queue: 257, Seen: 84
# Queue: 256, Seen: 85
# Queue: 255, Seen: 86
# Queue: 254, Seen: 87
# Queue: 253, Seen: 88
# Queue: 252, Seen: 89
# Queue: 251, Seen: 90
# Queue: 250, Seen: 91
# Queue: 249, Seen: 92
# Queue: 248, Seen: 93
# Queue: 247, Seen: 94
# Queue: 246, Seen: 95
# Queue: 245, Seen: 96
# Queue: 244, Seen: 97
# Queue: 243, Seen: 98
# Queue: 242, Seen: 99
# Queue: 241, Seen: 100
# Queue: 240, Seen: 101
# Queue: 239, Seen: 102
# Queue: 238, Seen: 103
# Queue: 237, Seen: 104
# Queue: 236, Seen: 105
# Queue: 235, Seen: 106
# Queue: 234, Seen: 107
# Queue: 233, Seen: 108
# Queue: 232, Seen: 109
# Queue: 231, Seen: 110
# Queue: 230, Seen: 111
# Queue: 229, Seen: 112
# Queue: 228, Seen: 113
# Queue: 227, Seen: 114
# Queue: 226, Seen: 115
# Queue: 225, Seen: 116
# Queue: 224, Seen: 117
# Queue: 223, Seen: 118
# Queue: 222, Seen: 119
# Queue: 221, Seen: 120
# Queue: 220, Seen: 121
# Queue: 219, Seen: 122
# Queue: 218, Seen: 123
# Queue: 217, Seen: 124
# Queue: 216, Seen: 125
# Queue: 215, Seen: 126
# Queue: 214, Seen: 127
# Queue: 213, Seen: 128
# Queue: 212, Seen: 129
# Queue: 211, Seen: 130
# Queue: 210, Seen: 131
# Queue: 209, Seen: 132
# Queue: 208, Seen: 133
# Queue: 207, Seen: 134
# Queue: 206, Seen: 135
# Queue: 205, Seen: 136
# Queue: 204, Seen: 137
# Queue: 203, Seen: 138
# Queue: 202, Seen: 139
# Queue: 201, Seen: 140
# Queue: 200, Seen: 141
# Queue: 199, Seen: 142
# Queue: 198, Seen: 143
# Queue: 197, Seen: 144
# Queue: 196, Seen: 145
# Queue: 195, Seen: 146
# Queue: 194, Seen: 147
# Queue: 193, Seen: 148
# Queue: 192, Seen: 149
# Queue: 191, Seen: 150
# Queue: 190, Seen: 151
# Queue: 189, Seen: 152
# Queue: 188, Seen: 153
# Queue: 187, Seen: 154
# Queue: 186, Seen: 155
# Queue: 185, Seen: 156
# Queue: 184, Seen: 157
# Queue: 183, Seen: 158
# Queue: 182, Seen: 159
# Queue: 181, Seen: 160
# Queue: 180, Seen: 161
# Queue: 179, Seen: 162
# Queue: 178, Seen: 163
# Queue: 177, Seen: 164
# Queue: 176, Seen: 165
# Queue: 175, Seen: 166
# Queue: 174, Seen: 167
# Queue: 173, Seen: 168
# Queue: 172, Seen: 169
# Queue: 171, Seen: 170
# Queue: 170, Seen: 171
# Queue: 169, Seen: 172
# Queue: 168, Seen: 173
# Queue: 167, Seen: 174
# Queue: 166, Seen: 175
# Queue: 165, Seen: 176
# Queue: 164, Seen: 177
# Queue: 163, Seen: 178
# Queue: 162, Seen: 179
# Queue: 161, Seen: 180
# Queue: 160, Seen: 181
# Queue: 159, Seen: 182
# Queue: 158, Seen: 183
# Queue: 157, Seen: 184
# Queue: 156, Seen: 185
# Queue: 155, Seen: 186
# Queue: 154, Seen: 187
# Queue: 153, Seen: 188
# Queue: 152, Seen: 189
# Queue: 151, Seen: 190
# Queue: 150, Seen: 191
# Queue: 149, Seen: 192
# Queue: 148, Seen: 193
# Queue: 147, Seen: 194
# Queue: 146, Seen: 195
# Queue: 145, Seen: 196
# Queue: 144, Seen: 197
# Queue: 143, Seen: 198
# Queue: 142, Seen: 199
# Queue: 141, Seen: 200
# Queue: 140, Seen: 201
# Queue: 139, Seen: 202
# Queue: 138, Seen: 203
# Queue: 137, Seen: 204
# Queue: 136, Seen: 205
# Queue: 135, Seen: 206
# Queue: 134, Seen: 207
# Queue: 133, Seen: 208
# Queue: 132, Seen: 209
# Queue: 131, Seen: 210
# Queue: 130, Seen: 211
# Queue: 129, Seen: 212
# Queue: 128, Seen: 213
# Queue: 127, Seen: 214
# Queue: 126, Seen: 215
# Queue: 125, Seen: 216
# Queue: 124, Seen: 217
# Queue: 123, Seen: 218
# Queue: 122, Seen: 219
# Queue: 121, Seen: 220
# Queue: 120, Seen: 221
# Queue: 119, Seen: 222
# Queue: 118, Seen: 223
# Queue: 117, Seen: 224
# Queue: 116, Seen: 225
# Queue: 115, Seen: 226
# Queue: 114, Seen: 227
# Queue: 113, Seen: 228
# Queue: 112, Seen: 229
# Queue: 111, Seen: 230
# Queue: 110, Seen: 231
# Queue: 109, Seen: 232
# Queue: 108, Seen: 233
# Queue: 107, Seen: 234
# Queue: 106, Seen: 235
# Queue: 105, Seen: 236
# Queue: 104, Seen: 237
# Queue: 103, Seen: 238
# Queue: 102, Seen: 239
# Queue: 101, Seen: 240
# Queue: 100, Seen: 241
# Queue: 99, Seen: 242
# Queue: 98, Seen: 243
# Queue: 97, Seen: 244
# Queue: 96, Seen: 245
# Queue: 95, Seen: 246
# Queue: 94, Seen: 247
# Queue: 93, Seen: 248
# Queue: 92, Seen: 249
# Queue: 91, Seen: 250
# Queue: 90, Seen: 251
# Queue: 89, Seen: 252
# Queue: 88, Seen: 253
# Queue: 87, Seen: 254
# Queue: 86, Seen: 255
# Queue: 85, Seen: 256
# Queue: 84, Seen: 257
# Queue: 83, Seen: 258
# Queue: 82, Seen: 259
# Queue: 81, Seen: 260
# Queue: 80, Seen: 261
# Queue: 79, Seen: 262
# Queue: 78, Seen: 263
# Queue: 77, Seen: 264
# Queue: 76, Seen: 265
# Queue: 75, Seen: 266
# Queue: 74, Seen: 267
# Queue: 73, Seen: 268
# Queue: 72, Seen: 269
# Queue: 71, Seen: 270
# Queue: 70, Seen: 271
# Queue: 69, Seen: 272
# Queue: 68, Seen: 273
# Queue: 67, Seen: 274
# Queue: 66, Seen: 275
# Queue: 65, Seen: 276
# Queue: 64, Seen: 277
# Queue: 63, Seen: 278
# Queue: 62, Seen: 279
# Queue: 61, Seen: 280
# Queue: 60, Seen: 281
# Queue: 59, Seen: 282
# Queue: 58, Seen: 283
# Queue: 57, Seen: 284
# Queue: 56, Seen: 285
# Queue: 55, Seen: 286
# Queue: 54, Seen: 287
# Queue: 53, Seen: 288
# Queue: 52, Seen: 289
# Queue: 51, Seen: 290
# Queue: 50, Seen: 291
# Queue: 49, Seen: 292
# Queue: 48, Seen: 293
# Queue: 47, Seen: 294
# Queue: 46, Seen: 295
# Queue: 45, Seen: 296
# Queue: 44, Seen: 297
# Queue: 43, Seen: 298
# Queue: 42, Seen: 299
# Queue: 41, Seen: 300
# Queue: 40, Seen: 301
# Queue: 39, Seen: 302
# Queue: 38, Seen: 303
# Queue: 37, Seen: 304
# Queue: 36, Seen: 305
# Queue: 35, Seen: 306
# Queue: 34, Seen: 307
# Queue: 33, Seen: 308
# Queue: 32, Seen: 309
# Queue: 31, Seen: 310
# Queue: 30, Seen: 311
# Queue: 29, Seen: 312
# Queue: 28, Seen: 313
# Queue: 27, Seen: 314
# Queue: 26, Seen: 315
# Queue: 25, Seen: 316
# Queue: 24, Seen: 317
# Queue: 23, Seen: 318
# Queue: 22, Seen: 319
# Queue: 21, Seen: 320
# Queue: 20, Seen: 321
# Queue: 19, Seen: 322
# Queue: 18, Seen: 323
# Queue: 17, Seen: 324
# Queue: 16, Seen: 325
# Queue: 15, Seen: 326
# Queue: 14, Seen: 327
# Queue: 13, Seen: 328
# Queue: 12, Seen: 329
# Queue: 11, Seen: 330
# Queue: 10, Seen: 331
# Queue: 9, Seen: 332
# Queue: 8, Seen: 333
# Queue: 7, Seen: 334
# Queue: 6, Seen: 335
# Queue: 5, Seen: 336
# Queue: 4, Seen: 337
# Queue: 3, Seen: 338
# Queue: 2, Seen: 339
# Queue: 1, Seen: 340
# Queue: 0, Seen: 341

# %%
con.close()
cur.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-182-435b160c7bbb> in <module>
#       1 con.close()
# ----> 2 cur.close()
#
# ProgrammingError: Cannot operate on a closed database.

# %%
contents[0]
# Out:
# {'title': '불매운동 0순위',
#  'body': '일본차도 안타고, 일본여행도 안갈거고, 유니클로도 안살거고, 카메라도 안살거고\n\xa0\n\n제일중요한게 빠졌네요\n\n--------------------------------------------------------------------------------------------------------------------\n\n내컴퓨터 > C:\\Windows\\System32\\drivers\\etc 들어가시면 hosts 파일이있습니다.\n\nhosts파일 열기(메모장등 편집툴로)\n\n\n127.0.0.1 www.chosun.com\n\n\n127.0.0.1 biz.chosun.com\n\n\n127.0.0.1 blogs.chosun.com\n\n\n127.0.0.1 cnnews.chosun.com\n\n\n127.0.0.1 danmee.chosun.com\n\n\n127.0.0.1 economy.chosun.com\n\n\n127.0.0.1 edu.chosun.com\n\n\n127.0.0.1 english.chosun.com\n\n\n127.0.0.1 fashion.chosun.com\n\n\n127.0.0.1 health.chosun.com\n\n\n127.0.0.1 issue.chosun.com\n\n\n127.0.0.1 japanese.chosun.com\n\n\n127.0.0.1 kartrider.chosun.com\n\n\n127.0.0.1 kid.chosun.com\n\n\n127.0.0.1 lifenlearning.chosun.com\n\n\n127.0.0.1 m.chosun.com\n\n\n127.0.0.1 m.health.chosun.com\n\n\n127.0.0.1 marathon.chosun.com\n\n\n127.0.0.1 mindgil.chosun.com\n\n\n127.0.0.1 monthly.chosun.com\n\n\n127.0.0.1 news.chosun.com\n\n\n127.0.0.1 news.tv.chosun.com\n\n\n127.0.0.1 pet.chosun.com\n\n\n127.0.0.1 picpen.chosun.com\n\n\n127.0.0.1 realty.chosun.com\n\n\n127.0.0.1 san.chosun.com\n\n\n127.0.0.1 sns.it.chosun.com\n\n\n127.0.0.1 sports.chosun.com\n\n\n127.0.0.1 thestory.chosun.com\n\n\n127.0.0.1 weeklybiz.chosun.com\n\n\n127.0.0.1 woman.chosun.com\n\n\n127.0.0.1 writers.chosun.com\n\n\n\n\xa0\n\n붙여넣기\n\n\xa0\n\n저장(관리자모드로)\n\n-------------------------------------------------------------------------------------------------------------------\n\n이제 조선일보는 BYE\n\n\xa0\n\np.s. 중/동도 시간나면 업데이트 하겠습니다. 주소 추가해서 다시올려주셔도 되요',
#  'comments': ['좋은정보~~',
#   '이렇게하면 조선일보놈들 영원히 ㅂㅂ할수있는건가요?',
#   '이걸 어디에 붙인다는 거에요?\n효과는?',
#   'C:\\Windows\\System32\\drivers\\etc\\\n\n에 들어가시면 hosts파일있습니다.\n\n\n거기에 붙이시면\xa0\n\n\n조선일보 사이트를 실수로라도 들어가지 않게됩니다.\n\n\n트래픽으로 광고단가가 측정되는곳이니 개인한명은 차이없지만 다수면 차이가 생기겠죠',
#   '조선 불매는 20년 넘었네요.\xa0\n삼성 불매는 12-3년 된 것 같구요.\xa0\n남양 불매는 5-6년 된 듯..\n\xa0\n남들한테 딱히 강요는 안합니다. 혼자 불매',
#   '좋은 정보네요.']}

# %%
requests.compat.urlparse(resp.request.url)
# Out:
# ParseResult(scheme='http', netloc='www.ppomppu.co.kr', path='/zboard/zboard.php', params='', query='id=freeboard&page=11', fragment='')
