# %%
# 1. 데이터 불러오기
# 이태까지 넘파이 관점 이제 데이터 분석 관점

# %%
import pandas as pd ## 넘파이 메소드 다 불러온다.

# %%
% matplotlib inline

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
# !pip install version-information ## 주피터 노트북 상에서 버전관리할때
# Out:
# ...
#   Stored in directory: C:\Users\legen\AppData\Local\pip\Cache\wheels\1f\4c\b3\1976ac11dbd802723b564de1acaa453a72c36c95827e576321
# Successfully built version-information
# ...
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# %load_ext version_information  ## 추가 매직메소드 extension를 사용하겠다. version_information라는
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-25b544523034> in <module>()
# ----> 1 get_ipython().run_line_magic('load_ext', 'version_information  ## 추가 매직메소드 extension를 사용하겠다. version_information라는')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2093                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2094             with self.builtin_trap:
# -> 2095                 result = fn(*args,**kwargs)
#    2096             return result
#    2097
#
# <decorator-gen-66> in load_ext(self, module_str)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %%
#설치할떄는 - 사용할떄는 _
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %version_information  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %version_information   #선생 3.7.4쓴다
# Out:
# Software versions
# Python 3.6.4 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 6.2.1
# OS Windows 10 10.0.17134 SP0
# Tue Jul 23 12:13:46 2019 ¢¥eCN©öI¡¾©ö C¡ÍA¨ª¨öA

# %%
# %version_information numpy,pandas
# Out:
# Software versions
# Python 3.6.4 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 6.2.1
# OS Windows 10 10.0.17134 SP0
# numpy 1.14.2
# pandas 0.22.0
# Tue Jul 23 12:14:42 2019 ¢¥eCN©öI¡¾©ö C¡ÍA¨ª¨öA

# %%
## 저자정보를 넣고싶다 애는안된다. 또다른애

# %%
# !pip install watermark
# Out:
# ...
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# %load_ext watermark

# %%
# %watermark -a'문근영' -p numpy,pandas  ## 누가만들었는지 워터마크 박아넣을수있따.+ 버전확인도됨
## 깃으로 이런식으로
# Out:
# 문근영
#
# numpy 1.14.2
# pandas 0.22.0

# %%
# %watermark -a'문근영' -d -p numpy,pandas 

#git에서 사용할 수 있다.  ## 누가만들었는지 워터마크 박아넣을수있따.+ 버전확인도됨
## 언제 어떤버전으로 분석했는지 깃에 관리해줄수 있따.
## 이거 박아놓고 깃 사용하며 관리를 한다.
# Out:
# 문근영 2019-07-23
#
# numpy 1.14.2
# pandas 0.22.0

# %%
## 랭글링 첫번쨰 하는일 데이터 불러오기

# %%
pd.read_# 펑션 스넹크방식

# %%
[x for x in dir(pd) if x.startswith('read_')] ## 18개의 데이터 타입을 불러올수 있따.
                                            ## sql 디비에서 불러와서 전처리 시킬수 있다., json, xml html
# Out:
# ['read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_msgpack',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table']

# %%
## startswith 로 포문돌려서 dir 뒤짐

# %%
data = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", header=None)## 옵션이 많다 데이터 지좆대로 한다. 경우에 따라서 옵션 하나씩하나씩 바꿔가면서 불러와야함, 파일위치, 버퍼만 입력
            ## 버퍼 인터넷버퍼 웹데이터 링크만 넣어줘가지고 가져올수 있따.
    ## 헤더가 없이 불러와졌따.
    ## 헤더란 옵션이 있다.
    ## 옵션찾아가지고 개판인 데이터 잘 불러오기 none 헤더없으면 자동적으로 숫자를 붙여준다. 넘파이에서는 안되는거지만 판다스에서는 자동적으로 이름붙어줄떄 숫자로 붙여줌 
    ## ex 엘라스티서치에서는 이름을 자동적으로 히어로 이름으로 붙여준다. 판다스에서는 숫자로

# %%
data[0] ## data,0 안된다 키방식으로 한다. # re!! 튜플로 어캐뽑지? =>  loc, iloc 로 튜플로 뽑을수 있다.
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: 0, Length: 150, dtype: float64

# %%
# 랭글링 불러와서 전처리 
# 그래프 그려보자
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A9C4E9A58>,
# ...
#       dtype=object)

# %%
data.mean() ## 엑시스 개념 들어감 조작할수 있고 이런거
# Out:
# 0    5.843333
# 1    3.054000
# 2    3.758667
# 3    1.198667
# dtype: float64

# %%
## 분석가마다 방식다름
## 데이터 잘 불러온다음
# 1.data.info

# %%
data ## index 를 내마음대로 지정할수있지만 지정안하면 0부터 숫자붙음 rangeindex
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
data.info() ## rangeindfex 인덱스를 지정하지 않았다. 0부터 149까지 150개 데이터 
            ## 전체 행개수  컬럼 5개다 
            ## 150개가 null=> missing data 라고 한다. 처리방법  삭제, 디폴트값으로 채운다, interpolate 한다
            ## 문자열을 오브젝트 5번쨰 컬럼 문자열 판다스는 문자열을 object클래스라고 한다
            ## object 문자열 타입
            ## 메모리 사용량이 5.9kb 모든 데이터를 메모리에 올린다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# 4    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
## 데이터 타입에 따라 분석 종류가 달라진다. 카테고리
# 기계학습한다 하면 데이터는 다 숫자데이터로 변형

# %%
## 첫번쨰로 info()한다.
## 두번쨰로 data.describe()

# %%
data.describe() # 각 컬럼에 대한 통계값을 보여준다.
                ## size(널값 미싱데이터 포함), 카운트 (미싱데이터 포함 x)
                ## 평균, 표준편차 => 정규분포(중요, 큰수의법칙(수가 크면 자기 고유분포에 가까워진다. 중심극한정리=>데이터가 커지면 정규분포에 가까워 진다.)
                ## mean,이랑 std 표준편차 정규성을 알수있음. 밑에 5개는 박스플라워(아웃라이어,인맥스,)
                ## 숫자보다 그래프 보는게 훨씬 편함 -> 예쁘게 그려진걸로
                
                ## 외도(스큐)왼쪽으로 쏠렸냐 오른쪽으로 쏠렸냐, 첨도() 뾰족하냐 아니냐
                ## opt
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.skew()
# Out:
# 0    0.314911
# 1    0.334053
# 2   -0.274464
# 3   -0.104997
# dtype: float64

# %%
data.kurt()
# Out:
# 0   -0.552064
# 1    0.290781
# 2   -1.401921
# 3   -1.339754
# dtype: float64

# %%
data.kurtosis()
# Out:
# 0   -0.552064
# 1    0.290781
# 2   -1.401921
# 3   -1.339754
# dtype: float64

# %%
# 등을 통해 정규분포정도를 암
# 정규성을 띠는 데이터는 => 데이터를 잘 수집했다. 이거야

# %%
data.boxplot() ## RE!!

#나사같은에 아웃라이어  ## 나사있으면 아웃라이어 나가는 데이터값들이 있다.

# %%
data.describe(include='object')
# Out:
#                       4
# count               150
# unique                3
# top     Iris-versicolor
# freq                 50

# %%
data.describe(include='all')
# Out:
#                  0           1           2           3                4
# count   150.000000  150.000000  150.000000  150.000000              150
# unique         NaN         NaN         NaN         NaN                3
# top            NaN         NaN         NaN         NaN  Iris-versicolor
# freq           NaN         NaN         NaN         NaN               50
# mean      5.843333    3.054000    3.758667    1.198667              NaN
# std       0.828066    0.433594    1.764420    0.763161              NaN
# min       4.300000    2.000000    1.000000    0.100000              NaN
# 25%       5.100000    2.800000    1.600000    0.300000              NaN
# 50%       5.800000    3.000000    4.350000    1.300000              NaN
# 75%       6.400000    3.300000    5.100000    1.800000              NaN
# max       7.900000    4.400000    6.900000    2.500000              NaN

# %%
data.describe(include=['float64'])
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.describe(include=['number'])
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
## describe 를 보면서 데이터의 분포를 분석

# %%
import seaborn as sns

# %%
# s statiscal 통계쪽 그래프 판다스기반
# 통계 + 예쁨
# 분석적관점

# %%
data.rename({4:'species'}, axis=1, inplace=True)

# %%
sns.pairplot(data, hue='species') # ## 각데이터별로 분포도 알수있다
## 파란색 어떠한 각도보더라도 분별이 되있따 판별이 잘되있는 데이터
## 주황색 초록색 섞여있음 예측모델 정확도가 낮다

## 이모델보고 스케일링 어떻게 할까 알수있다.
## 데이터 안예쁘다 하면 전처리( str->int 기계학습 모델에 넣으려면)

# %%
olds = pd.read_csv("C:\\Users\\legen\\Desktop\\ttt.csv",encoding = 'cp949') ## en

# %%
olds = pd.read_csv("C:\\Users\\legen\\Desktop\\ttt.csv",engine = 'python') ## en

# %%
olds = pd.read_csv("C:\\Users\\legen\\Desktop\\xxxcsv.csv",index_col='연번',engine = 'python',encoding='cp949') ## 공공데이터 앵간하면 이걸로 다됨
                                ## 불러들이때불터 index 컬럼정할수 있따.

# %%
olds = pd.read_csv("C:\\Users\\legen\\Desktop\\xxxcsv.csv",engine = 'python',encoding='cp949') ## 공공데이터 앵간하면 이걸로 다됨
                                ## 불러들이때불터 index 컬럼정할수 있따.

# %%
olds.set_index('연번', inplace=False) ## 인덱스 지정하는 방식 이거 임뮤터블 재할당해줘야함 inplace=True 자기자신 바껴주는거 원본 도 바뀐다
                                    ## 자기자신 바뀌고 return 이 non inplace ture 하면
#olds_raw = olds.copy() ## 딥카피 값만 원본저장
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
# 구분        260 non-null object
# 시 설 명     260 non-null object
# 입소정원      260 non-null int64
# 시설 소재지    260 non-null object
# 전화번호      260 non-null object
# dtypes: int64(1), object(4)
# memory usage: 10.2+ KB

# %%
## 컬럼 10개인데 테이터 81개 의미있는 분석 안나온다
## 연번 필요없는데 연번을 인덱스로 만들거나 or 삭제하는방법

# %%
## 두번쨰방법 없애버린다

# %%
olds.info()  # 아까 rangeindex 에서 intindex로바뀌었다.  효율은 range index 효율 어디서 어디까지
            # intindex 하나하나씩 다함
            # range 동시에 리니어로 쫙
            # but 지우는게 가장 효과적!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 6.4+ KB

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.reset_index()  ## 지우는것보다 인덱스를 새로 만듬, 레인지가 새로생김   ## re!! reset_index 왜하는건지 연변은 왜없어지는지, info 다시 레인지나옴
# Out:
#     index  연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  \
# 0       0   1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80
# 1       1   2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00
# 2       2   3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00
# 3       3   4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74
# 4       4   5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11
# 5       5   6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00
# 6       6   7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64
# 7       7   8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68
# 8       8   9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84
# 9       9  10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02
# 10     10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09
# ...

# %%
olds.reset_index(drop=True)  ## 지움
                                ## 반영시킬거면 inplace =True
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds = pd.read_csv("C:\\Users\\legen\\Desktop\\xxxcsv.csv",engine = 'python',encoding='cp949') ## 공공데이터 앵간하면 이걸로 다됨
                                ## 불러들이때불터 index 컬럼정할수 있따.

# %%
olds.reset_index(drop=True)  ## 지움
                                ## 반영시킬거면 inplace =True
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.drop(colums="연번", inplace=True)  ## 컬럼 지우는 방법

# %%
olds.drop(labels=[1,3], inplace=True)  ## 로우를 지울수 있따.

# %%
olds.drop(labels=['소재지'], axis = 1)  ## 로우를 지울수 있따. ##칼럼 로우 다 지울수 있으므로 이름이 인덱스가 아니라 라벨
                                        ##
# Out:
#     연번        경로당명칭    부지(㎡)   건물(㎡)  회원총계  남자회원  여자회원          전화번호  \
# 2    3      홍실1차경로당    90.00   90.00    41     9    32  053-551-8286
# 4    5      홍실2차경로당   154.11  154.11    31     0    31  053-556-8220
# 5    6        장수경로당   159.00  112.00    38     5    33  053-572-8123
# 6    7      내당2동경로당    93.00   62.64    35    10    25  053-571-1637
# 7    8        내당경로당   216.00  183.68    40     5    35  053-565-0437
# 8    9        천일경로당   165.00  172.84    17     2    15  053-566-3077
# 9   10        삼화경로당   130.00  136.02    30     5    25  053-565-5084
# 10  11      삼익맨션경로당   109.09  109.09    25     0    25  053-567-7765
# 11  12      광장타운경로당    76.00   76.00    38     4    34  053-563-3087
# 12  13        명우경로당    49.60   49.60    24     5    19  053-558-5006
# 13  14     삼익뉴타운경로당    66.00  132.00    45    13    32  053-562-1237
# 14  15      내당4동경로당   142.00   60.10    39    23    16  053-562-4594
# 15  16        내우경로당   169.50  148.51    27     0    27  053-564-4346
# ...

# %%
olds
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds = olds_raw.copy()

# %%
olds.drop('연번',axis=1, inplace=True)  ##

# %%
olds.rename_axis ## deprecated 되서 rename 쓴다

# %%
olds.rename({'소재지':'주소'}, axis=1, inplace=True) ## 매퍼 해싱 자료형태 딕셔너리 => 딕셔너리

# %%
olds["시"] = '대구광역시' ## 브로드캐스팅

# %%
olds["기준일자"].shape
## 넘파이 dtype 이랑 shape
# Out:
# (81,)

# %%
olds["기준일자"].dtype
# Out:
# dtype('O')

# %%
olds['기준일자'].astype("datetime64")  ## 왜 64? re!!
# Out:
# C:\Users\legen\Anaconda3\lib\site-packages\pandas\core\internals.py:3462: FutureWarning: Passing in 'datetime64' dtype with no frequency is deprecated and will raise in a future version. Please pass in 'datetime64[ns]' instead.
#   return self.apply('astype', dtype=dtype, **kwargs)
# 0    2017-11-10
# 1    2017-11-10
# 2    2017-11-10
# 3    2017-11-10
# 4    2017-11-10
# 5    2017-11-10
# 6    2017-11-10
# 7    2017-11-10
# 8    2017-11-10
# 9    2017-11-10
# 10   2017-11-10
# 11   2017-11-10
# 12   2017-11-10
# 13   2017-11-10
# 14   2017-11-10
# 15   2017-11-10
# 16   2017-11-10
# 17   2017-11-10
# 18   2017-11-10
# 19   2017-11-10
# 20   2017-11-10
# 21   2017-11-10
# 22   2017-11-10
# 23   2017-11-10
# 24   2017-11-10
# 25   2017-11-10
# 26   2017-11-10
# 27   2017-11-10
# 28   2017-11-10
# 29   2017-11-10
#         ...
# 51   2017-11-10
# 52   2017-11-10
# 53   2017-11-10
# 54   2017-11-10
# 55   2017-11-10
# 56   2017-11-10
# 57   2017-11-10
# 58   2017-11-10
# ...

# %%
olds = olds_raw

# %%
pd.to_datetime(olds["기준일자"]) ## 판다스 시계열분석 할떄 다시 자세히 한다. astype 에러없이 자동으로 다바꿔주는거 에러없이
# Out:
# 0    2017-11-10
# 1    2017-11-10
# 2    2017-11-10
# 3    2017-11-10
# 4    2017-11-10
# 5    2017-11-10
# 6    2017-11-10
# 7    2017-11-10
# 8    2017-11-10
# 9    2017-11-10
# 10   2017-11-10
# 11   2017-11-10
# 12   2017-11-10
# 13   2017-11-10
# 14   2017-11-10
# 15   2017-11-10
# 16   2017-11-10
# 17   2017-11-10
# 18   2017-11-10
# 19   2017-11-10
# 20   2017-11-10
# 21   2017-11-10
# 22   2017-11-10
# 23   2017-11-10
# 24   2017-11-10
# 25   2017-11-10
# 26   2017-11-10
# 27   2017-11-10
# 28   2017-11-10
# 29   2017-11-10
#         ...
# 51   2017-11-10
# 52   2017-11-10
# 53   2017-11-10
# 54   2017-11-10
# 55   2017-11-10
# 56   2017-11-10
# 57   2017-11-10
# 58   2017-11-10
# 59   2017-11-10
# 60   2017-11-10
# 61   2017-11-10
# 62   2017-11-10
# 63   2017-11-10
# 64   2017-11-10
# 65   2017-11-10
# 66   2017-11-10
# 67   2017-11-10
# 68   2017-11-10
# 69   2017-11-10
# 70   2017-11-10
# 71   2017-11-10
# 72   2017-11-10
# 73   2017-11-10
# 74   2017-11-10
# ...

# %%
olds['주소']
# Out:
# 0            대구광역시 서구 달구벌대로361길 35-29
# 1          대구광역시 서구 서대구로8길 15 내당시영아파트
# 2        대구광역시 서구 서대구로8길 49 내당보성홍실아파트
# 3                     대구광역시 서구 통학로 46
# 4            대구광역시 서구 통학로 39 보성2차홍실타운
# 5                  대구광역시 서구 큰장로9길 9-3
# 6               대구광역시 서구 큰장로15길 14-20
# 7                 대구광역시 서구 평리로 408-13
# 8             대구광역시 서구 달구벌대로373길 2-24
# 9              대구광역시 서구 달구벌대로373길 7-5
# 10                   대구광역시 서구 서대구로 25
# 11                대구광역시 서구 달구벌대로 1707
# 12             대구광역시 서구 평리로 214 광명아파트
# 13          대구광역시 서구 평리로 236 삼익뉴타운아파트
# 14                 대구광역시 서구 서대구로3길 43
# 15               대구광역시 서구 당산로51길 28-5
# 16            대구광역시 서구 당산로 260 코오롱아파트
# 17              대구광역시 서구 달구벌대로337길 29
# 18                 대구광역시 서구 서대구로7길 46
# 19                 대구광역시 서구 달서로39길 24
# 20              대구광역시 서구 통학로49길 30-27
# 21                대구광역시 서구 북비산로61길 34
# 22              대구광역시 서구 북비산로61길 43-5
# 23                 대구광역시 서구 통학로52길 30
# 24               대구광역시 서구 북비산로75길 2-3
# ...

# %%
olds['주소']# object 문자열
# Out:
# 0            대구광역시 서구 달구벌대로361길 35-29
# 1          대구광역시 서구 서대구로8길 15 내당시영아파트
# 2        대구광역시 서구 서대구로8길 49 내당보성홍실아파트
# 3                     대구광역시 서구 통학로 46
# 4            대구광역시 서구 통학로 39 보성2차홍실타운
# 5                  대구광역시 서구 큰장로9길 9-3
# 6               대구광역시 서구 큰장로15길 14-20
# 7                 대구광역시 서구 평리로 408-13
# 8             대구광역시 서구 달구벌대로373길 2-24
# 9              대구광역시 서구 달구벌대로373길 7-5
# 10                   대구광역시 서구 서대구로 25
# 11                대구광역시 서구 달구벌대로 1707
# 12             대구광역시 서구 평리로 214 광명아파트
# 13          대구광역시 서구 평리로 236 삼익뉴타운아파트
# 14                 대구광역시 서구 서대구로3길 43
# 15               대구광역시 서구 당산로51길 28-5
# 16            대구광역시 서구 당산로 260 코오롱아파트
# 17              대구광역시 서구 달구벌대로337길 29
# 18                 대구광역시 서구 서대구로7길 46
# 19                 대구광역시 서구 달서로39길 24
# 20              대구광역시 서구 통학로49길 30-27
# 21                대구광역시 서구 북비산로61길 34
# 22              대구광역시 서구 북비산로61길 43-5
# 23                 대구광역시 서구 통학로52길 30
# 24               대구광역시 서구 북비산로75길 2-3
# ...

# %%
x = olds['주소'].str ## re!!
x.

# %%
x[0][0][0][0]
# Out:
# '대'

# %%
x = x.replace('대구광역시','')

# %%
x = x.replace('서구','')

# %%
olds["구"]='서구'
olds["시"]='대구 광역시'

# %%
x.match  ## 정규식으로 길 찾아보기
# Out:
# <bound method StringMethods.match of <pandas.core.strings.StringMethods object at 0x0000020AA8E7A0F0>>

# %%
x

# %%
olds["기준일자"].describe()  ## 유니크가 1이고 날짜 하나 아주 구데기
# Out:
# count             81
# unique             1
# top       2017-11-10
# freq              81
# Name: 기준일자, dtype: object

# %%
olds
# Out:
#           경로당명칭                               주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 6.4+ KB

# %%
olds
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
## 기준일자 str인데 시간 날짜를 알려주는 데이터타입 있을까 없을까 궁금하누

# %%
## 시간날짜 패키지 time, calender, datatime 패키지
import time ,calender, datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-130-a69f355acc6f> in <module>()
#       1 ## 시간날짜 패키지 time, calender, datatime 패키지
# ----> 2 import time ,calender, datetime
#
# ModuleNotFoundError: No module named 'calender'

# %%
time.time()
# Out:
# 1563863635.0538685

# %%
## datetime util 이라는 서드파티 라이브러리를 쓴다.

# %%
import datetime

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
# datetime 이있는데 datetime이있누
# datetime 시간날짜 동시 date 날짜, timedelta 시간간격 몇시간뒤 이런거 timezone 시간대가 여러개인나라 time 시간만
from datetime import datetime

# %%
a = datetime  ## 필수적인거 3가지 [ ] 옵션
a = datetime(2019,7,22)

# %%
a
# Out:
# datetime.datetime(2019, 7, 22, 0, 0)

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'astimezone',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'dst',
#  'fold',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'now',
#  'replace',
#  'resolution',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'today',
#  'toordinal',
#  'tzinfo',
#  'tzname',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'weekday',
#  'year']

# %%
a.year
# Out:
# 2019

# %%
a.month
# Out:
# 7

# %%
a.day
# Out:
# 22

# %%
import timedelta
b = timedelta(3)

a+b #3일추가
a-b #3일뺴짐
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-144-e2e1403506d0> in <module>()
# ----> 1 import timedelta
#       2 b = timedelta(3)
#       3
#       4 a+b #3일추가
#       5 a-b #3일뺴짐
#
# ModuleNotFoundError: No module named 'timedelta'

# %%
a = datetime.striptime('2019-07-23', '%Y-%m-%d')   ## ㅅ각 객체별로 저장 년도 달 이름
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-ee9601208cf0> in <module>()
# ----> 1 a = datetime.striptime('2019-07-23', '%Y-%m-%d')
#
# AttributeError: type object 'datetime.datetime' has no attribute 'striptime'

# %%
a
# Out:
# datetime.datetime(2019, 7, 22, 0, 0)

# %%
## 넘파이는 타입캐스팅 지원해준다. 파이썬은 타입캐스팅 안되고 객체 다시 새로 생성해준다. 다시 재할당 원래 타입캐스팅은 메모리도 같다

# %%
a = '123'

# %%
id(a)
# Out:
# 2244697190672

# %%
a = int(a)

# %%
a
# Out:
# 123

# %%
id(a)
# Out:
# 2012970272

# %%
## look for 이용해 캐스팅 기법 찾을수 있따.

# %%
import numpy as np
np.lookfor('casting')
# Out:
# Search results for 'casting'
# ----------------------------
# numpy.abs
#     Calculate the absolute value element-wise.
# numpy.add
#     Add arguments element-wise.
# numpy.cos
#     Cosine element-wise.
# numpy.exp
#     Calculate the exponential of all elements in the input array.
# numpy.log
#     Natural logarithm, element-wise.
# numpy.mod
#     Return element-wise remainder of division.
# numpy.sin
#     Trigonometric sine, element-wise.
# numpy.tan
#     Compute tangent element-wise.
# numpy.cbrt
#     Return the cube-root of an array, element-wise.
# numpy.ceil
#     Return the ceiling of the input, element-wise.
# numpy.conj
#     Return the complex conjugate, element-wise.
# numpy.cosh
#     Hyperbolic cosine, element-wise.
# numpy.exp2
#     Calculate `2**p` for all `p` in the input array.
# numpy.fabs
#     Compute the absolute values element-wise.
# numpy.fmax
#     Element-wise maximum of array elements.
# numpy.fmin
#     Element-wise minimum of array elements.
# ...

# %%
a = np.array([1,2,3]) #
a
# Out:
# array([1, 2, 3])

# %%
a.astype('float64') ## 타입 바꾸는거 astype으로 쓰면 된다. re!! 왜 원소 여러개 생김? 이게타빙ㅂㅁ변경? # int 8이던게 64비트로 가니까 빈공간이 0으로 채워진다.
# Out:
# array([1., 0., 0., 0., 2., 0., 0., 0., 3., 0., 0., 0.])

# %%
a.dtype= 'int8'  ## 타입바꾸면 값이 이상해 진다.데이터 타입만 바꿀수가 없다.

# %%
a
# Out:
# array([1, 0, 0, 0, 2, 0, 0, 0, 3, 0, 0, 0], dtype=int8)
