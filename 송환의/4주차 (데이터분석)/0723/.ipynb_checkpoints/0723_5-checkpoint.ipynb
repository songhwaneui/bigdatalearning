# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
## size 
## rename 이름바꿀떄, astype 카테고리 바꿀떄

# %%
## 카테고리 또는 object val

# %%
tips.sex.value_counts() ## 카테고리별 갯구 별 표현
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.unique()  ## femaile male 외 카테고리 넣으면 에러남
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
tips.sex.nunique()  ## 카테고리 갯수
# Out:
# 2

# %%
## object.str 있었는데

# %%
t = tips.sex.cat  ### 카테고뢰 추가 관리 하는 거

# %%
t.codes ## 문자로 관리하면 비효율적이므로 카테고리 갯수만큼 숫자로 관리를 한다다. 1 여자 0 남자 내부적으로는 이렇게 효율적 관리
        ## 나중에 기계학습할떄 숫자만 사용 라벨인코딩을 할떄 코드를 써서 하면 편하다 rere!!
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     1
# 12     0
# 13     0
# 14     1
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     0
# 21     1
# 22     1
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1
#       ..
# 214    1
# 215    1
# 216    0
# 217    0
# 218    0
# 219    1
# 220    0
# 221    1
# 222    0
# 223    1
# 224    0
# 225    1
# 226    1
# 227    0
# 228    0
# 229    1
# 230    0
# 231    0
# 232    0
# 233    0
# 234    0
# 235    0
# 236    0
# 237    0
# 238    1
# 239    0
# 240    1
# 241    0
# 242    0
# 243    1
# Length: 244, dtype: int8

# %%
tips['_size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: _size, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-7d12d5c4111e> in <module>()
# ----> 1 tips.groupby("_size",'sex')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5157         if level is None and by is None:
#    5158             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5159         axis = self._get_axis_number(axis)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# --> 357                          .format(axis, type(self)))
# ...

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.value_counts().loc['Male'] ## re!! loc 뭐지
tips.sex.value_counts().iloc[0] ## re!! loc 뭐지
# Out:
# 157

# %%
tips.sex.value_counts().plot.bar()  ## idex는 x축 ~~ 결과에 .plot만 쓰면 그래프 그려줌
## 수집, 기초분석 다 복습해야함 선동언 올떄까지 나머지 3주 더 바쁘다

# %%
to[-----]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.rename({'size':'_size'}, axis=1, inplace=True)  ## 이름바꾸고 타입 바꾸고

# %%
tips['_size'] = tips['_size'].astype('category') ## re

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# _size         244 non-null category
# dtypes: category(5), float64(2)
# memory usage: 5.8 KB
