# %%
import pandas as pd

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbf in position 0: invalid start byte
olds = pd.read_csv('ttt.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-ce62cba19624> in <module>
# ----> 1 olds = pd.read_csv('ttt.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
olds = pd.read_csv('ttt.csv', encoding="euc-kr")

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds = pd.read_csv('ttt.csv', encoding="cp949")
# cp949하면 해결될 확률이 50%

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
# encodingerror 나면 첫번째 옵션은 encoding= 이 아님!
olds = pd.read_csv('ttt.csv', engine="python")
olds # 깨짐
# Out:
#     ����            ��δ��Ī                                          ������  \
# 0      1          ������δ�               �뱸������ ���� �ޱ������361�� 35-29
# 1      2   �ÿ�����(��)��δ�          �뱸������ ���� ���뱸��8�� 15 ����ÿ�����Ʈ
# 2      3        ȫ��1����δ�        �뱸������ ���� ���뱸��8�� 49 ���纸��ȫ�Ǿ���Ʈ
# 3      4         Ȳ������δ�                          �뱸������ ���� ���з� 46
# 4      5        ȫ��2����δ�            �뱸������ ���� ���з� 39 ����2��ȫ��Ÿ��
# 5      6           �����δ�                       �뱸������ ���� ū���9�� 9-3
# 6      7       ����2����δ�                    �뱸������ ���� ū���15�� 14-20
# 7      8           �����δ�                        �뱸������ ���� �򸮷� 408-13
# 8      9            õ�ϰ�δ�                �뱸������ ���� �ޱ������373�� 2-24
# 9     10           ��ȭ��δ�                 �뱸������ ���� �ޱ������373�� 7-5
# 10    11         ���͸Ǽǰ�δ�                         �뱸������ ���� ���뱸�� 25
# ...

# %%
olds = pd.read_csv('ttt.csv', engine="python", encoding='cp949')
# 공공 데이터는 이렇게 하면 99% 불러짐
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.info() # 실질적으로 분석하는 의미가 없음 그냥 정보인 데이터 데이터가 너무 작음
# 그런데 만약 분석을 한다고 하면 어떻게 할까?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 6.4+ KB

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
# 연번 필요없음 인덱스가 있으니까. 두가지 방법 1) 연번을 인덱스로 만들거나 2) 연번을 삭제하거나
# 1) 연번을 인덱스로
# 불러들일 때부터 인덱스를 정함
# 안좋아하는 사람도 있음
olds = pd.read_csv('ttt.csv', index_col='연번',
                   engine="python", encoding='cp949')
olds
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds = pd.read_csv('ttt.csv',
                   engine="python", encoding='cp949')
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
# 2) 인덱스를 불러들이고 나서 정함
olds.set_index('연번') # index를 두 개 이상 붙일 수 있음 <- keys
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds # 본래 df는 안 바뀌었음. 적용 안됐음.
# 우리가 아는 기법을 쓰려면 재할당 해야 하지만
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
# olds.set_index('연번', inplace=True) # 재할당 안 해도 자기 자신이 바뀜
# 자기 자신이 바뀌면 원래 데이터 바뀌어버림
# 그래서 원본 보관함

olds_raw = olds.copy()

# %%
olds.set_index('연번', inplace=True) # inplace=True는 썼다가 큰일날 경우가 있기 때문에
# inplace=True안 해보고 잘 바뀐 것 같으면 True
# inplace=True 하면 return None

# %%
olds
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.info() # 지금은 Int64Index (원래 RangeIndex였는데)
# 효율적인 건 RangeIndex가 더 효율적
# range~는 범위잡아서 보관하는데 얘는 하나씩 다 보관
# range 객체 하나만 가지고 있으면 됨
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 1 to 81
# Data columns (total 9 columns):
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 6.3+ KB

# %%
# 3) 없애 버린다 <- 가장 효과적

# %%
olds.reset_index() # 지우는 것보다 인덱스를 새로 만드는 것
# range index를 새로 만든다.
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.reset_index(drop=True) # 기존에 있는 연번이 없어짐
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.reset_index(drop=True, inplace=True) #반영

# %%
olds
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds_raw
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds = pd.read_csv('ttt.csv', engine="python", encoding='cp949')

# %%
# Signature:
# olds.drop(
#     labels=None,
#     axis=0,
#     index=None,
#     columns=None,
#     level=None,
#     inplace=False,
#     errors='raise',
# )
############ column 지우기 drop
olds.drop(columns='연번') # 반영 안됨
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.drop(columns='연번', inplace=True)

# %%
olds
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.drop(labels=0) # row를 없앰
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# 11      광장타운경로당              대구광역시 서구 달구벌대로 1707    76.00   76.00    38     4
# ...

# %%
olds.drop(labels=[2,3,4,]) # 필요없는 데이터 지워버림
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# 11      광장타운경로당              대구광역시 서구 달구벌대로 1707    76.00   76.00    38     4
# 12        명우경로당           대구광역시 서구 평리로 214 광명아파트    49.60   49.60    24     5
# 13     삼익뉴타운경로당        대구광역시 서구 평리로 236 삼익뉴타운아파트    66.00  132.00    45    13
# ...

# %%
olds.drop(labels=[2,3,4,], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-b373d61fb473> in <module>
# ----> 1 olds.drop(labels=[2,3,4,], axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
olds.drop(labels=['소재지'], axis=1) # column 지울 때도 사용할 수 있기 때문에
# 이름이 index가 아니고 labels인 것
# 자유자재로 지울 수 있어야 함
# 가능한 중복된 의미가 없는 게 좋은 데이터 소스
# 사실 소재지 필요 있을 것임
# Out:
#           경로당명칭    부지(㎡)   건물(㎡)  회원총계  남자회원  여자회원          전화번호        기준일자
# 0         내서경로당   139.80  160.80    40     0    40  053-554-0739  2017-11-10
# 1    시영내당(아)경로당   119.00  119.00    24     6    18  053-567-9772  2017-11-10
# 2       홍실1차경로당    90.00   90.00    41     9    32  053-551-8286  2017-11-10
# 3        황성정경로당   134.74  134.74    40    10    30  053-553-9874  2017-11-10
# 4       홍실2차경로당   154.11  154.11    31     0    31  053-556-8220  2017-11-10
# 5         장수경로당   159.00  112.00    38     5    33  053-572-8123  2017-11-10
# 6       내당2동경로당    93.00   62.64    35    10    25  053-571-1637  2017-11-10
# 7         내당경로당   216.00  183.68    40     5    35  053-565-0437  2017-11-10
# 8         천일경로당   165.00  172.84    17     2    15  053-566-3077  2017-11-10
# 9         삼화경로당   130.00  136.02    30     5    25  053-565-5084  2017-11-10
# 10      삼익맨션경로당   109.09  109.09    25     0    25  053-567-7765  2017-11-10
# ...

# %%
olds = olds_raw.copy()
# 원본을 살려두면 언제든지 돌아갈 수 있음.

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.drop('연번', axis=1, inplace=True)

# %% [markdown]
# label 대신 column 써도 됨 column 쓰면 굳이 axis 안 써도 된다.
# 추가할 수도 있다.

# %% [markdown]
# 소재지 쪼개기

# %%
# 이름 바꾸기
# olds.rename_axis는 deplicate돼서 rename쓸 것
olds.rename({'소재지':'주소'}, axis=1) # mapper는 dectionary 형태
# 항상 axis가 있으면 조심
# 반영 안 된다.
# Out:
#           경로당명칭                               주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.rename({'소재지':'주소'}, axis=1, inplace=True)

# %%
olds # 반영됐음
# Out:
#           경로당명칭                               주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds['시'] = olds['주소']
# 시가 없으면 뒤에를 이걸로 해버림

# %%
olds['시'] = '대구광역시' # broadcasting
olds
# Out:
#           경로당명칭                               주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 경로당명칭    81 non-null object
# 주소       81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# 시        81 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.4+ KB

# %%
olds['기준일자']
# Out:
# 0     2017-11-10
# 1     2017-11-10
# 2     2017-11-10
# 3     2017-11-10
# 4     2017-11-10
# 5     2017-11-10
# 6     2017-11-10
# 7     2017-11-10
# 8     2017-11-10
# 9     2017-11-10
# 10    2017-11-10
# 11    2017-11-10
# 12    2017-11-10
# 13    2017-11-10
# 14    2017-11-10
# 15    2017-11-10
# 16    2017-11-10
# 17    2017-11-10
# 18    2017-11-10
# 19    2017-11-10
# 20    2017-11-10
# 21    2017-11-10
# 22    2017-11-10
# 23    2017-11-10
# 24    2017-11-10
# 25    2017-11-10
# 26    2017-11-10
# 27    2017-11-10
# 28    2017-11-10
# 29    2017-11-10
#          ...
# 51    2017-11-10
# 52    2017-11-10
# 53    2017-11-10
# 54    2017-11-10
# 55    2017-11-10
# 56    2017-11-10
# 57    2017-11-10
# 58    2017-11-10
# 59    2017-11-10
# 60    2017-11-10
# 61    2017-11-10
# 62    2017-11-10
# 63    2017-11-10
# 64    2017-11-10
# 65    2017-11-10
# 66    2017-11-10
# 67    2017-11-10
# 68    2017-11-10
# 69    2017-11-10
# 70    2017-11-10
# 71    2017-11-10
# ...

# %%
olds['기준일자'].dtype # 넘파이 기반이니까 당연히 됨
# Out:
# dtype('O')

# %%
olds['기준일자'].shape
# Out:
# (81,)

# %%
olds['기준일자'].astype('datetime')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    2010     try:
# -> 2011         npdtype = np.dtype(dtype)
#    2012     except Exception:
#
# TypeError: data type "datetime" not understood
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-a68315cb8fa8> in <module>
# ----> 1 olds['기준일자'].astype('datetime')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
# ...

# %%
olds['기준일자'].astype('datetime64')
# 이름 끝에 계속 64가 붙음
# 얘는 inplace가 없기 때문에 재할당 해줘야 한다.
# Out:
# 0    2017-11-10
# 1    2017-11-10
# 2    2017-11-10
# 3    2017-11-10
# 4    2017-11-10
# 5    2017-11-10
# 6    2017-11-10
# 7    2017-11-10
# 8    2017-11-10
# 9    2017-11-10
# 10   2017-11-10
# 11   2017-11-10
# 12   2017-11-10
# 13   2017-11-10
# 14   2017-11-10
# 15   2017-11-10
# 16   2017-11-10
# 17   2017-11-10
# 18   2017-11-10
# 19   2017-11-10
# 20   2017-11-10
# 21   2017-11-10
# 22   2017-11-10
# 23   2017-11-10
# 24   2017-11-10
# 25   2017-11-10
# 26   2017-11-10
# 27   2017-11-10
# 28   2017-11-10
# 29   2017-11-10
#         ...
# 51   2017-11-10
# 52   2017-11-10
# 53   2017-11-10
# 54   2017-11-10
# 55   2017-11-10
# 56   2017-11-10
# 57   2017-11-10
# 58   2017-11-10
# 59   2017-11-10
# 60   2017-11-10
# 61   2017-11-10
# 62   2017-11-10
# 63   2017-11-10
# 64   2017-11-10
# 65   2017-11-10
# 66   2017-11-10
# 67   2017-11-10
# 68   2017-11-10
# 69   2017-11-10
# 70   2017-11-10
# 71   2017-11-10
# 72   2017-11-10
# 73   2017-11-10
# 74   2017-11-10
# ...

# %%
olds['기준일자'] = olds['기준일자'].astype('datetime64')

# %%
olds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 경로당명칭    81 non-null object
# 주소       81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null datetime64[ns]
# 시        81 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# 기준일자의 datatype이 datetime64로 바뀌었음.
# 그럼 뭐가좋음?

# %%
olds['기준일자'].describe() # 의미없는 데이터..
# Out:
# count                      81
# unique                      1
# top       2017-11-10 00:00:00
# freq                       81
# first     2017-11-10 00:00:00
# last      2017-11-10 00:00:00
# Name: 기준일자, dtype: object

# %% [markdown]
# 그래서 제일 처음에 데이터 한 번 다 봐야 하는 것

# %% [markdown]
# 판다스 만든 사람은 마음이 넓음. 요청하면 다 만들어줌.
# 그래서 너무 많음.
# 어느 순간부터 판다스가 계속 커지고 편해지고 파이썬이 너무 막강해지면서
# 파이썬이 너무 커짐.
# 싸이킷과 판다스랑 연동이 잘 안됐는데 지금은 95% 이상 연동됨.
# 최근 구글에서도 텐서플로우가 판다스와 연동되는 라이브러리를 만들었음.

# %%
# astype이 불편하고 에러가 많이 나서
# pd.to_datetime() # 얘를 만들어줌

# %%
olds = olds_raw.copy()

# %%
pd.to_datetime(olds['기준일자'])
# 더한 애는 실수 있으면 어디에 실수 났는지 보여주는 애 있음 - 시계열 분석
# Out:
# 0    2017-11-10
# 1    2017-11-10
# 2    2017-11-10
# 3    2017-11-10
# 4    2017-11-10
# 5    2017-11-10
# 6    2017-11-10
# 7    2017-11-10
# 8    2017-11-10
# 9    2017-11-10
# 10   2017-11-10
# 11   2017-11-10
# 12   2017-11-10
# 13   2017-11-10
# 14   2017-11-10
# 15   2017-11-10
# 16   2017-11-10
# 17   2017-11-10
# 18   2017-11-10
# 19   2017-11-10
# 20   2017-11-10
# 21   2017-11-10
# 22   2017-11-10
# 23   2017-11-10
# 24   2017-11-10
# 25   2017-11-10
# 26   2017-11-10
# 27   2017-11-10
# 28   2017-11-10
# 29   2017-11-10
#         ...
# 51   2017-11-10
# 52   2017-11-10
# 53   2017-11-10
# 54   2017-11-10
# 55   2017-11-10
# 56   2017-11-10
# 57   2017-11-10
# 58   2017-11-10
# 59   2017-11-10
# 60   2017-11-10
# 61   2017-11-10
# 62   2017-11-10
# 63   2017-11-10
# 64   2017-11-10
# 65   2017-11-10
# 66   2017-11-10
# 67   2017-11-10
# 68   2017-11-10
# 69   2017-11-10
# 70   2017-11-10
# 71   2017-11-10
# 72   2017-11-10
# 73   2017-11-10
# 74   2017-11-10
# ...

# %%
olds['시'] = '대구광역시'

# %%
olds
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
olds.rename({'소재지':'주소'}, axis=1, inplace=True)

# %%
olds['주소']
# Out:
# 0            대구광역시 서구 달구벌대로361길 35-29
# 1          대구광역시 서구 서대구로8길 15 내당시영아파트
# 2        대구광역시 서구 서대구로8길 49 내당보성홍실아파트
# 3                     대구광역시 서구 통학로 46
# 4            대구광역시 서구 통학로 39 보성2차홍실타운
# 5                  대구광역시 서구 큰장로9길 9-3
# 6               대구광역시 서구 큰장로15길 14-20
# 7                 대구광역시 서구 평리로 408-13
# 8             대구광역시 서구 달구벌대로373길 2-24
# 9              대구광역시 서구 달구벌대로373길 7-5
# 10                   대구광역시 서구 서대구로 25
# 11                대구광역시 서구 달구벌대로 1707
# 12             대구광역시 서구 평리로 214 광명아파트
# 13          대구광역시 서구 평리로 236 삼익뉴타운아파트
# 14                 대구광역시 서구 서대구로3길 43
# 15               대구광역시 서구 당산로51길 28-5
# 16            대구광역시 서구 당산로 260 코오롱아파트
# 17              대구광역시 서구 달구벌대로337길 29
# 18                 대구광역시 서구 서대구로7길 46
# 19                 대구광역시 서구 달서로39길 24
# 20              대구광역시 서구 통학로49길 30-27
# 21                대구광역시 서구 북비산로61길 34
# 22              대구광역시 서구 북비산로61길 43-5
# 23                 대구광역시 서구 통학로52길 30
# 24               대구광역시 서구 북비산로75길 2-3
# ...

# %%
# 정규식으로 구만 뽑아낼 수 있음
x = olds['주소'].str # []가 있으면 자동완성이 잘 안 됨 주피터 버그

# %%
x.replace('대구광역시', '')
# Out:
# 0             서구 달구벌대로361길 35-29
# 1           서구 서대구로8길 15 내당시영아파트
# 2         서구 서대구로8길 49 내당보성홍실아파트
# 3                      서구 통학로 46
# 4             서구 통학로 39 보성2차홍실타운
# 5                   서구 큰장로9길 9-3
# 6                서구 큰장로15길 14-20
# 7                  서구 평리로 408-13
# 8              서구 달구벌대로373길 2-24
# 9               서구 달구벌대로373길 7-5
# 10                    서구 서대구로 25
# 11                 서구 달구벌대로 1707
# 12              서구 평리로 214 광명아파트
# 13           서구 평리로 236 삼익뉴타운아파트
# 14                  서구 서대구로3길 43
# 15                서구 당산로51길 28-5
# 16             서구 당산로 260 코오롱아파트
# 17               서구 달구벌대로337길 29
# 18                  서구 서대구로7길 46
# 19                  서구 달서로39길 24
# 20               서구 통학로49길 30-27
# 21                 서구 북비산로61길 34
# 22               서구 북비산로61길 43-5
# 23                  서구 통학로52길 30
# 24                서구 북비산로75길 2-3
# 25           서구 북비산로74길 17 새마을금고
# 26                서구 달성공원로 13-14
# 27                서구 달서로26길 35-8
# ...

# %%
olds['주소'] = x.replace('대구광역시', '')

# %%
olds
# Out:
#     연번        경로당명칭                          주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0    1        내서경로당          서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    2   시영내당(아)경로당        서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2    3      홍실1차경로당      서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3    4       황성정경로당                   서구 통학로 46   134.74  134.74    40    10
# 4    5      홍실2차경로당          서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5    6        장수경로당                서구 큰장로9길 9-3   159.00  112.00    38     5
# 6    7      내당2동경로당             서구 큰장로15길 14-20    93.00   62.64    35    10
# 7    8        내당경로당               서구 평리로 408-13   216.00  183.68    40     5
# 8    9        천일경로당           서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9   10        삼화경로당            서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10  11      삼익맨션경로당                  서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds['구'] = '서구'

# %%
olds
# Out:
#     연번        경로당명칭                          주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0    1        내서경로당          서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    2   시영내당(아)경로당        서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2    3      홍실1차경로당      서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3    4       황성정경로당                   서구 통학로 46   134.74  134.74    40    10
# 4    5      홍실2차경로당          서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5    6        장수경로당                서구 큰장로9길 9-3   159.00  112.00    38     5
# 6    7      내당2동경로당             서구 큰장로15길 14-20    93.00   62.64    35    10
# 7    8        내당경로당               서구 평리로 408-13   216.00  183.68    40     5
# 8    9        천일경로당           서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9   10        삼화경로당            서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10  11      삼익맨션경로당                  서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
olds['주소'] = olds['주소'].str.replace('서구', '')

# %%
olds
# Out:
#     연번        경로당명칭                        주소    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0    1        내서경로당           달구벌대로361길 35-29   139.80  160.80    40     0
# 1    2   시영내당(아)경로당         서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2    3      홍실1차경로당       서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3    4       황성정경로당                    통학로 46   134.74  134.74    40    10
# 4    5      홍실2차경로당           통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5    6        장수경로당                 큰장로9길 9-3   159.00  112.00    38     5
# 6    7      내당2동경로당              큰장로15길 14-20    93.00   62.64    35    10
# 7    8        내당경로당                평리로 408-13   216.00  183.68    40     5
# 8    9        천일경로당            달구벌대로373길 2-24   165.00  172.84    17     2
# 9   10        삼화경로당             달구벌대로373길 7-5   130.00  136.02    30     5
# 10  11      삼익맨션경로당                   서대구로 25   109.09  109.09    25     0
# ...
