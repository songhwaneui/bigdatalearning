# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %% [markdown]
# 데이터 244개
# 데이터 category
# 일반적인 문자 데이터는 object
# 종류가 몇 개 없는 문자 데이터 (예 : 성별) 이런 데이터를 카테고리로 해놓으면 분석할 때 편해서 판다스에서 지원하는 데이터 타입
# 카테고리는 문자열도 될 수 있고 숫자도 될 수 있는데 보통 숫자는 잘 안 쓴다.
# 얘도 미싱 데이터가 없다.
# 나중에 체크할 게 더 있음.
# 나중에는 오컴의 면도날까지 체크
# 똑같으면 simple is the best
# 그거랑 차원의 저주라는 개념이 예측모델에 들어감.
# 여기서 컬럼을 차원이라고 함.
# 차원이 많은데 데이터가 충분하지 않으면 모델이 학습이 제대로 안 돼서 왜곡됨.
# 저건 정확한 예측 모델을 만들기 어려운 데이터양
# 보통 컬럼이 20개일 때 데이터가 10만 개 이상 안 모이면 시스템화시키기 어려움.
# 분석 정확도 70%하면 그렇구나 하는데 시스템 정확도 70%는 욕함
# 그래서 두 가지 개념을 나중에 더 볼 것.
# 데이터의 충분성!
# 그래서 info()가 아주 중요함.

# %%
tips.describe()
# 여기서 size의 평균이 안 중요함! 이건 categorical data나 마찬가지
# 저 size 데이터에 대해 알고 있는 사람은 이걸 int로 안 만들고 category로 만들었을 것
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# 전체 식사비용 평균이 19.78..., tip을 2.99 정도 준다.

# %%
tips.describe(include=['category'])
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [markdown]
# 데이터 분석에서 중요한 요소 1) 프로그래밍 2) 통계, 수학 3) 도메인 지식
# 도메인 지식이 없으면 분석을 제대로 할 수 없다.

# %%
tips 
# 성별, 흡연 여부, 시간, 덩치, 요일, 총 식사비용에 따라 팁을 얼마나 주는가 하는 데이터
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# 이 안에 숨겨진 의미를 어떤 의미를 찾는가가 분석가의 역량
# 지역은 못 찾음
# 남자가 팁 많이 줄까 여자가 많이 줄까
# 담배피는 사람이?
# 요일별로 어느 요일에 많이 줄까
# 만약 예측 모델 만들면 정확하지는 않지만 어떤 요일 어떤 시간 어떤 타입의 사람이 팁을 많이 줄지 볼 수 있음

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# 크게 비싼 곳은 아님
# 표준편차, 평균...
# 그래서 학교 근처라고 생각했음
# 3달라부터 50달러 사이에 있는 식당

# %%
tips.boxplot()

# %%
tips[['total_bill','tip']].boxplot()
# fancyindexing
# boxplot()은 DF에 쓸 수 있었기 때문에

# %% [markdown]
# 예측분석할때는 전혀 사용하지 않지만 판다스에서 지원
# aggregation 분석 지원

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %% [markdown]
# 여자가 팁 더 많이 줌 비율

# %%
tips.groupby('sex').sum()
# Out:
#         total_bill     tip  size
# sex
# Male       3256.82  485.07   413
# Female     1570.95  246.51   214

# %%
tips.groupby('sex').min()
# Out:
#         total_bill  tip  size
# sex
# Male          7.25  1.0     1
# Female        3.07  1.0     1

# %%
tips.groupby('sex').max()
# Out:
#         total_bill   tip  size
# sex
# Male         50.81  10.0     6
# Female       44.30   6.5     6

# %%
tips.groupby('day').mean()
# Out:
#       total_bill       tip      size
# day
# Thur   17.682742  2.771452  2.451613
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105

# %%
tips.groupby('day').max()
# Out:
#       total_bill    tip  size
# day
# Thur       43.11   6.70     6
# Fri        40.17   4.73     4
# Sat        50.81  10.00     5
# Sun        48.17   6.50     6

# %%
tips.groupby(['sex','day']).mean()
# Out:
#              total_bill       tip      size
# sex    day
# Male   Thur   18.714667  2.980333  2.433333
#        Fri    19.857000  2.693000  2.100000
#        Sat    20.802542  3.083898  2.644068
#        Sun    21.887241  3.220345  2.810345
# Female Thur   16.715312  2.575625  2.468750
#        Fri    14.145556  2.781111  2.111111
#        Sat    19.680357  2.801786  2.250000
#        Sun    19.872222  3.367222  2.944444

# %%
tips.groupby(['sex','day'])['total_bill', 'tip'].mean()
# 두 컬럼만 보고 싶으면
# Out:
#              total_bill       tip
# sex    day
# Male   Thur   18.714667  2.980333
#        Fri    19.857000  2.693000
#        Sat    20.802542  3.083898
#        Sun    21.887241  3.220345
# Female Thur   16.715312  2.575625
#        Fri    14.145556  2.781111
#        Sat    19.680357  2.801786
#        Sun    19.872222  3.367222

# %%
tips.groupby(['sex','day','time'])['total_bill', 'tip'].mean()
# Out:
#                     total_bill       tip
# sex    day  time
# Male   Thur Lunch    18.714667  2.980333
#             Dinner         NaN       NaN
#        Fri  Lunch    11.386667  1.900000
#             Dinner   23.487143  3.032857
#        Sat  Lunch          NaN       NaN
#             Dinner   20.802542  3.083898
#        Sun  Lunch          NaN       NaN
#             Dinner   21.887241  3.220345
# Female Thur Lunch    16.648710  2.561935
#             Dinner   18.780000  3.000000
#        Fri  Lunch    13.940000  2.745000
#             Dinner   14.310000  2.810000
#        Sat  Lunch          NaN       NaN
#             Dinner   19.680357  2.801786
#        Sun  Lunch          NaN       NaN
#             Dinner   19.872222  3.367222

# %% [markdown]
# 양만 봤을때~ 일요일 저녁에 먹으러 오는 남자가 팁 제일 많이 준다 하면서 신문에 사기

# %% [markdown]
# 이런 분석을 했다는 건 사기꾼들
# 일반적인 사람들은 aggregation 분석 많이 하지 않음
# 개별적인 사항을 확대시킬 수 있음.
# 경향을 보여주기는 참 좋음

# %%
t = tips.groupby(['sex'])['total_bill','tip'].mean()
t
# Out:
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
# 얘도 그래프 그릴 수 있음
t.plot.bar()

# %%
t.plot.line() # 의미 없음

# %%
t.plot.area()

# %%
t.plot.barh()
