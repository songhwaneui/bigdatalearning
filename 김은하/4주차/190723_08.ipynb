# %%
import pandas as pd
import numpy as np

# %%
pew = pd.read_csv('/Users/eunha/Desktop/2019 빅데이터 청년인재/tidy-data-master/data/pew.txt', delimiter='\t')

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %% [markdown]
# 일반적인 사람들은 이 표가 한 눈에 보이니까 좋아함.
# 정말 자주 있는 실수.
# wideformat(wideform)이라고 함
# 이걸 바꾸는 게 longform

# %%
# pew.melt(
#     id_vars=None, <- 고정시킬 것
#     value_vars=None, <- 지금 안 쓴다
#     var_name=None,
#     value_name='value',
#     col_level=None,
# )
# 지금 여기서는 데이터 몇 개 넣어야? 디폴트값 다 있으니까 안 넣어도 됨
pew.melt()
# 컬럼 = 그 값으로 다 만들어놓음
# Out:
#                variable                    value
# 0              religion                 Agnostic
# 1              religion                  Atheist
# 2              religion                 Buddhist
# 3              religion                 Catholic
# 4              religion       Don’t know/refused
# 5              religion         Evangelical Prot
# 6              religion                    Hindu
# 7              religion  Historically Black Prot
# 8              religion        Jehovah's Witness
# 9              religion                   Jewish
# 10             religion            Mainline Prot
# 11             religion                   Mormon
# 12             religion                   Muslim
# 13             religion                 Orthodox
# 14             religion          Other Christian
# 15             religion             Other Faiths
# 16             religion    Other World Religions
# 17             religion             Unaffiliated
# ...

# %%
pew.melt(['religion']) # 분석용으로 쓰는 데이터
# 와이드포맷은 사람이 보기 좋으라고 쓰는 것
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
pew.melt(['religion'], var_name = '문', value_name="근영") # rename써서 바꿔도 되는데 귀찮으니까 한번에 바꿈
# Out:
#                     religion                   문    근영
# 0                   Agnostic               <$10k    27
# 1                    Atheist               <$10k    12
# 2                   Buddhist               <$10k    27
# 3                   Catholic               <$10k   418
# 4         Don’t know/refused               <$10k    15
# 5           Evangelical Prot               <$10k   575
# 6                      Hindu               <$10k     1
# 7    Historically Black Prot               <$10k   228
# 8          Jehovah's Witness               <$10k    20
# 9                     Jewish               <$10k    19
# 10             Mainline Prot               <$10k   289
# 11                    Mormon               <$10k    29
# 12                    Muslim               <$10k     6
# 13                  Orthodox               <$10k    13
# 14           Other Christian               <$10k     9
# 15              Other Faiths               <$10k    20
# ...

# %%
pew.melt(['religion']).variable.value_counts()
# Out:
# $30-40k               18
# >150k                 18
# Don't know/refused    18
# $40-50k               18
# $10-20k               18
# $75-100k              18
# <$10k                 18
# $100-150k             18
# $20-30k               18
# $50-75k               18
# Name: variable, dtype: int64

# %%
# 18?

# %%
pew = pew.melt(['religion']) # in..없으니까 재할당

# %%
pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
# religion    180 non-null object
# variable    180 non-null object
# value       180 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 4.3+ KB

# %%
pew
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
pew.describe() # 값이 어떻게 되는지 묶어서 알 수 있음 의미있는 값을 가지게 되었다
# Out:
#              value
# count   180.000000
# mean    197.533333
# std     326.548693
# min       1.000000
# 25%      18.000000
# 50%      46.000000
# 75%     218.500000
# max    1529.000000

# %%
pew.groupby('variable').mean()
# Out:
#                          value
# variable
# $10-20k             154.500000
# $100-150k           177.611111
# $20-30k             186.500000
# $30-40k             183.444444
# $40-50k             171.388889
# $50-75k             288.055556
# $75-100k            221.666667
# <$10k               107.222222
# >150k               144.888889
# Don't know/refused  340.055556

# %%
# longformat이 아니면 분석할 때 쓰는 포맷이 아니기 때문에 안 되는 게 너무 많다
# 이 때 쓰는 게 .melt()
# tidy data가 아니면 첫번째 해야 되는 것!
# R쪽에서는 아주 기본적으로 쓰는 것

# %%
weather = pd.read_csv('/Users/eunha/Desktop/2019 빅데이터 청년인재/tidy-data-master/data/weather.txt',
                      delimiter='\t', na_values='-')

# %%
weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
weather = weather.melt(weather.columns[:4], var_name='day').dropna()
weather
# Out:
#               id  year  month element    day value
# 0    MX000017004  2010     12    TMAX    day    d1
# 1    MX000017004  2010     12    TMIN    day    d1
# 2    MX000017004  2010      2    TMAX    day    d2
# 3    MX000017004  2010      2    TMIN    day    d2
# 4    MX000017004  2010     11    TMAX    day    d2
# 5    MX000017004  2010     11    TMIN    day    d2
# 6    MX000017004  2010      2    TMAX    day    d3
# 7    MX000017004  2010      2    TMIN    day    d3
# 8    MX000017004  2010      7    TMAX    day    d3
# 9    MX000017004  2010      7    TMIN    day    d3
# 10   MX000017004  2010     11    TMAX    day    d4
# 11   MX000017004  2010     11    TMIN    day    d4
# 12   MX000017004  2010      3    TMAX    day    d5
# 13   MX000017004  2010      3    TMIN    day    d5
# 14   MX000017004  2010      8    TMAX    day    d5
# 15   MX000017004  2010      8    TMIN    day    d5
# 16   MX000017004  2010     10    TMAX    day    d5
# ...

# %%
weather.describe() # year 전부 2010 -> 의미없음
# Out:
#          year       month
# count   132.0  132.000000
# mean   2010.0    7.212121
# std       0.0    3.404152
# min    2010.0    1.000000
# 25%    2010.0    4.000000
# 50%    2010.0    8.000000
# 75%    2010.0   10.000000
# max    2010.0   12.000000

# %%
weather.drop(columns=['id', 'year'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-1eceadb9e687> in <module>
# ----> 1 weather.drop(columns=['id', 'year'], inplace=True)
#       2 weather
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
weather
# Out:
#      month element    day value
# 0       12    TMAX    day    d1
# 1       12    TMIN    day    d1
# 2        2    TMAX    day    d2
# 3        2    TMIN    day    d2
# 4       11    TMAX    day    d2
# 5       11    TMIN    day    d2
# 6        2    TMAX    day    d3
# 7        2    TMIN    day    d3
# 8        7    TMAX    day    d3
# 9        7    TMIN    day    d3
# 10      11    TMAX    day    d4
# 11      11    TMIN    day    d4
# 12       3    TMAX    day    d5
# 13       3    TMIN    day    d5
# 14       8    TMAX    day    d5
# 15       8    TMIN    day    d5
# 16      10    TMAX    day    d5
# 17      10    TMIN    day    d5
# 18      11    TMAX    day    d5
# 19      11    TMIN    day    d5
# 20      12    TMAX    day    d6
# 21      12    TMIN    day    d6
# 22      10    TMAX    day    d7
# 23      10    TMIN    day    d7
# 24       8    TMAX    day    d8
# 25       8    TMIN    day    d8
# 26       3    TMAX    day   d10
# 27       3    TMIN    day   d10
# ...

# %%
weather.reset_index(drop=True, inplace=True)

# %%
weather
# Out:
#      month element    day value
# 0       12    TMAX    day    d1
# 1       12    TMIN    day    d1
# 2        2    TMAX    day    d2
# 3        2    TMIN    day    d2
# 4       11    TMAX    day    d2
# 5       11    TMIN    day    d2
# 6        2    TMAX    day    d3
# 7        2    TMIN    day    d3
# 8        7    TMAX    day    d3
# 9        7    TMIN    day    d3
# 10      11    TMAX    day    d4
# 11      11    TMIN    day    d4
# 12       3    TMAX    day    d5
# 13       3    TMIN    day    d5
# 14       8    TMAX    day    d5
# 15       8    TMIN    day    d5
# 16      10    TMAX    day    d5
# 17      10    TMIN    day    d5
# 18      11    TMAX    day    d5
# 19      11    TMIN    day    d5
# 20      12    TMAX    day    d6
# 21      12    TMIN    day    d6
# 22      10    TMAX    day    d7
# 23      10    TMIN    day    d7
# 24       8    TMAX    day    d8
# 25       8    TMIN    day    d8
# 26       3    TMAX    day   d10
# 27       3    TMIN    day   d10
# ...

# %%
weather.value = weather.value.str.replace('d','')

# %%
weather
# Out:
#      month element    day value
# 0       12    TMAX    day     1
# 1       12    TMIN    day     1
# 2        2    TMAX    day     2
# 3        2    TMIN    day     2
# 4       11    TMAX    day     2
# 5       11    TMIN    day     2
# 6        2    TMAX    day     3
# 7        2    TMIN    day     3
# 8        7    TMAX    day     3
# 9        7    TMIN    day     3
# 10      11    TMAX    day     4
# 11      11    TMIN    day     4
# 12       3    TMAX    day     5
# 13       3    TMIN    day     5
# 14       8    TMAX    day     5
# 15       8    TMIN    day     5
# 16      10    TMAX    day     5
# 17      10    TMIN    day     5
# 18      11    TMAX    day     5
# 19      11    TMIN    day     5
# 20      12    TMAX    day     6
# 21      12    TMIN    day     6
# 22      10    TMAX    day     7
# 23      10    TMIN    day     7
# 24       8    TMAX    day     8
# 25       8    TMIN    day     8
# 26       3    TMAX    day    10
# 27       3    TMIN    day    10
# ...

# %%
weather.drop(columns=['day'], inplace=True)

# %%
weather.sort_values('month', inplace=True)

# %%
weather.reset_index(drop=True, inplace=True)

# %%
weather
# Out:
#      month element value
# 0        1    TMIN   NaN
# 1        1    TMAX   NaN
# 2        1    TMIN    30
# 3        1    TMAX    30
# 4        2    TMAX     2
# 5        2    TMIN     2
# 6        2    TMAX   NaN
# 7        2    TMIN     3
# 8        2    TMIN   NaN
# 9        2    TMAX    11
# 10       2    TMIN    11
# 11       2    TMAX     3
# 12       2    TMIN   NaN
# 13       2    TMIN    23
# 14       2    TMAX    23
# 15       2    TMIN   NaN
# 16       2    TMIN   NaN
# 17       2    TMAX   NaN
# 18       2    TMAX   NaN
# 19       2    TMAX   NaN
# 20       3    TMIN    10
# 21       3    TMAX     5
# 22       3    TMAX    10
# 23       3    TMAX   NaN
# 24       3    TMAX   NaN
# 25       3    TMIN    16
# 26       3    TMIN   NaN
# 27       3    TMAX    16
# 28       3    TMAX   NaN
# 29       3    TMIN   NaN
# ..     ...     ...   ...
# 102     10    TMAX    14
# 103     10    TMAX   NaN
# 104     11    TMIN   NaN
# 105     11    TMAX    26
# 106     11    TMIN    26
# ...

# %%
weather = pd.read_csv('/Users/eunha/Desktop/2019 빅데이터 청년인재/tidy-data-master/data/weather.txt',
                      sep='\t')

# %%
weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
pd.wide_to_long(weather, 'd', ['id', 'year', 'month', 'element'], '')
# Out:
#                                        d
# id          year month element
# MX000017004 2010 1     TMAX    1     NaN
#                                2     NaN
#                                3     NaN
#                                4     NaN
#                                5     NaN
#                                6     NaN
#                                7     NaN
#                                8     NaN
#                                9     NaN
#                                10    NaN
#                                11    NaN
#                                12    NaN
#                                13    NaN
#                                14    NaN
#                                15    NaN
#                                16    NaN
#                                17    NaN
#                                18    NaN
#                                19    NaN
#                                20    NaN
#                                21    NaN
# ...

# %%
pd.wide_to_long(weather, 'd', ['id', 'year', 'month', 'element'], '').dropna()
# 멀티인덱스
# 공통된 것을 모두 그룹화해줘서 보기가 좀더 편함
# melt보다 조금더 편하고 예쁘게 지원
# 그래서 판다스에는 두가지 방식의 melt
# Out:
#                                        d
# id          year month element
# MX000017004 2010 1     TMAX    30  278.0
#                        TMIN    30  145.0
#                  2     TMAX    2   273.0
#                                3   241.0
#                                11  297.0
#                                23  299.0
#                        TMIN    2   144.0
#                                3   144.0
#                                11  134.0
#                                23  107.0
#                  3     TMAX    5   321.0
#                                10  345.0
#                                16  311.0
#                        TMIN    5   142.0
#                                10  168.0
#                                16  176.0
#                  4     TMAX    27  363.0
#                        TMIN    27  167.0
#                  5     TMAX    27  332.0
#                        TMIN    27  182.0
#                  6     TMAX    17  280.0
# ...

# %%
billboard = pd.read_csv('/Users/eunha/Desktop/2019 빅데이터 청년인재/tidy-data-master/data/billboard.csv',)

# %%
billboard
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
billboard = pd.read_csv('/Users/eunha/Desktop/2019 빅데이터 청년인재/tidy-data-master/data/billboard.csv', 
                        parse_dates=True, date_parser='-') # <-??

# %%
billboard.info() #date.entered, date.peaked 날짜로 바꿔야 됨
# parse_dates 실패했음 -> 어쩔 수 없이 datetime 써서 바꿔야 함
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
billboard
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
# billboard.melt()
# melt 자주 쓰이기 때문에 판다스에서

# Signature: pd.wide_to_long(df, stubnames, i, j, sep='', suffix='\\d+')
# Docstring:
# Wide panel to long format. Less flexible but more user-friendly than melt.

# With stubnames ['A', 'B'], this function expects to find one or more
# group of columns with format
# A-suffix1, A-suffix2,..., B-suffix1, B-suffix2,...
# You specify what you want to call this suffix in the resulting long format
# with `j` (for example `j='year'`)

# Each row of these wide variables are assumed to be uniquely identified by
# `i` (can be a single column name or a list of column names)

# All remaining variables in the data frame are left intact.

# pd.wide_to_long(billboard, ) # 얘를 만들어줌
