# %%
# !pip install -U folium # -U : 업그레이드, -q : 밑에이상한거 안뜸.
# Out:
# Requirement already up-to-date: folium in c:\users\seodonguk\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in c:\users\seodonguk\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\seodonguk\anaconda3\lib\site-packages (from folium) (1.16.2)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in c:\users\seodonguk\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied, skipping upgrade: requests in c:\users\seodonguk\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied, skipping upgrade: six in c:\users\seodonguk\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\seodonguk\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\seodonguk\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\seodonguk\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\seodonguk\anaconda3\lib\site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in c:\users\seodonguk\anaconda3\lib\site-packages (from requests->folium) (1.24.1)

# %%
dir(folium) # import하면 dir해본다.
# Out:
# ['Choropleth',
#  'Circle',
#  'CircleMarker',
#  'ClickForMarker',
#  'ColorLine',
#  'ColorMap',
#  'CssLink',
#  'CustomIcon',
#  'Div',
#  'DivIcon',
#  'Element',
#  'FeatureGroup',
#  'Figure',
#  'FitBounds',
#  'GeoJson',
#  'GeoJsonTooltip',
#  'Html',
#  'IFrame',
#  'Icon',
#  'JavascriptLink',
#  'LatLngPopup',
#  'LayerControl',
#  'LinearColormap',
#  'Link',
#  'MacroElement',
#  'Map',
#  'Marker',
#  'PolyLine',
#  'Polygon',
#  'Popup',
#  'Rectangle',
#  'RegularPolygonMarker',
#  'StepColormap',
#  'TileLayer',
#  'Tooltip',
#  'TopoJson',
#  'Vega',
#  'VegaLite',
#  'WmsTileLayer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'branca',
#  'features',
#  'folium',
#  'map',
#  'raster_layers',
#  'sys',
#  'utilities',
#  'vector_layers']

# %%
import folium
m = folium.Map(location=[37.5665, 126.9780],zoom_start = 15) # 나중에 위도 경도 테이블에
# 위치기반 시스템은 api를 받아서 작업해야 한다.

# %%
m # 단순 단계구분도, 보고서용이지 시스템으로 쓰지 않는다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain')

# 지도상에 뭘 박는 것.
# HTML코드 필요.
# icon도 넣을 수 있다.
folium.Marker([37.5248, 126.9375], popup='<i>문근영</i>', 
icon=folium.Icon(icon='cloud')).add_to(m3)
folium.Marker([37.5311, 126.9113], popup='<b>Timberline Lodge</b>').add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
folium.Circle(radius=100, 
location= [37.5248, 126.9375],
popup='The Waterfront', 
color='crimson', 
fill=False, 
).add_to(m4)



folium.CircleMarker(
location=[37.5311, 126.9113], 
radius=50, 
popup='Laurelhurst Park', 
color='#3186cc', 
fill=True, 
fill_color='#3186cc' 
).add_to(m4)
m4
# 웹에서도 똑같이 구현 가능.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 위도 경도 알아내는 것. 사실 이걸 위해서 folium을 쓴다.
m5 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
m5.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m6 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 
m6.add_child(folium.ClickForMarker(popup="ClickPoint"))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 다각형
m7 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    popup='polygon1',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=5
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    popup='polygon2',
    fill_color='#45647d',
    number_of_sides=4,
    radius=10
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    popup='polygon3',
    fill_color='#769d96',
    number_of_sides=6,
    radius=15
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    popup='polygon4',
    fill_color='#769d96',
    number_of_sides=8,
    radius=20
    ).add_to(m7)
m7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

# %%
# !pip install vincent
# Out:
# Collecting vincent
#   Downloading https://files.pythonhosted.org/packages/11/bf/a12ecaa21a2e376a16de67e09f64a38a4acd95e04e5dc35ad2f13a6f0bfd/vincent-0.4.4.tar.gz
# Requirement already satisfied: pandas in c:\users\seodonguk\anaconda3\lib\site-packages (from vincent) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\seodonguk\anaconda3\lib\site-packages (from pandas->vincent) (2.8.0)
# Requirement already satisfied: pytz>=2011k in c:\users\seodonguk\anaconda3\lib\site-packages (from pandas->vincent) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\seodonguk\anaconda3\lib\site-packages (from pandas->vincent) (1.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\seodonguk\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas->vincent) (1.12.0)
# Building wheels for collected packages: vincent
#   Building wheel for vincent (setup.py): started
#   Building wheel for vincent (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\SeoDongUk\AppData\Local\pip\Cache\wheels\4c\0d\8a\65f34c765c6094a71cce3e42a49a26533eef61695e9b505f03
# Successfully built vincent
# Installing collected packages: vincent
# Successfully installed vincent-0.4.4

# %%
import vincent
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
bar.to_json('asset/vis1.json')

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Categories')
line.to_json('asset/vis2.json')

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='index')
scatter.axis_titles(x='Index', y='Data Value')
scatter.legend(title='Categories')
scatter.colors(brew='Set3')
scatter.to_json('asset/vis3.json')

# %%
area = vincent.Area(list_data)
area.to_json('asset/vis4.json')

# %%
import json
m8 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    fill_color='#132b5e',
    radius=5,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis1.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    fill_color='#45647d',
    radius=10,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis2.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    fill_color='#769d96',
    radius=15,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis3.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    fill_color='#769d96',
    radius=20,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis4.json')), width=450, height=250))
    ).add_to(m8)
m8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# seoul_topo_json = open('asset/seoul_municipalities_topo_simple.json', encoding='utf8')
# seoul_topo_json = json.load(seoul_topo_json)

seoul_geo_json = open('asset/seoul_municipalities_geo_simple.json',encoding='utf-8')
seoul_geo_json = json.load(seoul_geo_json)

# %%
m9 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

folium.GeoJson(seoul_geo_json,name='geojson').add_to(m9)

#folium.TopoJson(seoul_topo_json,"objects.seoul_municipalities_geo",name='topojson').add_to(m9)

folium.LayerControl().add_to(m9) # 중간 객체를 이용해서 집어 넣어야 한다.
m9

# 단계 구분도를 그려준다.
# 판다스 연동 시켜서 해야한다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']
# Out:
# [{'arcs': [[0, 1, 2]],
#   'type': 'Polygon',
#   'properties': {'code': '11250',
#    'name': '강동구',
#    'name_eng': 'Gangdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[3, -2, 4, 5]],
#   'type': 'Polygon',
#   'properties': {'code': '11240',
#    'name': '송파구',
#    'name_eng': 'Songpa-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[6, -6, 7, 8, 9, 10]],
#   'type': 'Polygon',
#   'properties': {'code': '11230',
#    'name': '강남구',
#    'name_eng': 'Gangnam-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-9, 11, 12, 13, 14]],
#   'type': 'Polygon',
#   'properties': {'code': '11220',
#    'name': '서초구',
#    'name_eng': 'Seocho-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-13, 15, 16, 17, 18]],
#   'type': 'Polygon',
#   'properties': {'code': '11210',
#    'name': '관악구',
#    'name_eng': 'Gwanak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-14, -19, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'code': '11200',
#    'name': '동작구',
#    'name_eng': 'Dongjak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[21, 22, -20, 23, 24, 25]],
#   'type': 'Polygon',
#   'properties': {'code': '11190',
#    'name': '영등포구',
#    'name_eng': 'Yeongdeungpo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-17, 26, 27]],
#   'type': 'Polygon',
#   'properties': {'code': '11180',
#    'name': '금천구',
#    'name_eng': 'Geumcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[28, -24, -18, -28, 29]],
#   'type': 'Polygon',
#   'properties': {'code': '11170',
#    'name': '구로구',
#    'name_eng': 'Guro-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[30, -26, 31, 32]],
#   'type': 'Polygon',
#   'properties': {'code': '11160',
#    'name': '강서구',
#    'name_eng': 'Gangseo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-32, -25, -29, 33]],
#   'type': 'Polygon',
#   'properties': {'code': '11150',
#    'name': '양천구',
#    'name_eng': 'Yangcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[34, 35, 36, -22, -31, 37, 38]],
#   'type': 'Polygon',
#   'properties': {'code': '11140',
#    'name': '마포구',
#    'name_eng': 'Mapo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[39, 40, -35, 41]],
#   'type': 'Polygon',
#   'properties': {'code': '11130',
#    'name': '서대문구',
#    'name_eng': 'Seodaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[42, -42, -39, 43]],
#   'type': 'Polygon',
#   'properties': {'code': '11120',
#    'name': '은평구',
#    'name_eng': 'Eunpyeong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[44, 45, 46, 47, 48]],
#   'type': 'Polygon',
#   'properties': {'code': '11110',
#    'name': '노원구',
#    'name_eng': 'Nowon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-48, 49, 50]],
#   'type': 'Polygon',
#   'properties': {'code': '11100',
#    'name': '도봉구',
#    'name_eng': 'Dobong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-50, -47, 51, 52]],
#   'type': 'Polygon',
#   'properties': {'code': '11090',
#    'name': '강북구',
#    'name_eng': 'Gangbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[53, -52, -46, 54, 55, 56]],
#   'type': 'Polygon',
#   'properties': {'code': '11080',
#    'name': '성북구',
#    'name_eng': 'Seongbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-45, 57, 58, 59, -55]],
#   'type': 'Polygon',
#   'properties': {'code': '11070',
#    'name': '중랑구',
#    'name_eng': 'Jungnang-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-56, -60, 60, 61, 62]],
#   'type': 'Polygon',
#   'properties': {'code': '11060',
#    'name': '동대문구',
#    'name_eng': 'Dongdaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-59, 63, -3, -4, -7, 64, -61]],
#   'type': 'Polygon',
#   'properties': {'code': '11050',
#    'name': '광진구',
#    'name_eng': 'Gwangjin-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-62, -65, -11, 65, 66]],
#   'type': 'Polygon',
#   'properties': {'code': '11040',
#    'name': '성동구',
#    'name_eng': 'Seongdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-66, -10, -15, -21, -23, -37, 67]],
#   'type': 'Polygon',
#   'properties': {'code': '11030',
#    'name': '용산구',
#    'name_eng': 'Yongsan-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-67, -68, -36, -41, 68]],
#   'type': 'Polygon',
#   'properties': {'code': '11020',
#    'name': '중구',
#    'name_eng': 'Jung-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[69, -57, -63, -69, -40, -43]],
#   'type': 'Polygon',
#   'properties': {'code': '11010',
#    'name': '종로구',
#    'name_eng': 'Jongno-gu',
#    'base_year': '2013',
#    'style': {}}}]

# %%
data = pd.DataFrame.from_dict(seoul_geo_json['features'])
# data = pd.DataFrame.from_dict(seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']).properties

# %%
t = data.geometry.map(lambda x:len(x['coordinates'][0]))
t[t==93]
# Out:
# 3    93
# Name: geometry, dtype: int64

# %%
keys = data[0].keys()

# %%
for i in keys:
    print(i)
# Out:
# code
# name
# name_eng
# base_year

# %%
data_list = {}
for key in keys:
    temp_list = []
    for inst in data:
        temp_list.append(inst[key])
    data_list[key] = temp_list

# %%
data_list.keys()
# Out:
# dict_keys(['code', 'name', 'name_eng', 'base_year'])

# %%
seoul_df = pd.DataFrame.from_dict(data_list)

# %%
seoul_df
# Out:
#      code  name         name_eng base_year
# 0   11250   강동구      Gangdong-gu      2013
# 1   11240   송파구        Songpa-gu      2013
# 2   11230   강남구       Gangnam-gu      2013
# 3   11220   서초구        Seocho-gu      2013
# 4   11210   관악구        Gwanak-gu      2013
# 5   11200   동작구       Dongjak-gu      2013
# 6   11190  영등포구  Yeongdeungpo-gu      2013
# 7   11180   금천구     Geumcheon-gu      2013
# 8   11170   구로구          Guro-gu      2013
# 9   11160   강서구       Gangseo-gu      2013
# 10  11150   양천구     Yangcheon-gu      2013
# 11  11140   마포구          Mapo-gu      2013
# 12  11130  서대문구     Seodaemun-gu      2013
# 13  11120   은평구     Eunpyeong-gu      2013
# 14  11110   노원구         Nowon-gu      2013
# 15  11100   도봉구        Dobong-gu      2013
# 16  11090   강북구       Gangbuk-gu      2013
# 17  11080   성북구      Seongbuk-gu      2013
# 18  11070   중랑구      Jungnang-gu      2013
# 19  11060  동대문구    Dongdaemun-gu      2013
# 20  11050   광진구      Gwangjin-gu      2013
# 21  11040   성동구     Seongdong-gu      2013
# 22  11030   용산구       Yongsan-gu      2013
# 23  11020    중구          Jung-gu      2013
# 24  11010   종로구        Jongno-gu      2013

# %%
seoul_df.to_csv('seoul_geo_df.csv')

# %%
# 단계 그래프
m10 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

seoul_geo_df = pd.read_csv('asset/seoul_geo_df.csv')
m10.choropleth(
    geo_data=seoul_geo_json,
    name='choropleth', # 마음대로
    data=seoul_geo_df, # 판다스 데이타프레임
    columns=['name', 'code'], # key와 value
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Seoul_choropleth'
) #마커가 안됨.
# Out:
# C:\Users\SeoDongUk\Anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
m10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
seoul_topo_json = open('asset/seoul_municipalities_topo_simple.json', encoding='utf-8')

# %%
seoul_topo_json = json.load(seoul_topo_json)

# %%
seoul_topo_json['objects']['seoul_municipalities_geo']['geometries'][2]
# Out:
# {'arcs': [[6, -6, 7, 8, 9, 10]],
#  'type': 'Polygon',
#  'properties': {'code': '11230',
#   'name': '강남구',
#   'name_eng': 'Gangnam-gu',
#   'base_year': '2013'}}

# %%
from pprint import pprint

# %%
for _ in seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']:
    if _['properties']['name'] == '강남구':
        print(_)
# Out:
# {'arcs': [[6, -6, 7, 8, 9, 10]], 'type': 'Polygon', 'properties': {'code': '11230', 'name': '강남구', 'name_eng': 'Gangnam-gu', 'base_year': '2013'}}

# %%
seoul_topo_json['arcs']
# Out:
# [[[5574, 2558],
#   [57, -6],
#   [43, 51],
#   [46, 31],
#   [186, 82],
#   [214, 63],
#   [93, 39],
#   [187, 113],
#   [57, -6],
#   [91, 7],
#   [48, 22],
#   [-25, -67],
#   [11, -58],
#   [28, -42],
#   [21, -58],
#   [7, -68],
#   [38, -91],
#   [-9, -157],
#   [28, -23],
#   [-7, -70],
#   [10, -52],
#   [-29, -3],
#   [-39, 27],
#   [-56, -27],
#   [-52, 7],
#   [-98, -26],
#   [-48, 15],
#   [-154, -214],
#   [-5, -91],
#   [-62, -72],
#   [-27, -69],
#   [-31, -1],
#   [-17, -50],
#   [-2, -48]],
#  [[6078, 1716],
#   [-22, 9],
#   [-386, 207],
#   [21, 43],
#   [45, 160],
#   [-76, 46],
#   [-143, 50]],
#  [[5517, 2231], [40, 79], [30, 112], [0, 102], [-13, 34]],
#  [[4835, 1874],
#   [95, -27],
#   [75, -3],
#   [108, 17],
#   [127, 46],
#   [104, 16],
#   [64, 124],
#   [109, 184]],
#  [[6078, 1716],
#   [0, -27],
#   [-33, -24],
#   [-22, -39],
#   [-19, -72],
#   [19, -61],
#   [65, -38],
#   [40, -5],
#   [39, 24],
#   [28, -26],
#   [110, -29],
#   [42, -27],
#   [-24, -67],
#   [3, -46],
#   [-29, -75],
#   [-23, -32],
#   [-80, -25],
#   [-40, -143],
#   [1, -36],
#   [-47, -35],
#   [-71, -2],
#   [-48, -60],
#   [-77, 30],
#   [-56, 8],
#   [4, -71],
#   [71, -48],
#   [-44, -26],
#   [-63, 0],
#   [-57, 31],
#   [0, -48],
#   [-46, -36]],
#  [[5721, 711],
#   [0, 40],
#   [-28, 61],
#   [-142, 234],
#   [10, 21],
#   [-52, 97],
#   [-54, 56],
#   [-55, 41],
#   [-88, 45],
#   [-294, 93],
#   [-64, 15],
#   [-73, 71],
#   [-43, 290],
#   [-10, 18],
#   [7, 81]],
#  [[4669, 1952], [166, -78]],
#  [[5721, 711],
#   [-77, -59],
#   [-12, -69],
#   [-56, 28],
#   [-19, 30],
#   [-92, 19],
#   [-45, -57],
#   [-84, -16],
#   [-31, 51]],
#  [[5305, 638],
#   [-21, 43],
#   [-107, 91],
#   [-61, 88],
#   [-3, 51],
#   [-98, -14],
#   [-68, -37],
#   [-21, 38],
#   [-39, 7],
#   [-15, -25],
#   [-108, -20],
#   [-14, -76],
#   [-78, -10],
#   [-47, 6],
#   [-141, 166],
#   [-59, 161],
#   [-116, -20],
#   [-40, 97],
#   [-177, 451],
#   [-36, 150],
#   [-19, 46],
#   [-84, 96]],
#  [[3953, 1927], [145, 142]],
#  [[4098, 2069],
#   [63, 49],
#   [80, 23],
#   [258, -123],
#   [16, 33],
#   [34, -32],
#   [120, -67]],
#  [[5305, 638],
#   [-27, -51],
#   [8, -44],
#   [-23, -8],
#   [-17, -47],
#   [-29, -17],
#   [-39, -71],
#   [0, -66],
#   [-68, -34],
#   [-29, -55],
#   [-121, 24],
#   [-50, -12],
#   [5, -35],
#   [42, -23],
#   [-10, -33],
#   [-39, -22],
#   [-14, -73],
#   [10, -25],
#   [-72, -16],
#   [-17, -21],
#   [-74, 21],
#   [-51, 1],
#   [-92, -31],
#   [-36, 34],
#   [-38, 10],
#   [-18, 52],
#   [-105, 97],
#   [-64, 13],
#   [-7, 39],
#   [45, 69],
#   [-11, 32],
#   [4, 58],
#   [-26, 43],
#   [15, 59],
#   [-6, 39],
#   [-30, 30],
#   [-19, 64],
#   [17, 46],
#   [-55, 37],
#   [-83, -141],
#   [-89, -45],
#   [-70, -16],
#   [-82, 1],
#   [-32, 38],
#   [-44, 94],
#   [-16, 8],
#   [-30, 90],
#   [-87, 2],
#   [-27, -12],
#   [15, -54],
#   [-6, -34],
#   [-58, -15],
#   [-74, -64]],
#  [[3581, 574],
#   [-18, 44],
#   [11, 100],
#   [-21, 45],
#   [-37, 36],
#   [-32, 59],
#   [-16, 76]],
#  [[3468, 934], [22, 382], [34, 71], [-62, 44], [-14, 34], [-3, 157]],
#  [[3445, 1622],
#   [38, 27],
#   [78, 3],
#   [32, -18],
#   [139, 77],
#   [91, 58],
#   [38, 37],
#   [32, 63],
#   [60, 58]],
#  [[3581, 574],
#   [-94, -27],
#   [-30, -72],
#   [-74, -50],
#   [-36, -55],
#   [-47, -2],
#   [-106, -38],
#   [-6, -65],
#   [-15, -22],
#   [-60, -6],
#   [-15, -24],
#   [-84, 0],
#   [-127, -38],
#   [-47, 0],
#   [-46, -31],
#   [-19, 28],
#   [3, 56],
#   [-46, 57],
#   [-73, 48],
#   [0, 47],
#   [-36, 40]],
#  [[2623, 420],
#   [-89, 82],
#   [-13, 45],
#   [-90, 20],
#   [-34, -1],
#   [-5, 74],
#   [-24, 47],
#   [15, 26],
#   [-34, 25],
#   [-55, 117],
#   [40, 20],
#   [20, 65],
#   [-40, 24],
#   [4, 53],
#   [-145, -32],
#   [-19, 20]],
#  [[2154, 1005], [60, 90]],
#  [[2214, 1095],
#   [44, 0],
#   [116, 43],
#   [62, 43],
#   [115, 11],
#   [37, 81],
#   [18, 17],
#   [59, -34],
#   [51, -4],
#   [28, -17],
#   [85, 0],
#   [88, 36],
#   [76, -33],
#   [32, -26],
#   [45, 11],
#   [72, 35],
#   [-6, -49],
#   [24, -70],
#   [-16, -73],
#   [147, -157],
#   [103, 23],
#   [74, 2]],
#  [[2214, 1095],
#   [149, 222],
#   [115, 25],
#   [23, 85],
#   [68, 206],
#   [27, 6],
#   [-17, 60],
#   [103, -8],
#   [152, 34],
#   [135, 51]],
#  [[2969, 1776], [49, -49], [63, -43], [116, -49], [248, -13]],
#  [[1998, 2361], [176, -117], [88, -42], [368, -98], [88, -14], [142, -132]],
#  [[2860, 1958], [50, -46], [20, -67], [39, -69]],
#  [[2214, 1095],
#   [-43, 13],
#   [-64, 66],
#   [-45, 149],
#   [-5, 125],
#   [7, 84],
#   [-55, 79],
#   [-175, 101]],
#  [[1834, 1712],
#   [5, 106],
#   [11, 59],
#   [20, 21],
#   [84, 45],
#   [24, 40],
#   [25, -6],
#   [24, 53],
#   [-4, 52],
#   [-64, 147],
#   [-18, 4]],
#  [[1941, 2233], [-14, 53], [71, 75]],
#  [[2623, 420],
#   [-85, -70],
#   [-38, -48],
#   [-19, -55],
#   [-31, -27],
#   [-58, 3],
#   [-48, -48],
#   [-42, -73],
#   [-95, 6],
#   [-1, 35],
#   [-53, 43],
#   [-11, 23],
#   [4, 74],
#   [-12, 29],
#   [-42, 21],
#   [7, 51],
#   [-31, 83],
#   [-24, -14],
#   [-50, 17],
#   [-7, 47],
#   [-45, 23],
#   [-1, 59],
#   [40, 59],
#   [-140, 200],
#   [-52, 93],
#   [-52, 138],
#   [21, 14]],
#  [[1758, 1103],
#   [63, 23],
#   [32, -12],
#   [84, -66],
#   [51, -57],
#   [91, -21],
#   [67, 8],
#   [8, 27]],
#  [[958, 1548],
#   [70, -2],
#   [47, -59],
#   [70, -52],
#   [67, 29],
#   [-9, 30],
#   [76, 3],
#   [6, 46],
#   [56, 15],
#   [23, 25],
#   [44, 9],
#   [43, -26],
#   [42, 14],
#   [31, -63],
#   [37, 0],
#   [12, -28],
#   [43, 6],
#   [50, -14],
#   [52, 11],
#   [20, 60],
#   [80, 112],
#   [16, 48]],
#  [[1758, 1103],
#   [39, 50],
#   [-19, 21],
#   [-49, -14],
#   [0, 33],
#   [-83, 73],
#   [-47, -48],
#   [-57, -29],
#   [-57, -76],
#   [-41, -13],
#   [-22, -45],
#   [-30, -25],
#   [-77, 9],
#   [-18, -22],
#   [-6, -130],
#   [-98, 28],
#   [-64, -7],
#   [-58, 43],
#   [-41, -25],
#   [-76, 4],
#   [-39, -14],
#   [-38, 43],
#   [4, 73],
#   [-10, 48],
#   [11, 31],
#   [56, 39],
#   [-13, 42],
#   [-78, 31],
#   [-55, 33],
#   [-27, 56],
#   [6, 37],
#   [41, -10],
#   [50, 24],
#   [19, 49],
#   [26, 15],
#   [22, 73],
#   [-6, 38],
#   [35, 10]],
#  [[1486, 2836], [-5, -69], [16, -29], [126, -72], [185, -155], [190, -150]],
#  [[1941, 2233],
#   [-16, 0],
#   [-71, 83],
#   [-108, -18],
#   [-53, 14],
#   [-102, 72],
#   [-34, -133],
#   [25, -69],
#   [-5, -84],
#   [9, -133],
#   [-242, -37],
#   [-134, -26],
#   [-97, 193],
#   [10, 24],
#   [-31, 80],
#   [-43, -2],
#   [-10, 49],
#   [-28, 22],
#   [-20, -68],
#   [-75, -23]],
#  [[916, 2177],
#   [-120, -1],
#   [-68, 19],
#   [-17, 29],
#   [-96, -5],
#   [-57, -47],
#   [-15, -51],
#   [-65, -39],
#   [-17, 70],
#   [18, 40],
#   [-49, 7],
#   [0, 39],
#   [-50, 12],
#   [-31, 36],
#   [-109, -1],
#   [-71, 51],
#   [-69, -4],
#   [-56, 90],
#   [-44, 45],
#   [60, 2],
#   [11, 27],
#   [118, 94],
#   [1, 42],
#   [-35, 62],
#   [51, -6],
#   [42, 22],
#   [36, 41],
#   [-12, 31],
#   [16, 36],
#   [108, 74],
#   [59, -4],
#   [-3, 60],
#   [10, 50],
#   [34, 3],
#   [47, 99],
#   [31, 15],
#   [-25, 42],
#   [3, 34],
#   [-29, 55],
#   [-9, 53],
#   [22, 50],
#   [24, 5],
#   [11, 54],
#   [20, 10],
#   [59, -18],
#   [169, -181],
#   [70, -69],
#   [102, -48],
#   [386, -247],
#   [109, -19]],
#  [[958, 1548],
#   [-12, 45],
#   [9, 50],
#   [-22, 58],
#   [38, 69],
#   [-5, 60],
#   [51, 75],
#   [-18, 57],
#   [-27, 5],
#   [-61, 95],
#   [5, 115]],
#  [[2212, 2880],
#   [-24, -28],
#   [51, -40],
#   [240, -130],
#   [95, -28],
#   [41, -37],
#   [-25, -46],
#   [-1, -42],
#   [164, -72],
#   [67, 26],
#   [256, 20],
#   [26, -16],
#   [45, 42]],
#  [[3147, 2529], [26, -47], [-23, -21], [11, -74]],
#  [[3161, 2387],
#   [25, -36],
#   [-32, -20],
#   [-28, -45],
#   [-27, -17],
#   [-21, -71],
#   [-94, -107],
#   [-100, -26],
#   [-24, -107]],
#  [[1486, 2836],
#   [2, 19],
#   [62, 4],
#   [28, 16],
#   [33, -23],
#   [39, 37],
#   [44, 7],
#   [82, 36],
#   [20, 56],
#   [-7, 32],
#   [37, 48],
#   [21, 59],
#   [31, 25]],
#  [[1878, 3152],
#   [115, -119],
#   [61, -50],
#   [33, -15],
#   [46, -61],
#   [56, -46],
#   [23, 19]],
#  [[2969, 3481],
#   [37, -25],
#   [14, -38],
#   [-13, -82],
#   [21, -36],
#   [49, -6],
#   [-13, -60],
#   [32, -71],
#   [1, -29],
#   [-27, -103],
#   [48, -43],
#   [-62, -34],
#   [-36, -36],
#   [209, -251]],
#  [[3229, 2667], [48, -76], [-44, -14], [-52, -39], [-34, -9]],
#  [[2212, 2880],
#   [151, 177],
#   [58, -9],
#   [-5, -47],
#   [104, 17],
#   [25, 62],
#   [35, -1],
#   [33, 24],
#   [-4, 40],
#   [17, 45],
#   [75, 70],
#   [113, 44],
#   [13, 87],
#   [14, 33],
#   [41, 0],
#   [34, 59],
#   [53, 0]],
#  [[3312, 3955],
#   [-41, -40],
#   [-155, -34],
#   [-45, -60],
#   [-73, -11],
#   [-6, -63],
#   [-17, -52],
#   [-22, -23],
#   [16, -31],
#   [10, -79],
#   [-20, -63],
#   [10, -18]],
#  [[1878, 3152],
#   [45, 56],
#   [36, -1],
#   [-30, -52],
#   [30, -48],
#   [66, -3],
#   [29, 14],
#   [60, -11],
#   [46, 24],
#   [-14, 55],
#   [46, 46],
#   [-12, 44],
#   [6, 40],
#   [-19, 73],
#   [29, 13],
#   [-4, 120],
#   [-15, 54],
#   [40, 117],
#   [27, 9],
#   [35, 51],
#   [-14, 42],
#   [37, 41],
#   [6, 44],
#   [-41, 79],
#   [69, 66],
#   [-10, 54],
#   [24, 45],
#   [12, 64],
#   [-77, 40],
#   [11, 22],
#   [89, -54],
#   [118, 16],
#   [66, 37],
#   [56, 49],
#   [90, 12],
#   [40, 26],
#   [54, 91],
#   [52, 30],
#   [59, 15],
#   [6, -30],
#   [57, -47],
#   [50, 6],
#   [38, -51],
#   [14, -67],
#   [40, -17],
#   [32, -93],
#   [37, -9],
#   [70, -85],
#   [-1, -42],
#   [49, -82]],
#  [[5456, 3733],
#   [-68, -20],
#   [-27, -33],
#   [-58, -20],
#   [-113, 53],
#   [-52, 8],
#   [-76, -23],
#   [-156, -67]],
#  [[4906, 3631], [-54, -1], [-46, -27], [-50, 4], [-125, 113], [-67, 82]],
#  [[4564, 3802], [-34, 49], [-103, 84]],
#  [[4427, 3935],
#   [40, 42],
#   [17, 67],
#   [82, 154],
#   [77, -79],
#   [15, 102],
#   [-26, 96],
#   [-3, 93],
#   [-40, 94],
#   [-4, 60],
#   [-40, 105],
#   [5, 79],
#   [22, 83],
#   [23, 143],
#   [-19, 43]],
#  [[4576, 5017],
#   [62, 44],
#   [35, 6],
#   [76, -16],
#   [57, 21],
#   [68, 88],
#   [57, 2],
#   [70, 37],
#   [71, 0],
#   [41, -46],
#   [31, -72],
#   [139, -22],
#   [22, -66],
#   [-58, -81],
#   [-14, -47],
#   [29, -49],
#   [14, -60],
#   [17, -15],
#   [6, -50],
#   [-29, -76],
#   [36, -86],
#   [-10, -45],
#   [-150, -78],
#   [104, -13],
#   [19, -40],
#   [-28, -56],
#   [39, -84],
#   [54, -9],
#   [39, 11],
#   [120, -20],
#   [63, -86],
#   [6, -97],
#   [-22, -90],
#   [-92, -71],
#   [0, -33],
#   [-28, -45],
#   [36, -40]],
#  [[4427, 3935],
#   [-48, 51],
#   [-24, 55],
#   [-39, 22],
#   [-30, 73],
#   [-84, 67],
#   [-47, 47],
#   [-68, 31],
#   [-74, 0],
#   [-38, 26],
#   [-11, 35],
#   [22, 132],
#   [20, 50],
#   [8, 99],
#   [46, 63],
#   [-30, 53],
#   [-45, 52],
#   [-31, 77],
#   [-53, 8],
#   [-5, 96]],
#  [[3896, 4972],
#   [10, 49],
#   [-13, 37],
#   [13, 109],
#   [49, 68],
#   [38, 1],
#   [25, 54],
#   [55, 6],
#   [44, -34],
#   [45, -4],
#   [51, 22],
#   [18, -30],
#   [8, -55],
#   [24, -64],
#   [19, -21],
#   [55, 8],
#   [94, 61],
#   [21, -31],
#   [42, -26],
#   [53, 30],
#   [29, -135]],
#  [[4564, 3802],
#   [-52, -37],
#   [-45, -74],
#   [-65, -59],
#   [-49, -61],
#   [-103, -65],
#   [-3, 61],
#   [-61, 7],
#   [-67, -27],
#   [-47, 48],
#   [-72, 36],
#   [-65, 16],
#   [-36, 41],
#   [-16, 48],
#   [6, 56],
#   [-126, 36],
#   [-55, 65],
#   [-40, 17],
#   [-14, 40],
#   [-30, -1],
#   [-91, 67],
#   [-16, 22]],
#  [[3517, 4038],
#   [25, 71],
#   [-47, 65],
#   [28, 47],
#   [-21, 74],
#   [-40, 48],
#   [-25, 51],
#   [5, 33],
#   [81, 52],
#   [52, 88],
#   [74, 23],
#   [14, 56],
#   [6, 84],
#   [-18, 105],
#   [-20, 35],
#   [34, 17],
#   [65, 68],
#   [90, 25],
#   [76, -8]],
#  [[3364, 3937], [36, 42], [67, 23], [50, 36]],
#  [[4906, 3631], [5, -171]],
#  [[4911, 3460],
#   [-20, 49],
#   [-30, 0],
#   [3, -48],
#   [-53, -26],
#   [-53, -7],
#   [-48, -80],
#   [-28, 10],
#   [-86, -31],
#   [-28, 23],
#   [-42, -94],
#   [-58, 0],
#   [-55, -21],
#   [-24, -76],
#   [-43, -27],
#   [-117, -146],
#   [-95, -84]],
#  [[4134, 2902],
#   [-21, 16],
#   [-57, -6],
#   [-30, 64],
#   [-28, 7],
#   [-93, -34],
#   [-29, 31],
#   [-3, 63],
#   [-15, 31],
#   [-56, 42],
#   [-24, 64],
#   [-84, -3],
#   [-21, -19],
#   [-48, 2],
#   [-78, 23],
#   [-42, 26],
#   [-30, 38],
#   [-7, 64],
#   [54, 6],
#   [45, 35],
#   [-29, 115],
#   [17, 66],
#   [-5, 80],
#   [-62, 39],
#   [-31, 118],
#   [-27, 35],
#   [6, 90],
#   [-46, -7],
#   [-26, 49]],
#  [[5456, 3733],
#   [90, -4],
#   [91, -56],
#   [-6, -31],
#   [15, -87],
#   [-15, -54],
#   [26, -25],
#   [-4, -59],
#   [-67, -90],
#   [3, -18],
#   [69, -78],
#   [-8, -19],
#   [-72, -14],
#   [-45, -79],
#   [-19, -89],
#   [-127, -16],
#   [22, -40],
#   [-2, -67],
#   [-26, -50],
#   [-2, -42]],
#  [[5379, 2815], [-23, -20], [-133, -58], [-124, 35], [-78, 10]],
#  [[5021, 2782],
#   [-6, 119],
#   [-19, 65],
#   [-93, 144],
#   [-28, 144],
#   [10, 39],
#   [38, 57],
#   [4, 32],
#   [-16, 78]],
#  [[5021, 2782], [-103, -230]],
#  [[4918, 2552],
#   [-22, 11],
#   [-182, 32],
#   [-19, 9],
#   [-164, 149],
#   [-92, 51],
#   [-68, -2],
#   [-84, -50],
#   [-48, -8],
#   [-102, 35]],
#  [[4137, 2779], [-3, 123]],
#  [[5379, 2815],
#   [52, -51],
#   [-13, -25],
#   [-22, -141],
#   [-13, -46],
#   [151, -4],
#   [40, 10]],
#  [[4669, 1952], [165, 350], [109, 239], [-25, 11]],
#  [[4098, 2069], [-98, 73], [-85, 13], [-18, 44], [4, 42]],
#  [[3901, 2241],
#   [16, 79],
#   [33, 9],
#   [82, 94],
#   [10, 51],
#   [36, 30],
#   [51, 6],
#   [14, 64],
#   [41, 36],
#   [7, 38],
#   [-50, 4],
#   [-4, 127]],
#  [[3161, 2387],
#   [54, 50],
#   [103, -4],
#   [69, -15],
#   [11, 36],
#   [54, -30],
#   [51, -8],
#   [27, 14],
#   [38, -44],
#   [40, -1],
#   [80, -81],
#   [52, 52],
#   [66, -6],
#   [25, 15],
#   [10, -82],
#   [39, -46],
#   [21, 4]],
#  [[3229, 2667],
#   [39, 44],
#   [62, 19],
#   [78, 1],
#   [178, -22],
#   [124, 12],
#   [79, 17],
#   [227, 4],
#   [74, 37],
#   [47, 0]],
#  [[3312, 3955], [52, -18]]]

# %%
(seoul_topo_json)
# Out:
# {'type': 'Topology',
#  'transform': {'scale': [6.247075827918093e-05, 5.151814945568312e-05],
#   'translate': [126.76700465024426, 37.42574929824175]},
#  'objects': {'seoul_municipalities_geo': {'type': 'GeometryCollection',
#    'geometries': [{'arcs': [[0, 1, 2]],
#      'type': 'Polygon',
#      'properties': {'code': '11250',
#       'name': '강동구',
#       'name_eng': 'Gangdong-gu',
#       'base_year': '2013'}},
#     {'arcs': [[3, -2, 4, 5]],
#      'type': 'Polygon',
#      'properties': {'code': '11240',
#       'name': '송파구',
#       'name_eng': 'Songpa-gu',
#       'base_year': '2013'}},
#     {'arcs': [[6, -6, 7, 8, 9, 10]],
#      'type': 'Polygon',
#      'properties': {'code': '11230',
#       'name': '강남구',
#       'name_eng': 'Gangnam-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-9, 11, 12, 13, 14]],
#      'type': 'Polygon',
#      'properties': {'code': '11220',
#       'name': '서초구',
#       'name_eng': 'Seocho-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-13, 15, 16, 17, 18]],
#      'type': 'Polygon',
#      'properties': {'code': '11210',
#       'name': '관악구',
#       'name_eng': 'Gwanak-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-14, -19, 19, 20]],
#      'type': 'Polygon',
#      'properties': {'code': '11200',
#       'name': '동작구',
#       'name_eng': 'Dongjak-gu',
#       'base_year': '2013'}},
#     {'arcs': [[21, 22, -20, 23, 24, 25]],
#      'type': 'Polygon',
#      'properties': {'code': '11190',
#       'name': '영등포구',
#       'name_eng': 'Yeongdeungpo-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-17, 26, 27]],
#      'type': 'Polygon',
#      'properties': {'code': '11180',
#       'name': '금천구',
#       'name_eng': 'Geumcheon-gu',
#       'base_year': '2013'}},
#     {'arcs': [[28, -24, -18, -28, 29]],
#      'type': 'Polygon',
#      'properties': {'code': '11170',
#       'name': '구로구',
#       'name_eng': 'Guro-gu',
#       'base_year': '2013'}},
#     {'arcs': [[30, -26, 31, 32]],
#      'type': 'Polygon',
#      'properties': {'code': '11160',
#       'name': '강서구',
#       'name_eng': 'Gangseo-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-32, -25, -29, 33]],
#      'type': 'Polygon',
#      'properties': {'code': '11150',
#       'name': '양천구',
#       'name_eng': 'Yangcheon-gu',
#       'base_year': '2013'}},
#     {'arcs': [[34, 35, 36, -22, -31, 37, 38]],
#      'type': 'Polygon',
#      'properties': {'code': '11140',
#       'name': '마포구',
#       'name_eng': 'Mapo-gu',
#       'base_year': '2013'}},
#     {'arcs': [[39, 40, -35, 41]],
#      'type': 'Polygon',
#      'properties': {'code': '11130',
#       'name': '서대문구',
#       'name_eng': 'Seodaemun-gu',
#       'base_year': '2013'}},
#     {'arcs': [[42, -42, -39, 43]],
#      'type': 'Polygon',
#      'properties': {'code': '11120',
#       'name': '은평구',
#       'name_eng': 'Eunpyeong-gu',
#       'base_year': '2013'}},
#     {'arcs': [[44, 45, 46, 47, 48]],
#      'type': 'Polygon',
#      'properties': {'code': '11110',
#       'name': '노원구',
#       'name_eng': 'Nowon-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-48, 49, 50]],
#      'type': 'Polygon',
#      'properties': {'code': '11100',
#       'name': '도봉구',
#       'name_eng': 'Dobong-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-50, -47, 51, 52]],
#      'type': 'Polygon',
#      'properties': {'code': '11090',
#       'name': '강북구',
#       'name_eng': 'Gangbuk-gu',
#       'base_year': '2013'}},
#     {'arcs': [[53, -52, -46, 54, 55, 56]],
#      'type': 'Polygon',
#      'properties': {'code': '11080',
#       'name': '성북구',
#       'name_eng': 'Seongbuk-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-45, 57, 58, 59, -55]],
#      'type': 'Polygon',
#      'properties': {'code': '11070',
#       'name': '중랑구',
#       'name_eng': 'Jungnang-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-56, -60, 60, 61, 62]],
#      'type': 'Polygon',
#      'properties': {'code': '11060',
#       'name': '동대문구',
#       'name_eng': 'Dongdaemun-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-59, 63, -3, -4, -7, 64, -61]],
#      'type': 'Polygon',
#      'properties': {'code': '11050',
#       'name': '광진구',
#       'name_eng': 'Gwangjin-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-62, -65, -11, 65, 66]],
#      'type': 'Polygon',
#      'properties': {'code': '11040',
#       'name': '성동구',
#       'name_eng': 'Seongdong-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-66, -10, -15, -21, -23, -37, 67]],
#      'type': 'Polygon',
#      'properties': {'code': '11030',
#       'name': '용산구',
#       'name_eng': 'Yongsan-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-67, -68, -36, -41, 68]],
#      'type': 'Polygon',
#      'properties': {'code': '11020',
#       'name': '중구',
#       'name_eng': 'Jung-gu',
#       'base_year': '2013'}},
#     {'arcs': [[69, -57, -63, -69, -40, -43]],
#      'type': 'Polygon',
#      'properties': {'code': '11010',
#       'name': '종로구',
#       'name_eng': 'Jongno-gu',
#       'base_year': '2013'}}]}},
#  'arcs': [[[5574, 2558],
#    [57, -6],
#    [43, 51],
#    [46, 31],
#    [186, 82],
#    [214, 63],
#    [93, 39],
#    [187, 113],
#    [57, -6],
#    [91, 7],
#    [48, 22],
#    [-25, -67],
#    [11, -58],
#    [28, -42],
#    [21, -58],
#    [7, -68],
#    [38, -91],
#    [-9, -157],
#    [28, -23],
#    [-7, -70],
#    [10, -52],
#    [-29, -3],
#    [-39, 27],
#    [-56, -27],
#    [-52, 7],
#    [-98, -26],
#    [-48, 15],
#    [-154, -214],
#    [-5, -91],
#    [-62, -72],
#    [-27, -69],
#    [-31, -1],
#    [-17, -50],
#    [-2, -48]],
#   [[6078, 1716],
#    [-22, 9],
#    [-386, 207],
#    [21, 43],
#    [45, 160],
#    [-76, 46],
#    [-143, 50]],
#   [[5517, 2231], [40, 79], [30, 112], [0, 102], [-13, 34]],
#   [[4835, 1874],
#    [95, -27],
#    [75, -3],
#    [108, 17],
#    [127, 46],
#    [104, 16],
#    [64, 124],
#    [109, 184]],
#   [[6078, 1716],
#    [0, -27],
#    [-33, -24],
#    [-22, -39],
#    [-19, -72],
#    [19, -61],
#    [65, -38],
#    [40, -5],
#    [39, 24],
#    [28, -26],
#    [110, -29],
#    [42, -27],
#    [-24, -67],
#    [3, -46],
#    [-29, -75],
#    [-23, -32],
#    [-80, -25],
#    [-40, -143],
#    [1, -36],
#    [-47, -35],
#    [-71, -2],
#    [-48, -60],
#    [-77, 30],
#    [-56, 8],
#    [4, -71],
#    [71, -48],
#    [-44, -26],
#    [-63, 0],
#    [-57, 31],
#    [0, -48],
#    [-46, -36]],
#   [[5721, 711],
#    [0, 40],
#    [-28, 61],
#    [-142, 234],
#    [10, 21],
#    [-52, 97],
#    [-54, 56],
#    [-55, 41],
#    [-88, 45],
#    [-294, 93],
#    [-64, 15],
#    [-73, 71],
#    [-43, 290],
#    [-10, 18],
#    [7, 81]],
#   [[4669, 1952], [166, -78]],
#   [[5721, 711],
#    [-77, -59],
#    [-12, -69],
#    [-56, 28],
#    [-19, 30],
#    [-92, 19],
#    [-45, -57],
#    [-84, -16],
#    [-31, 51]],
#   [[5305, 638],
#    [-21, 43],
#    [-107, 91],
#    [-61, 88],
#    [-3, 51],
#    [-98, -14],
#    [-68, -37],
#    [-21, 38],
#    [-39, 7],
#    [-15, -25],
#    [-108, -20],
#    [-14, -76],
#    [-78, -10],
#    [-47, 6],
#    [-141, 166],
#    [-59, 161],
#    [-116, -20],
#    [-40, 97],
#    [-177, 451],
#    [-36, 150],
#    [-19, 46],
#    [-84, 96]],
#   [[3953, 1927], [145, 142]],
#   [[4098, 2069],
#    [63, 49],
#    [80, 23],
#    [258, -123],
#    [16, 33],
#    [34, -32],
#    [120, -67]],
#   [[5305, 638],
#    [-27, -51],
#    [8, -44],
#    [-23, -8],
#    [-17, -47],
#    [-29, -17],
#    [-39, -71],
#    [0, -66],
#    [-68, -34],
#    [-29, -55],
#    [-121, 24],
#    [-50, -12],
#    [5, -35],
#    [42, -23],
#    [-10, -33],
#    [-39, -22],
#    [-14, -73],
#    [10, -25],
#    [-72, -16],
#    [-17, -21],
#    [-74, 21],
#    [-51, 1],
#    [-92, -31],
#    [-36, 34],
#    [-38, 10],
#    [-18, 52],
#    [-105, 97],
#    [-64, 13],
#    [-7, 39],
#    [45, 69],
#    [-11, 32],
#    [4, 58],
#    [-26, 43],
#    [15, 59],
#    [-6, 39],
#    [-30, 30],
#    [-19, 64],
#    [17, 46],
#    [-55, 37],
#    [-83, -141],
#    [-89, -45],
#    [-70, -16],
#    [-82, 1],
#    [-32, 38],
#    [-44, 94],
#    [-16, 8],
#    [-30, 90],
#    [-87, 2],
#    [-27, -12],
#    [15, -54],
#    [-6, -34],
#    [-58, -15],
#    [-74, -64]],
#   [[3581, 574],
#    [-18, 44],
#    [11, 100],
#    [-21, 45],
#    [-37, 36],
#    [-32, 59],
#    [-16, 76]],
#   [[3468, 934], [22, 382], [34, 71], [-62, 44], [-14, 34], [-3, 157]],
#   [[3445, 1622],
#    [38, 27],
#    [78, 3],
#    [32, -18],
#    [139, 77],
#    [91, 58],
#    [38, 37],
#    [32, 63],
#    [60, 58]],
#   [[3581, 574],
#    [-94, -27],
#    [-30, -72],
#    [-74, -50],
#    [-36, -55],
#    [-47, -2],
#    [-106, -38],
#    [-6, -65],
#    [-15, -22],
#    [-60, -6],
#    [-15, -24],
#    [-84, 0],
#    [-127, -38],
#    [-47, 0],
#    [-46, -31],
#    [-19, 28],
#    [3, 56],
#    [-46, 57],
#    [-73, 48],
#    [0, 47],
#    [-36, 40]],
#   [[2623, 420],
#    [-89, 82],
#    [-13, 45],
#    [-90, 20],
#    [-34, -1],
#    [-5, 74],
#    [-24, 47],
#    [15, 26],
#    [-34, 25],
#    [-55, 117],
#    [40, 20],
#    [20, 65],
#    [-40, 24],
#    [4, 53],
#    [-145, -32],
#    [-19, 20]],
#   [[2154, 1005], [60, 90]],
#   [[2214, 1095],
#    [44, 0],
#    [116, 43],
#    [62, 43],
#    [115, 11],
#    [37, 81],
#    [18, 17],
#    [59, -34],
#    [51, -4],
#    [28, -17],
#    [85, 0],
#    [88, 36],
#    [76, -33],
#    [32, -26],
#    [45, 11],
#    [72, 35],
#    [-6, -49],
#    [24, -70],
#    [-16, -73],
#    [147, -157],
#    [103, 23],
#    [74, 2]],
#   [[2214, 1095],
#    [149, 222],
#    [115, 25],
#    [23, 85],
#    [68, 206],
#    [27, 6],
#    [-17, 60],
#    [103, -8],
#    [152, 34],
#    [135, 51]],
#   [[2969, 1776], [49, -49], [63, -43], [116, -49], [248, -13]],
#   [[1998, 2361], [176, -117], [88, -42], [368, -98], [88, -14], [142, -132]],
#   [[2860, 1958], [50, -46], [20, -67], [39, -69]],
#   [[2214, 1095],
#    [-43, 13],
#    [-64, 66],
#    [-45, 149],
#    [-5, 125],
#    [7, 84],
#    [-55, 79],
#    [-175, 101]],
#   [[1834, 1712],
#    [5, 106],
#    [11, 59],
#    [20, 21],
#    [84, 45],
#    [24, 40],
#    [25, -6],
#    [24, 53],
#    [-4, 52],
#    [-64, 147],
#    [-18, 4]],
#   [[1941, 2233], [-14, 53], [71, 75]],
#   [[2623, 420],
#    [-85, -70],
#    [-38, -48],
#    [-19, -55],
#    [-31, -27],
#    [-58, 3],
#    [-48, -48],
#    [-42, -73],
#    [-95, 6],
#    [-1, 35],
#    [-53, 43],
#    [-11, 23],
#    [4, 74],
#    [-12, 29],
#    [-42, 21],
#    [7, 51],
#    [-31, 83],
#    [-24, -14],
#    [-50, 17],
#    [-7, 47],
#    [-45, 23],
#    [-1, 59],
#    [40, 59],
#    [-140, 200],
#    [-52, 93],
#    [-52, 138],
#    [21, 14]],
#   [[1758, 1103],
#    [63, 23],
#    [32, -12],
#    [84, -66],
#    [51, -57],
#    [91, -21],
#    [67, 8],
#    [8, 27]],
#   [[958, 1548],
#    [70, -2],
#    [47, -59],
#    [70, -52],
#    [67, 29],
#    [-9, 30],
#    [76, 3],
#    [6, 46],
#    [56, 15],
#    [23, 25],
#    [44, 9],
#    [43, -26],
#    [42, 14],
#    [31, -63],
#    [37, 0],
#    [12, -28],
#    [43, 6],
#    [50, -14],
#    [52, 11],
#    [20, 60],
#    [80, 112],
#    [16, 48]],
#   [[1758, 1103],
#    [39, 50],
#    [-19, 21],
#    [-49, -14],
#    [0, 33],
#    [-83, 73],
#    [-47, -48],
#    [-57, -29],
#    [-57, -76],
#    [-41, -13],
#    [-22, -45],
#    [-30, -25],
#    [-77, 9],
#    [-18, -22],
#    [-6, -130],
#    [-98, 28],
#    [-64, -7],
#    [-58, 43],
#    [-41, -25],
#    [-76, 4],
#    [-39, -14],
#    [-38, 43],
#    [4, 73],
#    [-10, 48],
#    [11, 31],
#    [56, 39],
#    [-13, 42],
#    [-78, 31],
#    [-55, 33],
#    [-27, 56],
#    [6, 37],
#    [41, -10],
#    [50, 24],
#    [19, 49],
#    [26, 15],
#    [22, 73],
#    [-6, 38],
#    [35, 10]],
#   [[1486, 2836], [-5, -69], [16, -29], [126, -72], [185, -155], [190, -150]],
#   [[1941, 2233],
#    [-16, 0],
#    [-71, 83],
#    [-108, -18],
#    [-53, 14],
#    [-102, 72],
#    [-34, -133],
#    [25, -69],
#    [-5, -84],
#    [9, -133],
#    [-242, -37],
#    [-134, -26],
#    [-97, 193],
#    [10, 24],
#    [-31, 80],
#    [-43, -2],
#    [-10, 49],
#    [-28, 22],
#    [-20, -68],
#    [-75, -23]],
#   [[916, 2177],
#    [-120, -1],
#    [-68, 19],
#    [-17, 29],
#    [-96, -5],
#    [-57, -47],
#    [-15, -51],
#    [-65, -39],
#    [-17, 70],
#    [18, 40],
#    [-49, 7],
#    [0, 39],
#    [-50, 12],
#    [-31, 36],
#    [-109, -1],
#    [-71, 51],
#    [-69, -4],
#    [-56, 90],
#    [-44, 45],
#    [60, 2],
#    [11, 27],
#    [118, 94],
#    [1, 42],
#    [-35, 62],
#    [51, -6],
#    [42, 22],
#    [36, 41],
#    [-12, 31],
#    [16, 36],
#    [108, 74],
#    [59, -4],
#    [-3, 60],
#    [10, 50],
#    [34, 3],
#    [47, 99],
#    [31, 15],
#    [-25, 42],
#    [3, 34],
#    [-29, 55],
#    [-9, 53],
#    [22, 50],
#    [24, 5],
#    [11, 54],
#    [20, 10],
#    [59, -18],
#    [169, -181],
#    [70, -69],
#    [102, -48],
#    [386, -247],
#    [109, -19]],
#   [[958, 1548],
#    [-12, 45],
#    [9, 50],
#    [-22, 58],
#    [38, 69],
#    [-5, 60],
#    [51, 75],
#    [-18, 57],
#    [-27, 5],
#    [-61, 95],
#    [5, 115]],
#   [[2212, 2880],
#    [-24, -28],
#    [51, -40],
#    [240, -130],
#    [95, -28],
#    [41, -37],
#    [-25, -46],
#    [-1, -42],
#    [164, -72],
#    [67, 26],
#    [256, 20],
#    [26, -16],
#    [45, 42]],
#   [[3147, 2529], [26, -47], [-23, -21], [11, -74]],
#   [[3161, 2387],
#    [25, -36],
#    [-32, -20],
#    [-28, -45],
#    [-27, -17],
#    [-21, -71],
#    [-94, -107],
#    [-100, -26],
#    [-24, -107]],
#   [[1486, 2836],
#    [2, 19],
#    [62, 4],
#    [28, 16],
#    [33, -23],
#    [39, 37],
#    [44, 7],
#    [82, 36],
#    [20, 56],
#    [-7, 32],
#    [37, 48],
#    [21, 59],
#    [31, 25]],
#   [[1878, 3152],
#    [115, -119],
#    [61, -50],
#    [33, -15],
#    [46, -61],
#    [56, -46],
#    [23, 19]],
#   [[2969, 3481],
#    [37, -25],
#    [14, -38],
#    [-13, -82],
#    [21, -36],
#    [49, -6],
#    [-13, -60],
#    [32, -71],
#    [1, -29],
#    [-27, -103],
#    [48, -43],
#    [-62, -34],
#    [-36, -36],
#    [209, -251]],
#   [[3229, 2667], [48, -76], [-44, -14], [-52, -39], [-34, -9]],
#   [[2212, 2880],
#    [151, 177],
#    [58, -9],
#    [-5, -47],
#    [104, 17],
#    [25, 62],
#    [35, -1],
#    [33, 24],
#    [-4, 40],
#    [17, 45],
#    [75, 70],
#    [113, 44],
#    [13, 87],
#    [14, 33],
#    [41, 0],
#    [34, 59],
#    [53, 0]],
#   [[3312, 3955],
#    [-41, -40],
#    [-155, -34],
#    [-45, -60],
#    [-73, -11],
#    [-6, -63],
#    [-17, -52],
#    [-22, -23],
#    [16, -31],
#    [10, -79],
#    [-20, -63],
#    [10, -18]],
#   [[1878, 3152],
#    [45, 56],
#    [36, -1],
#    [-30, -52],
#    [30, -48],
#    [66, -3],
#    [29, 14],
#    [60, -11],
#    [46, 24],
#    [-14, 55],
#    [46, 46],
#    [-12, 44],
#    [6, 40],
#    [-19, 73],
#    [29, 13],
#    [-4, 120],
#    [-15, 54],
#    [40, 117],
#    [27, 9],
#    [35, 51],
#    [-14, 42],
#    [37, 41],
#    [6, 44],
#    [-41, 79],
#    [69, 66],
#    [-10, 54],
#    [24, 45],
#    [12, 64],
#    [-77, 40],
#    [11, 22],
#    [89, -54],
#    [118, 16],
#    [66, 37],
#    [56, 49],
#    [90, 12],
#    [40, 26],
#    [54, 91],
#    [52, 30],
#    [59, 15],
#    [6, -30],
#    [57, -47],
#    [50, 6],
#    [38, -51],
#    [14, -67],
#    [40, -17],
#    [32, -93],
#    [37, -9],
#    [70, -85],
#    [-1, -42],
#    [49, -82]],
#   [[5456, 3733],
#    [-68, -20],
#    [-27, -33],
#    [-58, -20],
#    [-113, 53],
#    [-52, 8],
#    [-76, -23],
#    [-156, -67]],
#   [[4906, 3631], [-54, -1], [-46, -27], [-50, 4], [-125, 113], [-67, 82]],
#   [[4564, 3802], [-34, 49], [-103, 84]],
#   [[4427, 3935],
#    [40, 42],
#    [17, 67],
#    [82, 154],
#    [77, -79],
#    [15, 102],
#    [-26, 96],
#    [-3, 93],
#    [-40, 94],
#    [-4, 60],
#    [-40, 105],
#    [5, 79],
#    [22, 83],
#    [23, 143],
#    [-19, 43]],
#   [[4576, 5017],
#    [62, 44],
#    [35, 6],
#    [76, -16],
#    [57, 21],
#    [68, 88],
#    [57, 2],
#    [70, 37],
#    [71, 0],
#    [41, -46],
#    [31, -72],
#    [139, -22],
#    [22, -66],
#    [-58, -81],
#    [-14, -47],
#    [29, -49],
#    [14, -60],
#    [17, -15],
#    [6, -50],
#    [-29, -76],
#    [36, -86],
#    [-10, -45],
#    [-150, -78],
#    [104, -13],
#    [19, -40],
#    [-28, -56],
#    [39, -84],
#    [54, -9],
#    [39, 11],
#    [120, -20],
#    [63, -86],
#    [6, -97],
#    [-22, -90],
#    [-92, -71],
#    [0, -33],
#    [-28, -45],
#    [36, -40]],
#   [[4427, 3935],
#    [-48, 51],
#    [-24, 55],
#    [-39, 22],
#    [-30, 73],
#    [-84, 67],
#    [-47, 47],
#    [-68, 31],
#    [-74, 0],
#    [-38, 26],
#    [-11, 35],
#    [22, 132],
#    [20, 50],
#    [8, 99],
#    [46, 63],
#    [-30, 53],
#    [-45, 52],
#    [-31, 77],
#    [-53, 8],
#    [-5, 96]],
#   [[3896, 4972],
#    [10, 49],
#    [-13, 37],
#    [13, 109],
#    [49, 68],
#    [38, 1],
#    [25, 54],
#    [55, 6],
#    [44, -34],
#    [45, -4],
#    [51, 22],
#    [18, -30],
#    [8, -55],
#    [24, -64],
#    [19, -21],
#    [55, 8],
#    [94, 61],
#    [21, -31],
#    [42, -26],
#    [53, 30],
#    [29, -135]],
#   [[4564, 3802],
#    [-52, -37],
#    [-45, -74],
#    [-65, -59],
#    [-49, -61],
#    [-103, -65],
#    [-3, 61],
#    [-61, 7],
#    [-67, -27],
#    [-47, 48],
#    [-72, 36],
#    [-65, 16],
#    [-36, 41],
#    [-16, 48],
#    [6, 56],
#    [-126, 36],
#    [-55, 65],
#    [-40, 17],
#    [-14, 40],
#    [-30, -1],
#    [-91, 67],
#    [-16, 22]],
#   [[3517, 4038],
#    [25, 71],
#    [-47, 65],
#    [28, 47],
#    [-21, 74],
#    [-40, 48],
#    [-25, 51],
#    [5, 33],
#    [81, 52],
#    [52, 88],
#    [74, 23],
#    [14, 56],
#    [6, 84],
#    [-18, 105],
#    [-20, 35],
#    [34, 17],
#    [65, 68],
#    [90, 25],
#    [76, -8]],
#   [[3364, 3937], [36, 42], [67, 23], [50, 36]],
#   [[4906, 3631], [5, -171]],
#   [[4911, 3460],
#    [-20, 49],
#    [-30, 0],
#    [3, -48],
#    [-53, -26],
#    [-53, -7],
#    [-48, -80],
#    [-28, 10],
#    [-86, -31],
#    [-28, 23],
#    [-42, -94],
#    [-58, 0],
#    [-55, -21],
#    [-24, -76],
#    [-43, -27],
#    [-117, -146],
#    [-95, -84]],
#   [[4134, 2902],
#    [-21, 16],
#    [-57, -6],
#    [-30, 64],
#    [-28, 7],
#    [-93, -34],
#    [-29, 31],
#    [-3, 63],
#    [-15, 31],
#    [-56, 42],
#    [-24, 64],
#    [-84, -3],
#    [-21, -19],
#    [-48, 2],
#    [-78, 23],
#    [-42, 26],
#    [-30, 38],
#    [-7, 64],
#    [54, 6],
#    [45, 35],
#    [-29, 115],
#    [17, 66],
#    [-5, 80],
#    [-62, 39],
#    [-31, 118],
#    [-27, 35],
#    [6, 90],
#    [-46, -7],
#    [-26, 49]],
#   [[5456, 3733],
#    [90, -4],
#    [91, -56],
#    [-6, -31],
#    [15, -87],
#    [-15, -54],
#    [26, -25],
#    [-4, -59],
#    [-67, -90],
#    [3, -18],
#    [69, -78],
#    [-8, -19],
#    [-72, -14],
#    [-45, -79],
#    [-19, -89],
#    [-127, -16],
#    [22, -40],
#    [-2, -67],
#    [-26, -50],
#    [-2, -42]],
#   [[5379, 2815], [-23, -20], [-133, -58], [-124, 35], [-78, 10]],
#   [[5021, 2782],
#    [-6, 119],
#    [-19, 65],
#    [-93, 144],
#    [-28, 144],
#    [10, 39],
#    [38, 57],
#    [4, 32],
#    [-16, 78]],
#   [[5021, 2782], [-103, -230]],
#   [[4918, 2552],
#    [-22, 11],
#    [-182, 32],
#    [-19, 9],
#    [-164, 149],
#    [-92, 51],
#    [-68, -2],
#    [-84, -50],
#    [-48, -8],
#    [-102, 35]],
#   [[4137, 2779], [-3, 123]],
#   [[5379, 2815],
#    [52, -51],
#    [-13, -25],
#    [-22, -141],
#    [-13, -46],
#    [151, -4],
#    [40, 10]],
#   [[4669, 1952], [165, 350], [109, 239], [-25, 11]],
#   [[4098, 2069], [-98, 73], [-85, 13], [-18, 44], [4, 42]],
#   [[3901, 2241],
#    [16, 79],
#    [33, 9],
#    [82, 94],
#    [10, 51],
#    [36, 30],
#    [51, 6],
#    [14, 64],
#    [41, 36],
#    [7, 38],
#    [-50, 4],
#    [-4, 127]],
#   [[3161, 2387],
#    [54, 50],
#    [103, -4],
#    [69, -15],
#    [11, 36],
#    [54, -30],
#    [51, -8],
#    [27, 14],
#    [38, -44],
#    [40, -1],
#    [80, -81],
#    [52, 52],
#    [66, -6],
#    [25, 15],
#    [10, -82],
#    [39, -46],
#    [21, 4]],
#   [[3229, 2667],
#    [39, 44],
#    [62, 19],
#    [78, 1],
#    [178, -22],
#    [124, 12],
#    [79, 17],
#    [227, 4],
#    [74, 37],
#    [47, 0]],
#   [[3312, 3955], [52, -18]]]}

# %%
seoul_geo_json = open('asset/seoul_municipalities_geo_simple.json',encoding='utf-8')

# %%
seoul_geo_json = json.load(seoul_geo_json)

# %%
for _ in seoul_geo_json['features']:
    if _['properties']['name'] == '강남구':
        pprint(_)


# geo가 위도 경도고 더 자세해서 좋다.
# Out:
# {'geometry': {'coordinates': [[[127.05867359288398, 37.52629974922568],
#                                [127.0690698130372, 37.522279423505026],
#                                [127.06860425556381, 37.51812758676938],
#                                [127.06926628842805, 37.51717796437217],
#                                [127.0719146000724, 37.50224013587669],
#                                [127.0764808967127, 37.498612695580306],
#                                [127.08050206733888, 37.49783151325589],
#                                [127.0988509639092, 37.49302529254068],
#                                [127.10433125798602, 37.490728250649646],
#                                [127.1077937689776, 37.48860875954992],
#                                [127.11117085201238, 37.485708381512445],
#                                [127.1143875173445, 37.48073157362458],
#                                [127.11380709617507, 37.479633334849325],
#                                [127.12265007208167, 37.46756987490939],
#                                [127.12441393026374, 37.46442715236855],
#                                [127.12440571080893, 37.46240445587048],
#                                [127.11957248720776, 37.45936217377656],
#                                [127.11885903757606, 37.45578434878651],
#                                [127.11535741803938, 37.45722556454321],
#                                [127.11413179478714, 37.45875072431525],
#                                [127.10841788934951, 37.45972888008147],
#                                [127.10561257180657, 37.456815702518746],
#                                [127.10032466845217, 37.45598440195682],
#                                [127.09842759318751, 37.45862253857461],
#                                [127.09712653145507, 37.460848194480654],
#                                [127.09039613625872, 37.465520545397716],
#                                [127.0866005634691, 37.47006403057779],
#                                [127.08640440578156, 37.472697935184655],
#                                [127.0802737559454, 37.471973057552624],
#                                [127.07602132306535, 37.47005021331707],
#                                [127.07476117209941, 37.47199174520626],
#                                [127.07231320371885, 37.47234914588019],
#                                [127.07135137525977, 37.47107802023145],
#                                [127.06463901956462, 37.47003474490574],
#                                [127.06371868919344, 37.4661503234869],
#                                [127.0588551029968, 37.465611780743174],
#                                [127.0559170481904, 37.4659228914077],
#                                [127.04713549385288, 37.474479419244865],
#                                [127.04345123620755, 37.48276415595109],
#                                [127.03621915098798, 37.48175802427603],
#                                [127.03372275812187, 37.48674434662411],
#                                [127.02265609299096, 37.509970106251416],
#                                [127.02038705349842, 37.51771683027875],
#                                [127.01917707838057, 37.520085205855196],
#                                [127.01397119667513, 37.52503988289669],
#                                [127.02302831890559, 37.53231899582663],
#                                [127.0269608080842, 37.53484752757724],
#                                [127.0319617044248, 37.536064291470424],
#                                [127.04806779588436, 37.52970198575087],
#                                [127.04903802830752, 37.53140496708317],
#                                [127.05116490008963, 37.52975116557232],
#                                [127.05867359288398, 37.52629974922568]]],
#               'type': 'Polygon'},
#  'properties': {'base_year': '2013',
#                 'code': '11230',
#                 'name': '강남구',
#                 'name_eng': 'Gangnam-gu'},
#  'type': 'Feature'}

# %%
seoul_geo_json['features'][0]['properties']['name']
# Out:
# '강동구'

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.sex = tips.sex.map({'Male':1,'Female':2}) # 함수,dict 들어갈 수 있다. 시리즈에만 map적용 가능

# %%
tips.sex.map({'Male':1,'Female':2}) # 함수,dict 들어갈 수 있다. 시리즈에만 map적용 가능
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      2
# 5      1
# 6      1
# 7      1
# 8      1
# 9      1
# 10     1
# 11     2
# 12     1
# 13     1
# 14     2
# 15     1
# 16     2
# 17     1
# 18     2
# 19     1
# 20     1
# 21     2
# 22     2
# 23     1
# 24     1
# 25     1
# 26     1
# 27     1
# 28     1
# 29     2
#       ..
# 214    2
# 215    2
# 216    1
# 217    1
# 218    1
# 219    2
# 220    1
# 221    2
# 222    1
# 223    2
# 224    1
# 225    2
# 226    2
# 227    1
# 228    1
# 229    2
# 230    1
# 231    1
# 232    1
# 233    1
# 234    1
# 235    1
# 236    1
# 237    1
# 238    2
# 239    1
# 240    2
# 241    1
# 242    1
# 243    2
# Name: sex, Length: 244, dtype: int64

# %%
tips.sex.map(lambda x:1 if x=='Male' else 2)
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      2
# 5      1
# 6      1
# 7      1
# 8      1
# 9      1
# 10     1
# 11     2
# 12     1
# 13     1
# 14     2
# 15     1
# 16     2
# 17     1
# 18     2
# 19     1
# 20     1
# 21     2
# 22     2
# 23     1
# 24     1
# 25     1
# 26     1
# 27     1
# 28     1
# 29     2
#       ..
# 214    2
# 215    2
# 216    1
# 217    1
# 218    1
# 219    2
# 220    1
# 221    2
# 222    1
# 223    2
# 224    1
# 225    2
# 226    2
# 227    1
# 228    1
# 229    2
# 230    1
# 231    1
# 232    1
# 233    1
# 234    1
# 235    1
# 236    1
# 237    1
# 238    2
# 239    1
# 240    2
# 241    1
# 242    1
# 243    2
# Name: sex, Length: 244, dtype: category
# Categories (2, int64): [1, 2]

# %%
tips.sex.apply(lambda x:1 if x=='Male' else 2) # map은 series에서만 쓸수 있고, apply는 series + dataframe에 쓸 수 있다.
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      2
# 5      1
# 6      1
# 7      1
# 8      1
# 9      1
# 10     1
# 11     2
# 12     1
# 13     1
# 14     2
# 15     1
# 16     2
# 17     1
# 18     2
# 19     1
# 20     1
# 21     2
# 22     2
# 23     1
# 24     1
# 25     1
# 26     1
# 27     1
# 28     1
# 29     2
#       ..
# 214    2
# 215    2
# 216    1
# 217    1
# 218    1
# 219    2
# 220    1
# 221    2
# 222    1
# 223    2
# 224    1
# 225    2
# 226    2
# 227    1
# 228    1
# 229    2
# 230    1
# 231    1
# 232    1
# 233    1
# 234    1
# 235    1
# 236    1
# 237    1
# 238    2
# 239    1
# 240    2
# 241    1
# 242    1
# 243    2
# Name: sex, Length: 244, dtype: category
# Categories (2, int64): [1, 2]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.apply(lambda x:x['total_bill']+x['tip'],axis=1)
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
# 5      30.00
# 6      10.77
# 7      30.00
# 8      17.00
# 9      18.01
# 10     11.98
# 11     40.26
# 12     16.99
# 13     21.43
# 14     17.85
# 15     25.50
# 16     12.00
# 17     20.00
# 18     20.47
# 19     24.00
# 20     22.00
# 21     23.04
# 22     18.00
# 23     47.00
# 24     23.00
# 25     20.15
# 26     15.37
# 27     14.69
# 28     26.00
# 29     22.65
#        ...
# 214    34.67
# 215    14.00
# 216    31.15
# 217    13.09
# 218     9.18
# 219    33.23
# 220    14.36
# 221    16.90
# 222    10.50
# 223    18.98
# 224    15.00
# 225    18.77
# 226    12.09
# 227    23.45
# 228    16.00
# 229    25.00
# 230    26.01
# 231    18.69
# 232    15.00
# 233    12.24
# 234    18.53
# 235    11.32
# 236    13.60
# 237    34.00
# 238    40.50
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
tips[['total_bill','tip']].apply(lambda x:sum(x)) # 판다스의 모든 것을 바꿀 수 있다.
# Out:
# total_bill    4827.77
# tip            731.58
# dtype: float64

# %%
# groupby, crosstab, pivot table 3개 제일 중요하다.
# applymap도 며칠동안 해봐야한다.
< 빠르다 >
# 이것들만 알면 모든 랭글링 다 할 수 있다.

# %%
tips['ratio'] = tips.apply(lambda x:x['tip']/x['total_bill'],axis=1)# 각각 하나 적용하다

# %%
tips # 어떤 정규식 들어왔을때 변형 할 수 있다.
# 차원의 저주 : feature가 많으면 그만큼 데이터도 많이 필요하다. 데이터가 별로 없으면 모델이 학습이 잘 안된다.
# transform도 써봐
# Out:
#      total_bill   tip     sex smoker   day    time  size     ratio
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# 5         25.29  4.71    Male     No   Sun  Dinner     4  0.186240
# 6          8.77  2.00    Male     No   Sun  Dinner     2  0.228050
# 7         26.88  3.12    Male     No   Sun  Dinner     4  0.116071
# 8         15.04  1.96    Male     No   Sun  Dinner     2  0.130319
# 9         14.78  3.23    Male     No   Sun  Dinner     2  0.218539
# 10        10.27  1.71    Male     No   Sun  Dinner     2  0.166504
# 11        35.26  5.00  Female     No   Sun  Dinner     4  0.141804
# 12        15.42  1.57    Male     No   Sun  Dinner     2  0.101816
# 13        18.43  3.00    Male     No   Sun  Dinner     4  0.162778
# 14        14.83  3.02  Female     No   Sun  Dinner     2  0.203641
# 15        21.58  3.92    Male     No   Sun  Dinner     2  0.181650
# 16        10.33  1.67  Female     No   Sun  Dinner     3  0.161665
# 17        16.29  3.71    Male     No   Sun  Dinner     3  0.227747
# 18        16.97  3.50  Female     No   Sun  Dinner     3  0.206246
# 19        20.65  3.35    Male     No   Sat  Dinner     3  0.162228
# 20        17.92  4.08    Male     No   Sat  Dinner     2  0.227679
# 21        20.29  2.75  Female     No   Sat  Dinner     2  0.135535
# 22        15.77  2.23  Female     No   Sat  Dinner     2  0.141408
# 23        39.42  7.58    Male     No   Sat  Dinner     4  0.192288
# 24        19.82  3.18    Male     No   Sat  Dinner     2  0.160444
# 25        17.81  2.34    Male     No   Sat  Dinner     4  0.131387
# 26        13.37  2.00    Male     No   Sat  Dinner     2  0.149589
# 27        12.69  2.00    Male     No   Sat  Dinner     2  0.157604
# 28        21.70  4.30    Male     No   Sat  Dinner     2  0.198157
# 29        19.65  3.00  Female     No   Sat  Dinner     2  0.152672
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3  0.230742
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2  0.085271
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5  0.106572
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  0.129422
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2  0.186047
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4  0.102522
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  0.180921
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  0.259314
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1  0.223776
# 223       15.98  3.00  Female     No   Fri   Lunch     3  0.187735
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  0.117735
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2  0.153657
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2  0.198216
# 227       20.45  3.00    Male     No   Sat  Dinner     4  0.146699
# 228       13.28  2.72    Male     No   Sat  Dinner     2  0.204819
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2  0.130199
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4  0.083299
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  0.191205
# 232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# 233       10.77  1.47    Male     No   Sat  Dinner     2  0.136490
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  0.193175
# 235       10.07  1.25    Male     No   Sat  Dinner     2  0.124131
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  0.079365
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  0.035638
# 238       35.83  4.67  Female     No   Sat  Dinner     3  0.130338
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]
