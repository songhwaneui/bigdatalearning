# %% [markdown]
# # Persistant
# - 저장한다는 뜻

# %% [markdown]
# ## File

# %% [markdown]
# - Header: metadata about the contents of the file (file name, size, type, and so on)
# - Data: contents of the file as written by the creator or editor
# - End of file (EOF): special character that indicates the end of the file

# %% [markdown]
# ![File](https://cl.ly/94ed58be92e3/%255Bcb002ec878d189492ec595f7e72078d3%255D_FileFormat.png)

# %% [markdown]
# - mp3, wav 파일 등 header에 다 들어 있다.

# %% [markdown]
# ## flat file

# %% [markdown]
# data files that contain records with no structured relationships between the records and there's also no structure for indexing. (txt, csv, tsv)
# - text
#   - the new line character (\n) is default EOL terminator.
# - binary : 열때 깨지는 것들
#   - no EOL character

# %% [markdown]
# - 어디에서든지 열린다.

# %% [markdown]
# ## raw file
# 구조가 있는 것들

# %% [markdown]
# ## open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)

# %%
# %%writefile moon.txt
# asd ffdasf
# sadfasdf
# asdfasdfasdfasdf
# asdfasdfsd
# Out:
# Writing moon.txt

# %%
# %%는 셀 전체에 영향을 끼친다.

# %%
file = open('moon.txt',) # 경로,이름,확장자가 필요
# encoding

# %%
type(file) # 관례상 private
# Out:
# _io.TextIOWrapper

# %%
dir(file) ## next가 있다. : iterator or generator
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
next(file) # 한줄씩 뽑아낸다.
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-34-d13b30bd41a6> in <module>
# ----> 1 next(file) # 한줄씩 뽑아낸다.
#
# StopIteration:

# %%
file.readline() # 메모리 상에서 뽑아내서 없애버린다.
# 끝에 에러는 없다
# Out:
# ''

# %%
file.readlines().append('111\n') # 덧붙일 수 있다.
# 하지만 이미 readlines해서 메모리에서 소비시켜버림.

# %%
# 내부적으로 덧붙일 수 없게 해놨다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-abaff0422aa2> in <module>
# ----> 1 architecture(file)
#
# NameError: name 'architecture' is not defined

# %%
x = open('sss.txt','w')

# %%
x.write('Hello, world!')      
x.write('Hello, 문근영!3')      
x.close() # close하기 전에 써지지 않는다.

# %%
x
# Out:
# <_io.TextIOWrapper name='sss.txt' mode='w' encoding='cp949'>

# %%
for i in range(1_000_000):
    open('sss.txt')

# %%
import platform

# %%
platform.architecture() # 파이썬도 platform dependet한 것을 없애고 있다.
# Out:
# ('64bit', 'WindowsPE')

# %%
dir(platform)
# Out:
# ['DEV_NULL',
#  '_UNIXCONFDIR',
#  '_WIN32_CLIENT_RELEASES',
#  '_WIN32_SERVER_RELEASES',
#  '__builtins__',
#  '__cached__',
#  '__copyright__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  '_comparable_version',
#  '_component_re',
#  '_default_architecture',
#  '_dist_try_harder',
#  '_follow_symlinks',
#  '_ironpython26_sys_version_parser',
#  '_ironpython_sys_version_parser',
#  '_java_getprop',
#  '_libc_search',
#  '_linux_distribution',
#  '_lsb_release_version',
#  '_mac_ver_xml',
#  '_node',
#  '_norm_version',
#  '_parse_release_file',
#  '_platform',
#  '_platform_cache',
#  '_pypy_sys_version_parser',
#  '_release_filename',
#  '_release_version',
#  '_supported_dists',
#  '_sys_version',
#  '_sys_version_cache',
#  '_sys_version_parser',
#  '_syscmd_file',
#  '_syscmd_uname',
#  '_syscmd_ver',
#  '_uname_cache',
#  '_ver_output',
#  '_ver_stages',
#  'architecture',
#  'collections',
#  'dist',
#  'java_ver',
#  'libc_ver',
#  'linux_distribution',
#  'mac_ver',
#  'machine',
#  'node',
#  'os',
#  'platform',
#  'popen',
#  'processor',
#  'python_branch',
#  'python_build',
#  'python_compiler',
#  'python_implementation',
#  'python_revision',
#  'python_version',
#  'python_version_tuple',
#  're',
#  'release',
#  'subprocess',
#  'sys',
#  'system',
#  'system_alias',
#  'uname',
#  'uname_result',
#  'version',
#  'warnings',
#  'win32_ver']

# %%
file.readline()
# Out:
# ''

# %%
file.write('Hello, world!')      
file.write('Hello, 문근영!')      
file.close()

# %%
import sys
sys.stdin.encoding # 보통 기본 encoding으로 이것을 따른다.
# 한글 확장형이여서 utf-8은 에러가 날수 있지만 한글파일은 오류가 안난다.
# Out:
# 'cp949'

# %%
sys.stdout.encoding
# Out:
# 'UTF-8'

# %%
open('hello.txt', 'r', encoding='utf-8')

# %% [markdown]
# | 파일 모드 	| 기능 	| 설명 	|
# |-----------	|------------------------	|-------------------------------------------------------------------------------------------------------------------------------------------	|
# | r 	| 읽기 전용 	| 파일을 읽기 전용으로 열기. 단, 파일이 반드시 있어야 하며 파일이 없으면 에러 발생 	|
# | w 	| 쓰기 전용 	| 쓰기 전용으로 새 파일을 생성. 만약 파일이 있으면 내용을 덮어씀 	|
# | a 	| 추가 	| 파일을 열어 파일 끝에 값을 이어 씀. 만약 파일이 없으면 파일을 생성 	|
# | x 	| 배타적 생성(쓰기) 	| 파일을 쓰기 모드로 생성. 파일이 이미 있으면 에러 발생 	|
# | r+ 	| 읽기/쓰기 	| 파일을 읽기/쓰기용으로 열기. 단, 파일이 반드시 있어야 하며 파일이 없으면 에러 발생 	|
# | w+ 	| 읽기/쓰기 	| 파일을 읽기/쓰기용으로 열기. 파일이 없으면 파일을 생성하고, 파일이 있으면 내용을 덮어씀 	|
# | a+ 	| 추가(읽기/쓰기) 	| 파일을 열어 파일 끝에 값을 이어 씀. 만약 파일이 없으면 파일을 생성. 읽기는 파일의 모든 구간에서 가능하지만, 쓰기는 파일의 끝에서만 가능함 	|
# | x+ 	| 배타적 생성(읽기/쓰기) 	| 파일을 읽기/쓰기 모드로 생성. 파일이 이미 있으면 에러 발생 	|
# | t 	| 텍스트 모드 	| 파일을 읽거나 쓸 때 개행 문자 \n과 \r\n을 서로 변환 	|
# | b 	| 바이너리 모드 	| 파일의 내용을 그대로 읽고, 값을 그대로 씀 	|

# %%
file = open('hello2.txt', 'w')    
file.close() 
file.write('Hello, world!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-7d2c72c1c3af> in <module>()
#       1 file = open('hello2.txt', 'w')
#       2 file.close()
# ----> 3 file.write('Hello, world!')
#
# ValueError: I/O operation on closed file.

# %%
file = open('hello.txt', 'r')    
s = file.read()                  
print(s)                         
file.close()
# Out:
# Hello, world!

# %%
file = open('hello.txt', 'r')    
file.close()                     
s = file.read()                  
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8b7a8a8beac3> in <module>()
#       1 file = open('hello.txt', 'r')
#       2 file.close()
# ----> 3 s = file.read()
#       4 print(s)
#
# ValueError: I/O operation on closed file.

# %%
files = []
for _ in range(100000):
    files.append(open('foo.txt', 'w')) # 메모리상에 남아서 안됨.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-60-bd12c407fa52> in <module>
#       1 files = []
#       2 for _ in range(100000):
# ----> 3     files.append(open('foo.txt', 'w'))
#
# OSError: [Errno 24] Too many open files: 'foo.txt'

# %% [markdown]
# 파이썬에는 사용이 끝난 메모리를 정리해주는 가비지 컬렉터가 있어서 파일을 닫지 않아도 가비지 컬렉터가 파일을 닫아줍니다. 하지만 프로그래머가 파일을 직접 닫아야 하는 이유는 다음과 같습니다.
#
# - 너무 많은 파일을 열어 두면 그만큼 메모리 공간을 차지하므로 성능에 영향을 줄 수 있습니다.
# - 파일을 닫지 않으면 데이터가 쓰기가 완료되지 않을 수도 있습니다. 운영체제는 파일을 처리할 때 성능을 위해서 데이터를 버퍼(임시 공간)에 저장한 뒤 파일에 씁니다. 때에 따라서는 파일이 닫히는 시점에 버퍼의 내용이 파일에 저장됩니다.
# - 이론적으로 운영체제에서 열 수 있는 파일의 개수는 한계가 있습니다.
# - 운영체제에 따라 파일을 열었을 때 파일을 잠금 상태로 처리하는 경우가 있습니다. 실질적으로 파일 처리가 끝났더라도 파일을 닫지 않으면 다른 프로그램에서 파일을 사용할 수 없는 상태가 됩니다.
#
# 보통은 파일을 닫지 않아도 큰 문제가 없습니다. 하지만 실무에서는 사소한 실수로도 큰 문제가 발생하는 경우가 있으므로 파일을 정확히 닫는 습관을 기르는 것이 좋습니다.

# %%
# %%writefile sun.txt
# When, in disgrace with fortune and men's eyes,
# I all alone beweep my outcast state,
# And trouble deaf heaven with my bootless cries,
# And look upon myself and curse my fate,
# Out:
# Writing sun.txt

# %%
a = open('sun.txt') # iterator

# %%
a.read()
# Out:
# "When, in disgrace with fortune and men's eyes,\nI all alone beweep my outcast state,\nAnd trouble deaf heaven with my bootless cries,\nAnd look upon myself and curse my fate,"

# %%
a.readline()
# Out:
# ''

# %%
a.readlines()
# Out:
# ['I all alone beweep my outcast state,\n',
#  'And trouble deaf heaven with my bootless cries,\n',
#  'And look upon myself and curse my fate,']

# %%
b = open('sun.txt')

# %%
b.readline()
# Out:
# 'And trouble deaf heaven with my bootless cries,\n'

# %% [markdown]
# ## with

# %%
with open('sun.txt', 'r') as file:    
    s = file.read()                 
    print(s)
# Out:
# When, in disgrace with fortune and men's eyes,
# I all alone beweep my outcast state,
# And trouble deaf heaven with my bootless cries,
# And look upon myself and curse my fate,

# %%
try:
    file = open('sun.txt', 'r')
    s = file.read()                 
    print(s) 
finally:
    file.close()

# %%
with open('sun2.txt', 'w') as file: 
    for i in range(3):
        file.write('Hello, world! {0}\n'.format(i))

# %%
lines = ['문근영\n', 'only one.\n']
 
with open('moon.txt', 'w') as file: 
    file.writelines(lines)

# %%
with open('moon.txt', 'r') as file:    
    lines = file.readlines()
    print(lines)
# Out:
# ['문근영\n', 'only one.\n']

# %%
with open('moon.txt', 'r') as file:    
    line = file.readline()
    print(line.strip('\n'))        
    while line != '':
        line = file.readline()
        print(line.strip('\n'))
# Out:
# 문근영
# only one.

# %%
with open('moon.txt', 'r') as file:   
    for i in file:
        print(i, end='')
# Out:
# 문근영
# only one.

# %%
class File:
    def __init__(self, filename, mode):
        self.filename = filename
        self.mode = mode

    def __enter__(self):
        self.open_file = open(self.filename, self.mode)
        return self.open_file

    def __exit__(self, *args):
        self.open_file.close()

files = []
for _ in range(10000):
    with File('foo.txt', 'w') as infile:
        infile.write('foo')
        files.append(infile)

# %% [markdown]
# | 메서드 	| 설명 	|
# |--------------------------	|------------------------------------------------------------------------	|
# | read([n]) 	| 파일에서 문자열을 읽음 	|
# | write(string or byte_string)	| 파일에 문자열을 씀 	|
# | readline([n]) 	| 파일의 내용을 한 줄 읽음 	|
# | readlines() 	| 파일의 내용을 한 줄씩 읽어서 리스트로 가져옴 	|
# | writelines(문자열리스트) 	| 파일에 리스트의 문자열을 씀, 리스트의 각 문자열에는 \n을 붙여주어야 함 	|

# %% [markdown]
# ## pickle

# %%
name = '문근영'
scores = {'korean': 90, 'english': 95, 'mathematics': 85, 'science': 82}

# %%
import pickle #

# %%
with open('moon.pickle', 'wb') as file:    # 확장자 마음대로
    pickle.dump(name, file) #dump 저장할 때 쓰는 것.
    pickle.dump(scores, file)

# %%
with open('moon.pickle', 'rb') as file:    
    scores_2 = pickle.load(file)
    name_2 = pickle.load(file) # 피클은 순서별로 불러일으킨다.
    
    
    print(scores_2)
    print(name_2)
# Out:
# 문근영
# {'korean': 90, 'english': 95, 'mathematics': 85, 'science': 82}

# %%
name_
# Out:
# '문근영'

# %%
scores_
# Out:
# {'korean': 90, 'english': 95, 'mathematics': 85, 'science': 82}

# %%
with open('moon.pickle', 'rb') as file:    
    scores = pickle.load(file)
    name = pickle.load(file)
    print(name)
    print(scores)
# Out:
# {'korean': 90, 'english': 95, 'mathematics': 85, 'science': 82}
# 문근영

# %%
with open('moon.pickle', 'rb') as file:    
    scores = pickle.load(file)
    print(name)
# Out:
# {'korean': 90, 'english': 95, 'mathematics': 85, 'science': 82}

# %% [markdown]
# | 메서드 	| 설명 	|
# |-----------------------------	|-----------------------------	|
# | pickle.load(파일객체) 	| 파일에서 파이썬 객체를 읽음 	|
# | pickle.dump(객체, 파일객체) 	| 파일에 파이썬 객체를 저장 	|

# %%
todo = ['write blog post', 'reply to email', 'read in a book','안녕']
pickled_data = pickle.dumps(todo) # s가붙으면 한꺼번에 한다.
print(pickled_data)
# Out:
# b'\x80\x03]q\x00(X\x0f\x00\x00\x00write blog postq\x01X\x0e\x00\x00\x00reply to emailq\x02X\x0e\x00\x00\x00read in a bookq\x03X\x06\x00\x00\x00\xec\x95\x88\xeb\x85\x95q\x04e.'

# %%
todo = ['정유민']
pickled_Data = pickle.dumps(todo)
print(pickled_Data)
# Out:
# b'\x80\x03]q\x00X\t\x00\x00\x00\xec\xa0\x95\xec\x9c\xa0\xeb\xaf\xbcq\x01a.'

# %%
pickled_Data.decode('latin1').encode('utf-8')
# Out:
# b'\xc2\x80\x03]q\x00X\t\x00\x00\x00\xc3\xac\xc2\xa0\xc2\x95\xc3\xac\xc2\x9c\xc2\xa0\xc3\xab\xc2\xaf\xc2\xbcq\x01a.'

# %%
import requests

# %%
s = requests.get('https://www.data.go.kr/search/index.do')
s.content.decode('utf-8')

# %%
restored_data = pickle.loads(pickled_data)

# %%
restored_data
# Out:
# ['write blog post', 'reply to email', 'read in a book']

# %%
import pickle
 
name = 'Abder'
website = 'http://abder.io'
english_french = {'paper':'papier', 'pen':'stylo', 'car':'voiture'} # dictionary
tup = (31,'abder',4.0) # tuple
 
pickled_file = open('pickled_file.pickle', 'wb')
pickle.dump(name, pickled_file)
pickle.dump(website, pickled_file)
pickle.dump(english_french, pickled_file)
pickle.dump(tup, pickled_file)

# %%
from pickle import Pickler
 
name = 'Abder'
website = 'http://abder.io'
english_french = {'paper':'papier', 'pen':'stylo', 'car':'voiture'} # dictionary
tup = (31,'abder',4.0) # tuple
 
# 단순한거 저장할때 쓴다. class방식으로 사용하는 것임.
# 순서에 좀더 유연할 수 있다.
pickled_file = open('pickled_file.pickle', 'wb')
p = Pickler(pickled_file)
p.dump(name); p.dump(website); p.dump(english_french); p.dump(tup)

# %%
import pickle
 
pickled_file = open('pickled_file.pickle', 'rb')
 
name = pickle.load(pickled_file)
website = pickle.load(pickled_file)
english_french = pickle.load(pickled_file)
tup = pickle.load(pickled_file)
 
print('Name: ')
print(name)
print('Website:')
print(website)
print('Englsh to French:')
print(english_french)
print('Tuple data:')
print(tup)
# Out:
# Name:
# Abder
# Website:
# http://abder.io
# Englsh to French:
# {'paper': 'papier', 'pen': 'stylo', 'car': 'voiture'}
# Tuple data:
# (31, 'abder', 4.0)

# %%
from pickle import Unpickler
 
pickled_file = open('pickled_file.pickle', 'rb')
u = Unpickler(pickled_file)
name = u.load(); website = u.load(); english_french = u.load(); tup = u.load()
 
print('Name: ')
print(name)
print('Website:')
print(website)
print('English to French:')
print(english_french)
print('Tuple data:')
print(tup)
# Out:
# Name:
# Abder
# Website:
# http://abder.io
# English to French:
# {'paper': 'papier', 'pen': 'stylo', 'car': 'voiture'}
# Tuple data:
# (31, 'abder', 4.0)

# %%
import base64

# %%
data = base64.encodebytes('moon111.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/base64.py in _input_type_check(s)
#     516     try:
# --> 517         m = memoryview(s)
#     518     except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ca1b66f38f8d> in <module>()
# ----> 1 data = base64.encodebytes('moon111.png')
#
# /anaconda3/lib/python3.6/base64.py in encodebytes(s)
#     532     """Encode a bytestring into a bytes object containing multiple lines
#     533     of base-64 data."""
# --> 534     _input_type_check(s)
#     535     pieces = []
#     536     for i in range(0, len(s), MAXBINSIZE):
#
# /anaconda3/lib/python3.6/base64.py in _input_type_check(s)
#     518     except TypeError as err:
#     519         msg = "expected bytes-like object, not %s" % s.__class__.__name__
# --> 520         raise TypeError(msg) from err
#     521     if m.format not in ('c', 'b', 'B'):
#     522         msg = ("expected single byte elements, not %r from %s" %
#
# TypeError: expected bytes-like object, not str

# %%
data = open('moon111.png','rb')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/base64.py in _input_type_check(s)
#     516     try:
# --> 517         m = memoryview(s)
#     518     except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not '_io.BufferedReader'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-3f7572c3d485> in <module>()
# ----> 1 data2 = base64.encodebytes(data)
#
# /anaconda3/lib/python3.6/base64.py in encodebytes(s)
#     532     """Encode a bytestring into a bytes object containing multiple lines
#     533     of base-64 data."""
# --> 534     _input_type_check(s)
#     535     pieces = []
#     536     for i in range(0, len(s), MAXBINSIZE):
#
# /anaconda3/lib/python3.6/base64.py in _input_type_check(s)
#     518     except TypeError as err:
#     519         msg = "expected bytes-like object, not %s" % s.__class__.__name__
# --> 520         raise TypeError(msg) from err
#     521     if m.format not in ('c', 'b', 'B'):
#     522         msg = ("expected single byte elements, not %r from %s" %
#
# TypeError: expected bytes-like object, not BufferedReader

# %% [markdown]
# https://www.datacamp.com/community/tutorials/reading-writing-files-python
# https://realpython.com/read-write-files-python/
